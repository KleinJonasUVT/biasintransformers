# %% [markdown]
# # Data exploration on the SoNaR corpus

# %%
import pandas as pd
import xml.etree.ElementTree as ET
from azure.storage.blob import BlobServiceClient
from io import StringIO
import os
from dotenv import load_dotenv
from collections import Counter
import csv
import numpy as np
import re
from openai import OpenAI, AsyncOpenAI
import tiktoken
import concurrent.futures
import asyncio
from enum import Enum
from pydantic import BaseModel
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import nltk
import string

# initialize the OpenAI client
openai_client = OpenAI(api_key=os.getenv("general_API"))
async_openai_client = AsyncOpenAI(api_key=os.getenv("general_API"))

# Load environment variables from the .env file
load_dotenv()

# Azure Blob Storage configuration
connection_string = os.getenv("SONAR_STORAGE_KEY")

# %%
container_name = "books"
output_file_wordcount_and_10gram_perfile = f"../out/{container_name}/wordcount_and_10gram_perfile_{container_name}.csv"
output_file_fulltext = f"../out/{container_name}/combined_{container_name}.txt"
output_csv_wordfrequencies = f"../out/{container_name}/word_frequencies_{container_name}.csv"
gendered_output_csv = f"../out/{container_name}/gendered_wordpairs_{container_name}.csv"
professions_output_csv = f"../out/{container_name}/professions_{container_name}.csv"

# %% [markdown]
# ### Counting the number of words and 10-grams in a subset of the corpus

# %%
class BlobProcessor:
    def __init__(self, connection_string, container_name, output_file):
        self.connection_string = connection_string
        self.container_name = container_name
        self.blob_service_client = BlobServiceClient.from_connection_string(connection_string)
        self.container_client = self.blob_service_client.get_container_client(container_name)
        self.data = []
        self.output_file = output_file
    
    def list_blobs(self):
        """List all blobs in the container."""
        return list(self.container_client.list_blobs())
    
    def process_xml_files(self):
        """Process XML files in the container and compute word counts and 10-grams."""
        blobs = self.list_blobs()
        xml_files = [blob.name for blob in blobs if blob.name.endswith('.xml')]
        print(f"XML files: {xml_files}")
        print(f"Processing {len(blobs)} files...")
        print(f"First 5 files: {[blob.name for blob in blobs][:5]}")

        total_files = len(blobs)
        for i, blob in enumerate(blobs, start=1):
            blob_name = blob.name
            print(f"Processing file {blob_name} ({i}/{total_files})")

            if blob_name.endswith('.xml'):
                try:
                    # Download blob content
                    blob_client = self.container_client.get_blob_client(blob_name)
                    blob_data = blob_client.download_blob().readall()
                    print(f"Blob data: {blob_data[:100]}")  # Preview first 100 bytes

                    # Parse XML content
                    xml_content = blob_data.decode('iso-8859-15')
                    tree = ET.ElementTree(ET.fromstring(xml_content))
                    root = tree.getroot()

                    # Count <w> elements
                    word_count = len(root.findall('.//dcoi:w', {'dcoi': 'http://lands.let.ru.nl/projects/d-coi/ns/1.0'}))
                except ET.ParseError as e:
                    print(f"Error parsing {blob_name}: {e}")
                    word_count = 0

                # Calculate the number of 10-grams
                ten_grams = max(0, word_count - 10 + 1)
                
                # Append results
                self.data.append({
                    'filename': blob_name,
                    'word_count': word_count,
                    'ten_grams': ten_grams
                })

                print(f"File {blob_name} processed: {i}/{total_files}")

    def get_dataframe(self):
        """Return the data as a Pandas DataFrame."""
        return pd.DataFrame(self.data)
    
    def save_dataframe(self):
        """Save the DataFrame to a file."""
        df = self.get_dataframe()
        df.to_csv(self.output_file, index=False)
        print(f"DataFrame saved to {self.output_file}")
    
    def get_total_ten_grams(self):
        """Calculate the total number of 10-grams."""
        if not self.data:
            return 0
        df = self.get_dataframe()
        return df['ten_grams'].sum()
    
    def summary(self):
        """Print a summary of the processing results."""
        df = self.get_dataframe()
        print(df)
        print(f"Total 10-grams: {self.get_total_ten_grams()}")

# %%
# Initialize BlobProcessor
processor = BlobProcessor(connection_string, container_name, output_file_wordcount_and_10gram_perfile)

# Process XML files
processor.process_xml_files()

# Print summary
processor.summary()

# Save DataFrame to a CSV file
processor.save_dataframe()
# Out:
# XML files: ['WR-P-E-K-0000000001.dcoi.xml', 'WR-P-E-K-0000000002.dcoi.xml', 'WR-P-E-K-0000000003.dcoi.xml', 'WR-P-E-K-0000000004.dcoi.xml', 'WR-P-E-K-0000000005.dcoi.xml', 'WR-P-E-K-0000000006.dcoi.xml', 'WR-P-E-K-0000000007.dcoi.xml', 'WR-P-E-K-0000000008.dcoi.xml', 'WR-P-E-K-0000000009.dcoi.xml', 'WR-P-E-K-0000000010.dcoi.xml', 'WR-P-E-K-0000000011.dcoi.xml', 'WR-P-E-K-0000000012.dcoi.xml', 'WR-P-E-K-0000000013.dcoi.xml', 'WR-P-E-K-0000000014.dcoi.xml', 'WR-P-E-K-0000000015.dcoi.xml', 'WR-P-E-K-0000000016.dcoi.xml', 'WR-P-E-K-0000000017.dcoi.xml', 'WR-P-E-K-0000000018.dcoi.xml', 'WR-P-E-K-0000000019.dcoi.xml', 'WR-P-E-K-0000000020.dcoi.xml', 'WR-P-E-K-0000000021.dcoi.xml', 'WR-P-E-K-0000000022.dcoi.xml', 'WR-P-E-K-0000000023.dcoi.xml', 'WR-P-E-K-0000000024.dcoi.xml', 'WR-P-E-K-0000000025.dcoi.xml', 'WR-P-E-K-0000000026.dcoi.xml', 'WR-P-E-K-0000000027.dcoi.xml', 'WR-P-E-K-0000000028.dcoi.xml', 'WR-P-E-K-0000000029.dcoi.xml', 'WR-P-E-K-0000000030.dcoi.xml', 'WR-P-E-K-0000000031.dcoi.xml', 'WR-P-E-K-0000000032.dcoi.xml', 'WR-P-E-K-0000000033.dcoi.xml', 'WR-P-E-K-0000000034.dcoi.xml', 'WR-P-E-K-0000000035.dcoi.xml', 'WR-P-E-K-0000000036.dcoi.xml', 'WR-P-E-K-0000000037.dcoi.xml', 'WR-P-E-K-0000000038.dcoi.xml', 'WR-P-E-K-0000000039.dcoi.xml', 'WR-P-E-K-0000000040.dcoi.xml', 'WR-P-E-K-0000000041.dcoi.xml', 'WR-P-E-K-0000000042.dcoi.xml', 'WR-P-E-K-0000000043.dcoi.xml', 'WR-P-E-K-0000000044.dcoi.xml', 'WR-P-E-K-0000000045.dcoi.xml', 'WR-P-E-K-0000000046.dcoi.xml', 'WR-P-E-K-0000000047.dcoi.xml', 'WR-P-E-K-0000000048.dcoi.xml', 'WR-P-E-K-0000000049.dcoi.xml', 'WR-P-E-K-0000000050.dcoi.xml', 'WR-P-E-K-0000000051.dcoi.xml', 'WR-P-E-K-0000000052.dcoi.xml', 'WR-P-E-K-0000000053.dcoi.
778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000764.dcoi.xml processed: 764/778
# Processing file WR-P-E-K-0000000765.dcoi.xml (765/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000765.dcoi.xml processed: 765/778
# Processing file WR-P-E-K-0000000766.dcoi.xml (766/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000766.dcoi.xml processed: 766/778
# Processing file WR-P-E-K-0000000767.dcoi.xml (767/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000767.dcoi.xml processed: 767/778
# Processing file WR-P-E-K-0000000768.dcoi.xml (768/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000768.dcoi.xml processed: 768/778
# Processing file WR-P-E-K-0000000769.dcoi.xml (769/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000769.dcoi.xml processed: 769/778
# Processing file WR-P-E-K-0000000770.dcoi.xml (770/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000770.dcoi.xml processed: 770/778
# Processing file WR-P-E-K-0000000771.dcoi.xml (771/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000771.dcoi.xml processed: 771/778
# Processing file WR-P-E-K-0000000772.dcoi.xml (772/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000772.dcoi.xml processed: 772/778
# Processing file WR-P-E-K-0000000773.dcoi.xml (773/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000773.dcoi.xml processed: 773/778
# Processing file WR-P-E-K-0000000774.dcoi.xml (774/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000774.dcoi.xml processed: 774/778
# Processing file WR-P-E-K-0000000775.dcoi.xml (775/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000775.dcoi.xml processed: 775/778
# Processing file WR-P-E-K-0000000776.dcoi.xml (776/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000776.dcoi.xml processed: 776/778
# Processing file WR-P-E-K-0000000777.dcoi.xml (777/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000777.dcoi.xml processed: 777/778
# Processing file WR-P-E-K-0000000778.dcoi.xml (778/778)
# Blob data: b'<?xml version="1.0" encoding="iso-8859-15"?>\n  <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI"'
# File WR-P-E-K-0000000778.dcoi.xml processed: 778/778
#                          filename  word_count  ten_grams
# 0    WR-P-E-K-0000000001.dcoi.xml         619        610
# 1    WR-P-E-K-0000000002.dcoi.xml         647        638
# 2    WR-P-E-K-0000000003.dcoi.xml         794        785
# 3    WR-P-E-K-0000000004.dcoi.xml         627        618
# 4    WR-P-E-K-0000000005.dcoi.xml         525        516
# ..                            ...         ...        ...
# 773  WR-P-E-K-0000000774.dcoi.xml         243        234
# 774  WR-P-E-K-0000000775.dcoi.xml         218        209
# 775  WR-P-E-K-0000000776.dcoi.xml          48         39
# 776  WR-P-E-K-0000000777.dcoi.xml         243        234
# 777  WR-P-E-K-0000000778.dcoi.xml          11          2
#
# [778 rows x 3 columns]
# Total 10-grams: 132769
# DataFrame saved to ../out/blogs/wordcount_and_10gram_perfile_blogs.csv

# %% [markdown]
# ### Inspecting full text and topics

# %%
class BlobTextExtractor:
    def __init__(self, connection_string, container_name):
        self.connection_string = connection_string
        self.container_name = container_name
        self.blob_service_client = BlobServiceClient.from_connection_string(connection_string)
        self.container_client = self.blob_service_client.get_container_client(container_name)

    def extract_text_from_blob(self, blob_name):
        """Extract text from <w> elements in a single blob."""
        try:
            # Download blob content
            blob_client = self.container_client.get_blob_client(blob_name)
            blob_data = blob_client.download_blob().readall()
            
            # Parse the XML content
            tree = ET.ElementTree(ET.fromstring(blob_data.decode('iso-8859-15')))
            root = tree.getroot()
            
            # Extract text from <w> elements
            word_elements = root.findall('.//dcoi:w', {'dcoi': 'http://lands.let.ru.nl/projects/d-coi/ns/1.0'})
            return ' '.join(w.text for w in word_elements if w.text)
        except Exception as e:
            print(f"Error processing blob {blob_name}: {e}")
            return ""

    def save_texts_to_single_file(self, output_file):
        """Extract text from all XML blobs in the container and save to a single file."""
        with open(output_file, 'w', encoding='utf-8') as outfile:
            # List all blobs in the container
            blobs = list(self.container_client.list_blobs())
            xml_files = [blob.name for blob in blobs if blob.name.endswith('.xml')]

            print(f"Found {len(xml_files)} XML files in container '{self.container_name}'.")

            for i, blob_name in enumerate(xml_files, start=1):
                print(f"Processing file {i}/{len(xml_files)}: {blob_name}")

                # Extract text from the blob
                text = self.extract_text_from_blob(blob_name)

                # Write the title (blob name without extension), text, and blank line to the output file
                outfile.write(f"{os.path.splitext(blob_name)[0]}\n")  # Write the title
                outfile.write(text)  # Write the extracted text
                outfile.write("\n\n")  # Add a blank line between entries
                
                print(f"Added text from {blob_name} to the combined file.")
        
        print(f"All texts saved to a single file at {output_file}.")

# %%
# Initialize the BlobTextExtractor
extractor = BlobTextExtractor(connection_string, container_name)

# Extract texts and save to a single output file
extractor.save_texts_to_single_file(output_file_fulltext)
# Out:
# Found 778 XML files in container 'blogs'.
# Processing file 1/778: WR-P-E-K-0000000001.dcoi.xml
# Added text from WR-P-E-K-0000000001.dcoi.xml to the combined file.
# Processing file 2/778: WR-P-E-K-0000000002.dcoi.xml
# Added text from WR-P-E-K-0000000002.dcoi.xml to the combined file.
# Processing file 3/778: WR-P-E-K-0000000003.dcoi.xml
# Added text from WR-P-E-K-0000000003.dcoi.xml to the combined file.
# Processing file 4/778: WR-P-E-K-0000000004.dcoi.xml
# Added text from WR-P-E-K-0000000004.dcoi.xml to the combined file.
# Processing file 5/778: WR-P-E-K-0000000005.dcoi.xml
# Added text from WR-P-E-K-0000000005.dcoi.xml to the combined file.
# Processing file 6/778: WR-P-E-K-0000000006.dcoi.xml
# Added text from WR-P-E-K-0000000006.dcoi.xml to the combined file.
# Processing file 7/778: WR-P-E-K-0000000007.dcoi.xml
# Added text from WR-P-E-K-0000000007.dcoi.xml to the combined file.
# Processing file 8/778: WR-P-E-K-0000000008.dcoi.xml
# Added text from WR-P-E-K-0000000008.dcoi.xml to the combined file.
# Processing file 9/778: WR-P-E-K-0000000009.dcoi.xml
# Added text from WR-P-E-K-0000000009.dcoi.xml to the combined file.
# Processing file 10/778: WR-P-E-K-0000000010.dcoi.xml
# Added text from WR-P-E-K-0000000010.dcoi.xml to the combined file.
# Processing file 11/778: WR-P-E-K-0000000011.dcoi.xml
# Added text from WR-P-E-K-0000000011.dcoi.xml to the combined file.
# Processing file 12/778: WR-P-E-K-0000000012.dcoi.xml
# Added text from WR-P-E-K-0000000012.dcoi.xml to the combined file.
# Processing file 13/778: WR-P-E-K-0000000013.dcoi.xml
# Added text from WR-P-E-K-0000000013.dcoi.xml to the combined file.
# Processing file 14/778: WR-P-E-K-0000000014.dcoi.xml
# Added text from WR-P-E-K-0000000014.dcoi.xml to the combined file.
# Processing file 15/778: WR-P-E-K-0000000015.dcoi.xml
# Added text from WR-P-E-K-0000000015.dcoi.xml to the combined file.
# Processing file 16/778: WR-P-E-K-0000000016.dcoi.xml
# Added text from WR-P-E-K-0000000016.dcoi.xml to the combined file.
# Processing file 17/778: WR-P-E-K-0000000017.dcoi.xml
# Added text from WR-P-E-K-0000000017.dcoi.xml to the combined file.
# Processing file 18/778: WR-P-E-K-0000000018.dcoi.xml
# Added text from WR-P-E-K-0000000018.dcoi.xml to the combined file.
# Processing file 19/778: WR-P-E-K-0000000019.dcoi.xml
# Added text from WR-P-E-K-0000000019.dcoi.xml to the combined file.
# Processing file 20/778: WR-P-E-K-0000000020.dcoi.xml
# Added text from WR-P-E-K-0000000020.dcoi.xml to the combined file.
# Processing file 21/778: WR-P-E-K-0000000021.dcoi.xml
# Added text from WR-P-E-K-0000000021.dcoi.xml to the combined file.
# Processing file 22/778: WR-P-E-K-0000000022.dcoi.xml
# Added text from WR-P-E-K-0000000022.dcoi.xml to the combined file.
# Processing file 23/778: WR-P-E-K-0000000023.dcoi.xml
# Added text from WR-P-E-K-0000000023.dcoi.xml to the combined file.
# Processing file 24/778: WR-P-E-K-0000000024.dcoi.xml
# Added text from WR-P-E-K-0000000024.dcoi.xml to the combined file.
# Processing file 25/778: WR-P-E-K-0000000025.dcoi.xml
# Added text from WR-P-E-K-0000000025.dcoi.xml to the combined file.
# Processing file 26/778: WR-P-E-K-0000000026.dcoi.xml
# Added text from WR-P-E-K-0000000026.dcoi.xml to the combined file.
# Processing file 27/778: WR-P-E-K-0000000027.dcoi.xml
# Added text from WR-P-E-K-0000000027.dcoi.xml to the combined file.
# Processing file 28/778: WR-P-E-K-0000000028.dcoi.xml
# Added text from WR-P-E-K-0000000028.dcoi.xml to the combined file.
# Processing file 29/778: WR-P-E-K-0000000029.dcoi.xml
# Added text from WR-P-E-K-0000000029.dcoi.xml to the combined file.
# Processing file 30/778: WR-P-E-K-0000000030.dcoi.xml
# Added text from WR-P-E-K-0000000030.dcoi.xml to the combined file.
# Processing file 31/778: WR-P-E-K-0000000031.dcoi.xml
# Added text from WR-P-E-K-0000000031.dcoi.xml to the combined file.
# Processing file 32/778: WR-P-E-K-0000000032.dcoi.xml
# Added text from WR-P-E-K-0000000032.dcoi.xml to the combined file.
# Processing file 33/778: WR-P-E-K-0000000033.dcoi.xml
# Added text from WR-P-E-K-0000000033.dcoi.xml to the combined file.
# Processing file 34/778: WR-P-E-K-0000000034.dcoi.xml
# Added text from WR-P-E-K-0000000034.dcoi.xml to the combined file.
# Processing file 35/778: WR-P-E-K-0000000035.dcoi.xml
# Added text from WR-P-E-K-0000000035.dcoi.xml to the combined file.
# Processing file 36/778: WR-P-E-K-0000000036.dcoi.xml
# Added text from WR-P-E-K-0000000036.dcoi.xml to the combined file.
# Processing file 37/778: WR-P-E-K-0000000037.dcoi.xml
# Added text from WR-P-E-K-0000000037.dcoi.xml to the combined file.
# Processing file 38/778: WR-P-E-K-0000000038.dcoi.xml
# Added text from WR-P-E-K-0000000038.dcoi.xml to the combined file.
# Processing file 39/778: WR-P-E-K-0000000039.dcoi.xml
# Added text from WR-P-E-K-0000000039.dcoi.xml to the combined file.
# Processing file 40/778: WR-P-E-K-0000000040.dcoi.xml
# Added text from WR-P-E-K-0000000040.dcoi.xml to the combined file.
# Processing file 41/778: WR-P-E-K-0000000041.dcoi.xml
# Added text from WR-P-E-K-0000000041.dcoi.xml to the combined file.
# Processing file 42/778: WR-P-E-K-0000000042.dcoi.xml
# Added text from WR-P-E-K-0000000042.dcoi.xml to the combined file.
# Processing file 43/778: WR-P-E-K-0000000043.dcoi.xml
# Added text from WR-P-E-K-0000000043.dcoi.xml to the combined file.
# Processing file 44/778: WR-P-E-K-0000000044.dcoi.xml
# Added text from WR-P-E-K-0000000044.dcoi.xml to the combined file.
# Processing file 45/778: WR-P-E-K-0000000045.dcoi.xml
# Added text from WR-P-E-K-0000000045.dcoi.xml to the combined file.
# Processing file 46/778: WR-P-E-K-0000000046.dcoi.xml
# Added text from WR-P-E-K-0000000046.dcoi.xml to the combined file.
# Processing file 47/778: WR-P-E-K-0000000047.dcoi.xml
# Added text from WR-P-E-K-0000000047.dcoi.xml to the combined file.
# Processing file 48/778: WR-P-E-K-0000000048.dcoi.xml
# Added text from WR-P-E-K-0000000048.dcoi.xml to the combined file.
# Processing file 49/778: WR-P-E-K-0000000049.dcoi.xml
# Added text from WR-P-E-K-0000000049.dcoi.xml to the combined file.
# Processing file 50/778: WR-P-E-K-0000000050.dcoi.xml
# Added text from WR-P-E-K-0000000050.dcoi.xml to the combined file.
# Processing file 51/778: WR-P-E-K-0000000051.dcoi.xml
# Added text from WR-P-E-K-0000000051.dcoi.xml to the combined file.
# Processing file 52/778: WR-P-E-K-0000000052.dcoi.xml
# Added text from WR-P-E-K-0000000052.dcoi.xml to the combined file.
# Processing file 53/778: WR-P-E-K-0000000053.dcoi.xml
# Added text from WR-P-E-K-0000000053.dcoi.xml to the combined file.
# Processing file 54/778: WR-P-E-K-0000000054.dcoi.xml
# Added text from WR-P-E-K-0000000054.dcoi.xml to the combined file.
# Processing file 55/778: WR-P-E-K-0000000055.dcoi.xml
# Added text from WR-P-E-K-0000000055.dcoi.xml to the combined file.
# Processing file 56/778: WR-P-E-K-0000000056.dcoi.xml
# Added text from WR-P-E-K-0000000056.dcoi.xml to the combined file.
# Processing file 57/778: WR-P-E-K-0000000057.dcoi.xml
# Added text from WR-P-E-K-0000000057.dcoi.xml to the combined file.
# Processing file 58/778: WR-P-E-K-0000000058.dcoi.xml
# Added text from WR-P-E-K-0000000058.dcoi.xml to the combined file.
# Processing file 59/778: WR-P-E-K-0000000059.dcoi.xml
# Added text from WR-P-E-K-0000000059.dcoi.xml to the combined file.
# Processing file 60/778: WR-P-E-K-0000000060.dcoi.xml
# Added text from WR-P-E-K-0000000060.dcoi.xml to the combined file.
# Processing file 61/778: WR-P-E-K-0000000061.dcoi.xml
# Added text from WR-P-E-K-0000000061.dcoi.xml to the combined file.
# Processing file 62/778: WR-P-E-K-0000000062.dcoi.xml
# Added text from WR-P-E-K-0000000062.dcoi.xml to the combined file.
# Processing file 63/778: WR-P-E-K-0000000063.dcoi.xml
# Added text from WR-P-E-K-0000000063.dcoi.xml to the combined file.
# Processing file 64/778: WR-P-E-K-0000000064.dcoi.xml
# Added text from WR-P-E-K-0000000064.dcoi.xml to the combined file.
# Processing file 65/778: WR-P-E-K-0000000065.dcoi.xml
# Added text from WR-P-E-K-0000000065.dcoi.xml to the combined file.
# Processing file 66/778: WR-P-E-K-0000000066.dcoi.xml
# Added text from WR-P-E-K-0000000066.dcoi.xml to the combined file.
# Processing file 67/778: WR-P-E-K-0000000067.dcoi.xml
# Added text from WR-P-E-K-0000000067.dcoi.xml to the combined file.
# Processing file 68/778: WR-P-E-K-0000000068.dcoi.xml
# Added text from WR-P-E-K-0000000068.dcoi.xml to the combined file.
# Processing file 69/778: WR-P-E-K-0000000069.dcoi.xml
# Added text from WR-P-E-K-0000000069.dcoi.xml to the combined file.
# Processing file 70/778: WR-P-E-K-0000000070.dcoi.xml
# Added text from WR-P-E-K-0000000070.dcoi.xml to the combined file.
# Processing file 71/778: WR-P-E-K-0000000071.dcoi.xml
# Added text from WR-P-E-K-0000000071.dcoi.xml to the combined file.
# Processing file 72/778: WR-P-E-K-0000000072.dcoi.xml
# Added text from WR-P-E-K-0000000072.dcoi.xml to the combined file.
# Processing file 73/778: WR-P-E-K-0000000073.dcoi.xml
# Added text from WR-P-E-K-0000000073.dcoi.xml to the combined file.
# Processing file 74/778: WR-P-E-K-0000000074.dcoi.xml
# Added text from WR-P-E-K-0000000074.dcoi.xml to the combined file.
# Processing file 75/778: WR-P-E-K-0000000075.dcoi.xml
# Added text from WR-P-E-K-0000000075.dcoi.xml to the combined file.
# Processing file 76/778: WR-P-E-K-0000000076.dcoi.xml
# Added text from WR-P-E-K-0000000076.dcoi.xml to the combined file.
# Processing file 77/778: WR-P-E-K-0000000077.dcoi.xml
# Added text from WR-P-E-K-0000000077.dcoi.xml to the combined file.
# Processing file 78/778: WR-P-E-K-0000000078.dcoi.xml
# Added text from WR-P-E-K-0000000078.dcoi.xml to the combined file.
# Processing file 79/778: WR-P-E-K-0000000079.dcoi.xml
# Added text from WR-P-E-K-0000000079.dcoi.xml to the combined file.
# Processing file 80/778: WR-P-E-K-0000000080.dcoi.xml
# Added text from WR-P-E-K-0000000080.dcoi.xml to the combined file.
# Processing file 81/778: WR-P-E-K-0000000081.dcoi.xml
# Added text from WR-P-E-K-0000000081.dcoi.xml to the combined file.
# Processing file 82/778: WR-P-E-K-0000000082.dcoi.xml
# Added text from WR-P-E-K-0000000082.dcoi.xml to the combined file.
# Processing file 83/778: WR-P-E-K-0000000083.dcoi.xml
# Added text from WR-P-E-K-0000000083.dcoi.xml to the combined file.
# Processing file 84/778: WR-P-E-K-0000000084.dcoi.xml
# Added text from WR-P-E-K-0000000084.dcoi.xml to the combined file.
# Processing file 85/778: WR-P-E-K-0000000085.dcoi.xml
# Added text from WR-P-E-K-0000000085.dcoi.xml to the combined file.
# Processing file 86/778: WR-P-E-K-0000000086.dcoi.xml
# Added text from WR-P-E-K-0000000086.dcoi.xml to the combined file.
# Processing file 87/778: WR-P-E-K-0000000087.dcoi.xml
# Added text from WR-P-E-K-0000000087.dcoi.xml to the combined file.
# Processing file 88/778: WR-P-E-K-0000000088.dcoi.xml
# Added text from WR-P-E-K-0000000088.dcoi.xml to the combined file.
# Processing file 89/778: WR-P-E-K-0000000089.dcoi.xml
# Added text from WR-P-E-K-0000000089.dcoi.xml to the combined file.
# Processing file 90/778: WR-P-E-K-0000000090.dcoi.xml
# Added text from WR-P-E-K-0000000090.dcoi.xml to the combined file.
# Processing file 91/778: WR-P-E-K-0000000091.dcoi.xml
# Added text from WR-P-E-K-0000000091.dcoi.xml to the combined file.
# Processing file 92/778: WR-P-E-K-0000000092.dcoi.xml
# Added text from WR-P-E-K-0000000092.dcoi.xml to the combined file.
# Processing file 93/778: WR-P-E-K-0000000093.dcoi.xml
# Added text from WR-P-E-K-0000000093.dcoi.xml to the combined file.
# Processing file 94/778: WR-P-E-K-0000000094.dcoi.xml
# Added text from WR-P-E-K-0000000094.dcoi.xml to the combined file.
# Processing file 95/778: WR-P-E-K-0000000095.dcoi.xml
# Added text from WR-P-E-K-0000000095.dcoi.xml to the combined file.
# Processing file 96/778: WR-P-E-K-0000000096.dcoi.xml
# Added text from WR-P-E-K-0000000096.dcoi.xml to the combined file.
# Processing file 97/778: WR-P-E-K-0000000097.dcoi.xml
# Added text from WR-P-E-K-0000000097.dcoi.xml to the combined file.
# Processing file 98/778: WR-P-E-K-0000000098.dcoi.xml
# Added text from WR-P-E-K-0000000098.dcoi.xml to the combined file.
# Processing file 99/778: WR-P-E-K-0000000099.dcoi.xml
# Added text from WR-P-E-K-0000000099.dcoi.xml to the combined file.
# Processing file 100/778: WR-P-E-K-0000000100.dcoi.xml
# Added text from WR-P-E-K-0000000100.dcoi.xml to the combined file.
# Processing file 101/778: WR-P-E-K-0000000101.dcoi.xml
# Added text from WR-P-E-K-0000000101.dcoi.xml to the combined file.
# Processing file 102/778: WR-P-E-K-0000000102.dcoi.xml
# Added text from WR-P-E-K-0000000102.dcoi.xml to the combined file.
# Processing file 103/778: WR-P-E-K-0000000103.dcoi.xml
# Added text from WR-P-E-K-0000000103.dcoi.xml to the combined file.
# Processing file 104/778: WR-P-E-K-0000000104.dcoi.xml
# Added text from WR-P-E-K-0000000104.dcoi.xml to the combined file.
# Processing file 105/778: WR-P-E-K-0000000105.dcoi.xml
# Added text from WR-P-E-K-0000000105.dcoi.xml to the combined file.
# Processing file 106/778: WR-P-E-K-0000000106.dcoi.xml
# Added text from WR-P-E-K-0000000106.dcoi.xml to the combined file.
# Processing file 107/778: WR-P-E-K-0000000107.dcoi.xml
# Added text from WR-P-E-K-0000000107.dcoi.xml to the combined file.
# Processing file 108/778: WR-P-E-K-0000000108.dcoi.xml
# Added text from WR-P-E-K-0000000108.dcoi.xml to the combined file.
# Processing file 109/778: WR-P-E-K-0000000109.dcoi.xml
# Added text from WR-P-E-K-0000000109.dcoi.xml to the combined file.
# Processing file 110/778: WR-P-E-K-0000000110.dcoi.xml
# Added text from WR-P-E-K-0000000110.dcoi.xml to the combined file.
# Processing file 111/778: WR-P-E-K-0000000111.dcoi.xml
# Added text from WR-P-E-K-0000000111.dcoi.xml to the combined file.
# Processing file 112/778: WR-P-E-K-0000000112.dcoi.xml
# Added text from WR-P-E-K-0000000112.dcoi.xml to the combined file.
# Processing file 113/778: WR-P-E-K-0000000113.dcoi.xml
# Added text from WR-P-E-K-0000000113.dcoi.xml to the combined file.
# Processing file 114/778: WR-P-E-K-0000000114.dcoi.xml
# Added text from WR-P-E-K-0000000114.dcoi.xml to the combined file.
# Processing file 115/778: WR-P-E-K-0000000115.dcoi.xml
# Added text from WR-P-E-K-0000000115.dcoi.xml to the combined file.
# Processing file 116/778: WR-P-E-K-0000000116.dcoi.xml
# Added text from WR-P-E-K-0000000116.dcoi.xml to the combined file.
# Processing file 117/778: WR-P-E-K-0000000117.dcoi.xml
# Added text from WR-P-E-K-0000000117.dcoi.xml to the combined file.
# Processing file 118/778: WR-P-E-K-0000000118.dcoi.xml
# Added text from WR-P-E-K-0000000118.dcoi.xml to the combined file.
# Processing file 119/778: WR-P-E-K-0000000119.dcoi.xml
# Added text from WR-P-E-K-0000000119.dcoi.xml to the combined file.
# Processing file 120/778: WR-P-E-K-0000000120.dcoi.xml
# Added text from WR-P-E-K-0000000120.dcoi.xml to the combined file.
# Processing file 121/778: WR-P-E-K-0000000121.dcoi.xml
# Added text from WR-P-E-K-0000000121.dcoi.xml to the combined file.
# Processing file 122/778: WR-P-E-K-0000000122.dcoi.xml
# Added text from WR-P-E-K-0000000122.dcoi.xml to the combined file.
# Processing file 123/778: WR-P-E-K-0000000123.dcoi.xml
# Added text from WR-P-E-K-0000000123.dcoi.xml to the combined file.
# Processing file 124/778: WR-P-E-K-0000000124.dcoi.xml
# Added text from WR-P-E-K-0000000124.dcoi.xml to the combined file.
# Processing file 125/778: WR-P-E-K-0000000125.dcoi.xml
# Added text from WR-P-E-K-0000000125.dcoi.xml to the combined file.
# Processing file 126/778: WR-P-E-K-0000000126.dcoi.xml
# Added text from WR-P-E-K-0000000126.dcoi.xml to the combined file.
# Processing file 127/778: WR-P-E-K-0000000127.dcoi.xml
# Added text from WR-P-E-K-0000000127.dcoi.xml to the combined file.
# Processing file 128/778: WR-P-E-K-0000000128.dcoi.xml
# Added text from WR-P-E-K-0000000128.dcoi.xml to the combined file.
# Processing file 129/778: WR-P-E-K-0000000129.dcoi.xml
# Added text from WR-P-E-K-0000000129.dcoi.xml to the combined file.
# Processing file 130/778: WR-P-E-K-0000000130.dcoi.xml
# Added text from WR-P-E-K-0000000130.dcoi.xml to the combined file.
# Processing file 131/778: WR-P-E-K-0000000131.dcoi.xml
# Added text from WR-P-E-K-0000000131.dcoi.xml to the combined file.
# Processing file 132/778: WR-P-E-K-0000000132.dcoi.xml
# Added text from WR-P-E-K-0000000132.dcoi.xml to the combined file.
# Processing file 133/778: WR-P-E-K-0000000133.dcoi.xml
# Added text from WR-P-E-K-0000000133.dcoi.xml to the combined file.
# Processing file 134/778: WR-P-E-K-0000000134.dcoi.xml
# Added text from WR-P-E-K-0000000134.dcoi.xml to the combined file.
# Processing file 135/778: WR-P-E-K-0000000135.dcoi.xml
# Added text from WR-P-E-K-0000000135.dcoi.xml to the combined file.
# Processing file 136/778: WR-P-E-K-0000000136.dcoi.xml
# Added text from WR-P-E-K-0000000136.dcoi.xml to the combined file.
# Processing file 137/778: WR-P-E-K-0000000137.dcoi.xml
# Added text from WR-P-E-K-0000000137.dcoi.xml to the combined file.
# Processing file 138/778: WR-P-E-K-0000000138.dcoi.xml
# Added text from WR-P-E-K-0000000138.dcoi.xml to the combined file.
# Processing file 139/778: WR-P-E-K-0000000139.dcoi.xml
# Added text from WR-P-E-K-0000000139.dcoi.xml to the combined file.
# Processing file 140/778: WR-P-E-K-0000000140.dcoi.xml
# Added text from WR-P-E-K-0000000140.dcoi.xml to the combined file.
# Processing file 141/778: WR-P-E-K-0000000141.dcoi.xml
# Added text from WR-P-E-K-0000000141.dcoi.xml to the combined file.
# Processing file 142/778: WR-P-E-K-0000000142.dcoi.xml
# Added text from WR-P-E-K-0000000142.dcoi.xml to the combined file.
# Processing file 143/778: WR-P-E-K-0000000143.dcoi.xml
# Added text from WR-P-E-K-0000000143.dcoi.xml to the combined file.
# Processing file 144/778: WR-P-E-K-0000000144.dcoi.xml
# Added text from WR-P-E-K-0000000144.dcoi.xml to the combined file.
# Processing file 145/778: WR-P-E-K-0000000145.dcoi.xml
# Added text from WR-P-E-K-0000000145.dcoi.xml to the combined file.
# Processing file 146/778: WR-P-E-K-0000000146.dcoi.xml
# Added text from WR-P-E-K-0000000146.dcoi.xml to the combined file.
# Processing file 147/778: WR-P-E-K-0000000147.dcoi.xml
# Added text from WR-P-E-K-0000000147.dcoi.xml to the combined file.
# Processing file 148/778: WR-P-E-K-0000000148.dcoi.xml
# Added text from WR-P-E-K-0000000148.dcoi.xml to the combined file.
# Processing file 149/778: WR-P-E-K-0000000149.dcoi.xml
# Added text from WR-P-E-K-0000000149.dcoi.xml to the combined file.
# Processing file 150/778: WR-P-E-K-0000000150.dcoi.xml
# Added text from WR-P-E-K-0000000150.dcoi.xml to the combined file.
# Processing file 151/778: WR-P-E-K-0000000151.dcoi.xml
# Added text from WR-P-E-K-0000000151.dcoi.xml to the combined file.
# Processing file 152/778: WR-P-E-K-0000000152.dcoi.xml
# Added text from WR-P-E-K-0000000152.dcoi.xml to the combined file.
# Processing file 153/778: WR-P-E-K-0000000153.dcoi.xml
# Added text from WR-P-E-K-0000000153.dcoi.xml to the combined file.
# Processing file 154/778: WR-P-E-K-0000000154.dcoi.xml
# Added text from WR-P-E-K-0000000154.dcoi.xml to the combined file.
# Processing file 155/778: WR-P-E-K-0000000155.dcoi.xml
# Added text from WR-P-E-K-0000000155.dcoi.xml to the combined file.
# Processing file 156/778: WR-P-E-K-0000000156.dcoi.xml
# Added text from WR-P-E-K-0000000156.dcoi.xml to the combined file.
# Processing file 157/778: WR-P-E-K-0000000157.dcoi.xml
# Added text from WR-P-E-K-0000000157.dcoi.xml to the combined file.
# Processing file 158/778: WR-P-E-K-0000000158.dcoi.xml
# Added text from WR-P-E-K-0000000158.dcoi.xml to the combined file.
# Processing file 159/778: WR-P-E-K-0000000159.dcoi.xml
# Added text from WR-P-E-K-0000000159.dcoi.xml to the combined file.
# Processing file 160/778: WR-P-E-K-0000000160.dcoi.xml
# Added text from WR-P-E-K-0000000160.dcoi.xml to the combined file.
# Processing file 161/778: WR-P-E-K-0000000161.dcoi.xml
# Added text from WR-P-E-K-0000000161.dcoi.xml to the combined file.
# Processing file 162/778: WR-P-E-K-0000000162.dcoi.xml
# Added text from WR-P-E-K-0000000162.dcoi.xml to the combined file.
# Processing file 163/778: WR-P-E-K-0000000163.dcoi.xml
# Added text from WR-P-E-K-0000000163.dcoi.xml to the combined file.
# Processing file 164/778: WR-P-E-K-0000000164.dcoi.xml
# Added text from WR-P-E-K-0000000164.dcoi.xml to the combined file.
# Processing file 165/778: WR-P-E-K-0000000165.dcoi.xml
# Added text from WR-P-E-K-0000000165.dcoi.xml to the combined file.
# Processing file 166/778: WR-P-E-K-0000000166.dcoi.xml
# Added text from WR-P-E-K-0000000166.dcoi.xml to the combined file.
# Processing file 167/778: WR-P-E-K-0000000167.dcoi.xml
# Added text from WR-P-E-K-0000000167.dcoi.xml to the combined file.
# Processing file 168/778: WR-P-E-K-0000000168.dcoi.xml
# Added text from WR-P-E-K-0000000168.dcoi.xml to the combined file.
# Processing file 169/778: WR-P-E-K-0000000169.dcoi.xml
# Added text from WR-P-E-K-0000000169.dcoi.xml to the combined file.
# Processing file 170/778: WR-P-E-K-0000000170.dcoi.xml
# Added text from WR-P-E-K-0000000170.dcoi.xml to the combined file.
# Processing file 171/778: WR-P-E-K-0000000171.dcoi.xml
# Added text from WR-P-E-K-0000000171.dcoi.xml to the combined file.
# Processing file 172/778: WR-P-E-K-0000000172.dcoi.xml
# Added text from WR-P-E-K-0000000172.dcoi.xml to the combined file.
# Processing file 173/778: WR-P-E-K-0000000173.dcoi.xml
# Added text from WR-P-E-K-0000000173.dcoi.xml to the combined file.
# Processing file 174/778: WR-P-E-K-0000000174.dcoi.xml
# Added text from WR-P-E-K-0000000174.dcoi.xml to the combined file.
# Processing file 175/778: WR-P-E-K-0000000175.dcoi.xml
# Added text from WR-P-E-K-0000000175.dcoi.xml to the combined file.
# Processing file 176/778: WR-P-E-K-0000000176.dcoi.xml
# Added text from WR-P-E-K-0000000176.dcoi.xml to the combined file.
# Processing file 177/778: WR-P-E-K-0000000177.dcoi.xml
# Added text from WR-P-E-K-0000000177.dcoi.xml to the combined file.
# Processing file 178/778: WR-P-E-K-0000000178.dcoi.xml
# Added text from WR-P-E-K-0000000178.dcoi.xml to the combined file.
# Processing file 179/778: WR-P-E-K-0000000179.dcoi.xml
# Added text from WR-P-E-K-0000000179.dcoi.xml to the combined file.
# Processing file 180/778: WR-P-E-K-0000000180.dcoi.xml
# Added text from WR-P-E-K-0000000180.dcoi.xml to the combined file.
# Processing file 181/778: WR-P-E-K-0000000181.dcoi.xml
# Added text from WR-P-E-K-0000000181.dcoi.xml to the combined file.
# Processing file 182/778: WR-P-E-K-0000000182.dcoi.xml
# Added text from WR-P-E-K-0000000182.dcoi.xml to the combined file.
# Processing file 183/778: WR-P-E-K-0000000183.dcoi.xml
# Added text from WR-P-E-K-0000000183.dcoi.xml to the combined file.
# Processing file 184/778: WR-P-E-K-0000000184.dcoi.xml
# Added text from WR-P-E-K-0000000184.dcoi.xml to the combined file.
# Processing file 185/778: WR-P-E-K-0000000185.dcoi.xml
# Added text from WR-P-E-K-0000000185.dcoi.xml to the combined file.
# Processing file 186/778: WR-P-E-K-0000000186.dcoi.xml
# Added text from WR-P-E-K-0000000186.dcoi.xml to the combined file.
# Processing file 187/778: WR-P-E-K-0000000187.dcoi.xml
# Added text from WR-P-E-K-0000000187.dcoi.xml to the combined file.
# Processing file 188/778: WR-P-E-K-0000000188.dcoi.xml
# Added text from WR-P-E-K-0000000188.dcoi.xml to the combined file.
# Processing file 189/778: WR-P-E-K-0000000189.dcoi.xml
# Added text from WR-P-E-K-0000000189.dcoi.xml to the combined file.
# Processing file 190/778: WR-P-E-K-0000000190.dcoi.xml
# Added text from WR-P-E-K-0000000190.dcoi.xml to the combined file.
# Processing file 191/778: WR-P-E-K-0000000191.dcoi.xml
# Added text from WR-P-E-K-0000000191.dcoi.xml to the combined file.
# Processing file 192/778: WR-P-E-K-0000000192.dcoi.xml
# Added text from WR-P-E-K-0000000192.dcoi.xml to the combined file.
# Processing file 193/778: WR-P-E-K-0000000193.dcoi.xml
# Added text from WR-P-E-K-0000000193.dcoi.xml to the combined file.
# Processing file 194/778: WR-P-E-K-0000000194.dcoi.xml
# Added text from WR-P-E-K-0000000194.dcoi.xml to the combined file.
# Processing file 195/778: WR-P-E-K-0000000195.dcoi.xml
# Added text from WR-P-E-K-0000000195.dcoi.xml to the combined file.
# Processing file 196/778: WR-P-E-K-0000000196.dcoi.xml
# Added text from WR-P-E-K-0000000196.dcoi.xml to the combined file.
# Processing file 197/778: WR-P-E-K-0000000197.dcoi.xml
# Added text from WR-P-E-K-0000000197.dcoi.xml to the combined file.
# Processing file 198/778: WR-P-E-K-0000000198.dcoi.xml
# Added text from WR-P-E-K-0000000198.dcoi.xml to the combined file.
# Processing file 199/778: WR-P-E-K-0000000199.dcoi.xml
# Added text from WR-P-E-K-0000000199.dcoi.xml to the combined file.
# Processing file 200/778: WR-P-E-K-0000000200.dcoi.xml
# Added text from WR-P-E-K-0000000200.dcoi.xml to the combined file.
# Processing file 201/778: WR-P-E-K-0000000201.dcoi.xml
# Added text from WR-P-E-K-0000000201.dcoi.xml to the combined file.
# Processing file 202/778: WR-P-E-K-0000000202.dcoi.xml
# Added text from WR-P-E-K-0000000202.dcoi.xml to the combined file.
# Processing file 203/778: WR-P-E-K-0000000203.dcoi.xml
# Added text from WR-P-E-K-0000000203.dcoi.xml to the combined file.
# Processing file 204/778: WR-P-E-K-0000000204.dcoi.xml
# Added text from WR-P-E-K-0000000204.dcoi.xml to the combined file.
# Processing file 205/778: WR-P-E-K-0000000205.dcoi.xml
# Added text from WR-P-E-K-0000000205.dcoi.xml to the combined file.
# Processing file 206/778: WR-P-E-K-0000000206.dcoi.xml
# Added text from WR-P-E-K-0000000206.dcoi.xml to the combined file.
# Processing file 207/778: WR-P-E-K-0000000207.dcoi.xml
# Added text from WR-P-E-K-0000000207.dcoi.xml to the combined file.
# Processing file 208/778: WR-P-E-K-0000000208.dcoi.xml
# Added text from WR-P-E-K-0000000208.dcoi.xml to the combined file.
# Processing file 209/778: WR-P-E-K-0000000209.dcoi.xml
# Added text from WR-P-E-K-0000000209.dcoi.xml to the combined file.
# Processing file 210/778: WR-P-E-K-0000000210.dcoi.xml
# Added text from WR-P-E-K-0000000210.dcoi.xml to the combined file.
# Processing file 211/778: WR-P-E-K-0000000211.dcoi.xml
# Added text from WR-P-E-K-0000000211.dcoi.xml to the combined file.
# Processing file 212/778: WR-P-E-K-0000000212.dcoi.xml
# Added text from WR-P-E-K-0000000212.dcoi.xml to the combined file.
# Processing file 213/778: WR-P-E-K-0000000213.dcoi.xml
# Added text from WR-P-E-K-0000000213.dcoi.xml to the combined file.
# Processing file 214/778: WR-P-E-K-0000000214.dcoi.xml
# Added text from WR-P-E-K-0000000214.dcoi.xml to the combined file.
# Processing file 215/778: WR-P-E-K-0000000215.dcoi.xml
# Added text from WR-P-E-K-0000000215.dcoi.xml to the combined file.
# Processing file 216/778: WR-P-E-K-0000000216.dcoi.xml
# Added text from WR-P-E-K-0000000216.dcoi.xml to the combined file.
# Processing file 217/778: WR-P-E-K-0000000217.dcoi.xml
# Added text from WR-P-E-K-0000000217.dcoi.xml to the combined file.
# Processing file 218/778: WR-P-E-K-0000000218.dcoi.xml
# Added text from WR-P-E-K-0000000218.dcoi.xml to the combined file.
# Processing file 219/778: WR-P-E-K-0000000219.dcoi.xml
# Added text from WR-P-E-K-0000000219.dcoi.xml to the combined file.
# Processing file 220/778: WR-P-E-K-0000000220.dcoi.xml
# Added text from WR-P-E-K-0000000220.dcoi.xml to the combined file.
# Processing file 221/778: WR-P-E-K-0000000221.dcoi.xml
# Added text from WR-P-E-K-0000000221.dcoi.xml to the combined file.
# Processing file 222/778: WR-P-E-K-0000000222.dcoi.xml
# Added text from WR-P-E-K-0000000222.dcoi.xml to the combined file.
# Processing file 223/778: WR-P-E-K-0000000223.dcoi.xml
# Added text from WR-P-E-K-0000000223.dcoi.xml to the combined file.
# Processing file 224/778: WR-P-E-K-0000000224.dcoi.xml
# Added text from WR-P-E-K-0000000224.dcoi.xml to the combined file.
# Processing file 225/778: WR-P-E-K-0000000225.dcoi.xml
# Added text from WR-P-E-K-0000000225.dcoi.xml to the combined file.
# Processing file 226/778: WR-P-E-K-0000000226.dcoi.xml
# Added text from WR-P-E-K-0000000226.dcoi.xml to the combined file.
# Processing file 227/778: WR-P-E-K-0000000227.dcoi.xml
# Added text from WR-P-E-K-0000000227.dcoi.xml to the combined file.
# Processing file 228/778: WR-P-E-K-0000000228.dcoi.xml
# Added text from WR-P-E-K-0000000228.dcoi.xml to the combined file.
# Processing file 229/778: WR-P-E-K-0000000229.dcoi.xml
# Added text from WR-P-E-K-0000000229.dcoi.xml to the combined file.
# Processing file 230/778: WR-P-E-K-0000000230.dcoi.xml
# Added text from WR-P-E-K-0000000230.dcoi.xml to the combined file.
# Processing file 231/778: WR-P-E-K-0000000231.dcoi.xml
# Added text from WR-P-E-K-0000000231.dcoi.xml to the combined file.
# Processing file 232/778: WR-P-E-K-0000000232.dcoi.xml
# Added text from WR-P-E-K-0000000232.dcoi.xml to the combined file.
# Processing file 233/778: WR-P-E-K-0000000233.dcoi.xml
# Added text from WR-P-E-K-0000000233.dcoi.xml to the combined file.
# Processing file 234/778: WR-P-E-K-0000000234.dcoi.xml
# Added text from WR-P-E-K-0000000234.dcoi.xml to the combined file.
# Processing file 235/778: WR-P-E-K-0000000235.dcoi.xml
# Added text from WR-P-E-K-0000000235.dcoi.xml to the combined file.
# Processing file 236/778: WR-P-E-K-0000000236.dcoi.xml
# Added text from WR-P-E-K-0000000236.dcoi.xml to the combined file.
# Processing file 237/778: WR-P-E-K-0000000237.dcoi.xml
# Added text from WR-P-E-K-0000000237.dcoi.xml to the combined file.
# Processing file 238/778: WR-P-E-K-0000000238.dcoi.xml
# Added text from WR-P-E-K-0000000238.dcoi.xml to the combined file.
# Processing file 239/778: WR-P-E-K-0000000239.dcoi.xml
# Added text from WR-P-E-K-0000000239.dcoi.xml to the combined file.
# Processing file 240/778: WR-P-E-K-0000000240.dcoi.xml
# Added text from WR-P-E-K-0000000240.dcoi.xml to the combined file.
# Processing file 241/778: WR-P-E-K-0000000241.dcoi.xml
# Added text from WR-P-E-K-0000000241.dcoi.xml to the combined file.
# Processing file 242/778: WR-P-E-K-0000000242.dcoi.xml
# Added text from WR-P-E-K-0000000242.dcoi.xml to the combined file.
# Processing file 243/778: WR-P-E-K-0000000243.dcoi.xml
# Added text from WR-P-E-K-0000000243.dcoi.xml to the combined file.
# Processing file 244/778: WR-P-E-K-0000000244.dcoi.xml
# Added text from WR-P-E-K-0000000244.dcoi.xml to the combined file.
# Processing file 245/778: WR-P-E-K-0000000245.dcoi.xml
# Added text from WR-P-E-K-0000000245.dcoi.xml to the combined file.
# Processing file 246/778: WR-P-E-K-0000000246.dcoi.xml
# Added text from WR-P-E-K-0000000246.dcoi.xml to the combined file.
# Processing file 247/778: WR-P-E-K-0000000247.dcoi.xml
# Added text from WR-P-E-K-0000000247.dcoi.xml to the combined file.
# Processing file 248/778: WR-P-E-K-0000000248.dcoi.xml
# Added text from WR-P-E-K-0000000248.dcoi.xml to the combined file.
# Processing file 249/778: WR-P-E-K-0000000249.dcoi.xml
# Added text from WR-P-E-K-0000000249.dcoi.xml to the combined file.
# Processing file 250/778: WR-P-E-K-0000000250.dcoi.xml
# Added text from WR-P-E-K-0000000250.dcoi.xml to the combined file.
# Processing file 251/778: WR-P-E-K-0000000251.dcoi.xml
# Added text from WR-P-E-K-0000000251.dcoi.xml to the combined file.
# Processing file 252/778: WR-P-E-K-0000000252.dcoi.xml
# Added text from WR-P-E-K-0000000252.dcoi.xml to the combined file.
# Processing file 253/778: WR-P-E-K-0000000253.dcoi.xml
# Added text from WR-P-E-K-0000000253.dcoi.xml to the combined file.
# Processing file 254/778: WR-P-E-K-0000000254.dcoi.xml
# Added text from WR-P-E-K-0000000254.dcoi.xml to the combined file.
# Processing file 255/778: WR-P-E-K-0000000255.dcoi.xml
# Added text from WR-P-E-K-0000000255.dcoi.xml to the combined file.
# Processing file 256/778: WR-P-E-K-0000000256.dcoi.xml
# Added text from WR-P-E-K-0000000256.dcoi.xml to the combined file.
# Processing file 257/778: WR-P-E-K-0000000257.dcoi.xml
# Added text from WR-P-E-K-0000000257.dcoi.xml to the combined file.
# Processing file 258/778: WR-P-E-K-0000000258.dcoi.xml
# Added text from WR-P-E-K-0000000258.dcoi.xml to the combined file.
# Processing file 259/778: WR-P-E-K-0000000259.dcoi.xml
# Added text from WR-P-E-K-0000000259.dcoi.xml to the combined file.
# Processing file 260/778: WR-P-E-K-0000000260.dcoi.xml
# Added text from WR-P-E-K-0000000260.dcoi.xml to the combined file.
# Processing file 261/778: WR-P-E-K-0000000261.dcoi.xml
# Added text from WR-P-E-K-0000000261.dcoi.xml to the combined file.
# Processing file 262/778: WR-P-E-K-0000000262.dcoi.xml
# Added text from WR-P-E-K-0000000262.dcoi.xml to the combined file.
# Processing file 263/778: WR-P-E-K-0000000263.dcoi.xml
# Added text from WR-P-E-K-0000000263.dcoi.xml to the combined file.
# Processing file 264/778: WR-P-E-K-0000000264.dcoi.xml
# Added text from WR-P-E-K-0000000264.dcoi.xml to the combined file.
# Processing file 265/778: WR-P-E-K-0000000265.dcoi.xml
# Added text from WR-P-E-K-0000000265.dcoi.xml to the combined file.
# Processing file 266/778: WR-P-E-K-0000000266.dcoi.xml
# Added text from WR-P-E-K-0000000266.dcoi.xml to the combined file.
# Processing file 267/778: WR-P-E-K-0000000267.dcoi.xml
# Added text from WR-P-E-K-0000000267.dcoi.xml to the combined file.
# Processing file 268/778: WR-P-E-K-0000000268.dcoi.xml
# Added text from WR-P-E-K-0000000268.dcoi.xml to the combined file.
# Processing file 269/778: WR-P-E-K-0000000269.dcoi.xml
# Added text from WR-P-E-K-0000000269.dcoi.xml to the combined file.
# Processing file 270/778: WR-P-E-K-0000000270.dcoi.xml
# Added text from WR-P-E-K-0000000270.dcoi.xml to the combined file.
# Processing file 271/778: WR-P-E-K-0000000271.dcoi.xml
# Added text from WR-P-E-K-0000000271.dcoi.xml to the combined file.
# Processing file 272/778: WR-P-E-K-0000000272.dcoi.xml
# Added text from WR-P-E-K-0000000272.dcoi.xml to the combined file.
# Processing file 273/778: WR-P-E-K-0000000273.dcoi.xml
# Added text from WR-P-E-K-0000000273.dcoi.xml to the combined file.
# Processing file 274/778: WR-P-E-K-0000000274.dcoi.xml
# Added text from WR-P-E-K-0000000274.dcoi.xml to the combined file.
# Processing file 275/778: WR-P-E-K-0000000275.dcoi.xml
# Added text from WR-P-E-K-0000000275.dcoi.xml to the combined file.
# Processing file 276/778: WR-P-E-K-0000000276.dcoi.xml
# Added text from WR-P-E-K-0000000276.dcoi.xml to the combined file.
# Processing file 277/778: WR-P-E-K-0000000277.dcoi.xml
# Added text from WR-P-E-K-0000000277.dcoi.xml to the combined file.
# Processing file 278/778: WR-P-E-K-0000000278.dcoi.xml
# Added text from WR-P-E-K-0000000278.dcoi.xml to the combined file.
# Processing file 279/778: WR-P-E-K-0000000279.dcoi.xml
# Added text from WR-P-E-K-0000000279.dcoi.xml to the combined file.
# Processing file 280/778: WR-P-E-K-0000000280.dcoi.xml
# Added text from WR-P-E-K-0000000280.dcoi.xml to the combined file.
# Processing file 281/778: WR-P-E-K-0000000281.dcoi.xml
# Added text from WR-P-E-K-0000000281.dcoi.xml to the combined file.
# Processing file 282/778: WR-P-E-K-0000000282.dcoi.xml
# Added text from WR-P-E-K-0000000282.dcoi.xml to the combined file.
# Processing file 283/778: WR-P-E-K-0000000283.dcoi.xml
# Added text from WR-P-E-K-0000000283.dcoi.xml to the combined file.
# Processing file 284/778: WR-P-E-K-0000000284.dcoi.xml
# Added text from WR-P-E-K-0000000284.dcoi.xml to the combined file.
# Processing file 285/778: WR-P-E-K-0000000285.dcoi.xml
# Added text from WR-P-E-K-0000000285.dcoi.xml to the combined file.
# Processing file 286/778: WR-P-E-K-0000000286.dcoi.xml
# Added text from WR-P-E-K-0000000286.dcoi.xml to the combined file.
# Processing file 287/778: WR-P-E-K-0000000287.dcoi.xml
# Added text from WR-P-E-K-0000000287.dcoi.xml to the combined file.
# Processing file 288/778: WR-P-E-K-0000000288.dcoi.xml
# Added text from WR-P-E-K-0000000288.dcoi.xml to the combined file.
# Processing file 289/778: WR-P-E-K-0000000289.dcoi.xml
# Added text from WR-P-E-K-0000000289.dcoi.xml to the combined file.
# Processing file 290/778: WR-P-E-K-0000000290.dcoi.xml
# Added text from WR-P-E-K-0000000290.dcoi.xml to the combined file.
# Processing file 291/778: WR-P-E-K-0000000291.dcoi.xml
# Added text from WR-P-E-K-0000000291.dcoi.xml to the combined file.
# Processing file 292/778: WR-P-E-K-0000000292.dcoi.xml
# Added text from WR-P-E-K-0000000292.dcoi.xml to the combined file.
# Processing file 293/778: WR-P-E-K-0000000293.dcoi.xml
# Added text from WR-P-E-K-0000000293.dcoi.xml to the combined file.
# Processing file 294/778: WR-P-E-K-0000000294.dcoi.xml
# Added text from WR-P-E-K-0000000294.dcoi.xml to the combined file.
# Processing file 295/778: WR-P-E-K-0000000295.dcoi.xml
# Added text from WR-P-E-K-0000000295.dcoi.xml to the combined file.
# Processing file 296/778: WR-P-E-K-0000000296.dcoi.xml
# Added text from WR-P-E-K-0000000296.dcoi.xml to the combined file.
# Processing file 297/778: WR-P-E-K-0000000297.dcoi.xml
# Added text from WR-P-E-K-0000000297.dcoi.xml to the combined file.
# Processing file 298/778: WR-P-E-K-0000000298.dcoi.xml
# Added text from WR-P-E-K-0000000298.dcoi.xml to the combined file.
# Processing file 299/778: WR-P-E-K-0000000299.dcoi.xml
# Added text from WR-P-E-K-0000000299.dcoi.xml to the combined file.
# Processing file 300/778: WR-P-E-K-0000000300.dcoi.xml
# Added text from WR-P-E-K-0000000300.dcoi.xml to the combined file.
# Processing file 301/778: WR-P-E-K-0000000301.dcoi.xml
# Added text from WR-P-E-K-0000000301.dcoi.xml to the combined file.
# Processing file 302/778: WR-P-E-K-0000000302.dcoi.xml
# Added text from WR-P-E-K-0000000302.dcoi.xml to the combined file.
# Processing file 303/778: WR-P-E-K-0000000303.dcoi.xml
# Added text from WR-P-E-K-0000000303.dcoi.xml to the combined file.
# Processing file 304/778: WR-P-E-K-0000000304.dcoi.xml
# Added text from WR-P-E-K-0000000304.dcoi.xml to the combined file.
# Processing file 305/778: WR-P-E-K-0000000305.dcoi.xml
# Added text from WR-P-E-K-0000000305.dcoi.xml to the combined file.
# Processing file 306/778: WR-P-E-K-0000000306.dcoi.xml
# Added text from WR-P-E-K-0000000306.dcoi.xml to the combined file.
# Processing file 307/778: WR-P-E-K-0000000307.dcoi.xml
# Added text from WR-P-E-K-0000000307.dcoi.xml to the combined file.
# Processing file 308/778: WR-P-E-K-0000000308.dcoi.xml
# Added text from WR-P-E-K-0000000308.dcoi.xml to the combined file.
# Processing file 309/778: WR-P-E-K-0000000309.dcoi.xml
# Added text from WR-P-E-K-0000000309.dcoi.xml to the combined file.
# Processing file 310/778: WR-P-E-K-0000000310.dcoi.xml
# Added text from WR-P-E-K-0000000310.dcoi.xml to the combined file.
# Processing file 311/778: WR-P-E-K-0000000311.dcoi.xml
# Added text from WR-P-E-K-0000000311.dcoi.xml to the combined file.
# Processing file 312/778: WR-P-E-K-0000000312.dcoi.xml
# Added text from WR-P-E-K-0000000312.dcoi.xml to the combined file.
# Processing file 313/778: WR-P-E-K-0000000313.dcoi.xml
# Added text from WR-P-E-K-0000000313.dcoi.xml to the combined file.
# Processing file 314/778: WR-P-E-K-0000000314.dcoi.xml
# Added text from WR-P-E-K-0000000314.dcoi.xml to the combined file.
# Processing file 315/778: WR-P-E-K-0000000315.dcoi.xml
# Added text from WR-P-E-K-0000000315.dcoi.xml to the combined file.
# Processing file 316/778: WR-P-E-K-0000000316.dcoi.xml
# Added text from WR-P-E-K-0000000316.dcoi.xml to the combined file.
# Processing file 317/778: WR-P-E-K-0000000317.dcoi.xml
# Added text from WR-P-E-K-0000000317.dcoi.xml to the combined file.
# Processing file 318/778: WR-P-E-K-0000000318.dcoi.xml
# Added text from WR-P-E-K-0000000318.dcoi.xml to the combined file.
# Processing file 319/778: WR-P-E-K-0000000319.dcoi.xml
# Added text from WR-P-E-K-0000000319.dcoi.xml to the combined file.
# Processing file 320/778: WR-P-E-K-0000000320.dcoi.xml
# Added text from WR-P-E-K-0000000320.dcoi.xml to the combined file.
# Processing file 321/778: WR-P-E-K-0000000321.dcoi.xml
# Added text from WR-P-E-K-0000000321.dcoi.xml to the combined file.
# Processing file 322/778: WR-P-E-K-0000000322.dcoi.xml
# Added text from WR-P-E-K-0000000322.dcoi.xml to the combined file.
# Processing file 323/778: WR-P-E-K-0000000323.dcoi.xml
# Added text from WR-P-E-K-0000000323.dcoi.xml to the combined file.
# Processing file 324/778: WR-P-E-K-0000000324.dcoi.xml
# Added text from WR-P-E-K-0000000324.dcoi.xml to the combined file.
# Processing file 325/778: WR-P-E-K-0000000325.dcoi.xml
# Added text from WR-P-E-K-0000000325.dcoi.xml to the combined file.
# Processing file 326/778: WR-P-E-K-0000000326.dcoi.xml
# Added text from WR-P-E-K-0000000326.dcoi.xml to the combined file.
# Processing file 327/778: WR-P-E-K-0000000327.dcoi.xml
# Added text from WR-P-E-K-0000000327.dcoi.xml to the combined file.
# Processing file 328/778: WR-P-E-K-0000000328.dcoi.xml
# Added text from WR-P-E-K-0000000328.dcoi.xml to the combined file.
# Processing file 329/778: WR-P-E-K-0000000329.dcoi.xml
# Added text from WR-P-E-K-0000000329.dcoi.xml to the combined file.
# Processing file 330/778: WR-P-E-K-0000000330.dcoi.xml
# Added text from WR-P-E-K-0000000330.dcoi.xml to the combined file.
# Processing file 331/778: WR-P-E-K-0000000331.dcoi.xml
# Added text from WR-P-E-K-0000000331.dcoi.xml to the combined file.
# Processing file 332/778: WR-P-E-K-0000000332.dcoi.xml
# Added text from WR-P-E-K-0000000332.dcoi.xml to the combined file.
# Processing file 333/778: WR-P-E-K-0000000333.dcoi.xml
# Added text from WR-P-E-K-0000000333.dcoi.xml to the combined file.
# Processing file 334/778: WR-P-E-K-0000000334.dcoi.xml
# Added text from WR-P-E-K-0000000334.dcoi.xml to the combined file.
# Processing file 335/778: WR-P-E-K-0000000335.dcoi.xml
# Added text from WR-P-E-K-0000000335.dcoi.xml to the combined file.
# Processing file 336/778: WR-P-E-K-0000000336.dcoi.xml
# Added text from WR-P-E-K-0000000336.dcoi.xml to the combined file.
# Processing file 337/778: WR-P-E-K-0000000337.dcoi.xml
# Added text from WR-P-E-K-0000000337.dcoi.xml to the combined file.
# Processing file 338/778: WR-P-E-K-0000000338.dcoi.xml
# Added text from WR-P-E-K-0000000338.dcoi.xml to the combined file.
# Processing file 339/778: WR-P-E-K-0000000339.dcoi.xml
# Added text from WR-P-E-K-0000000339.dcoi.xml to the combined file.
# Processing file 340/778: WR-P-E-K-0000000340.dcoi.xml
# Added text from WR-P-E-K-0000000340.dcoi.xml to the combined file.
# Processing file 341/778: WR-P-E-K-0000000341.dcoi.xml
# Added text from WR-P-E-K-0000000341.dcoi.xml to the combined file.
# Processing file 342/778: WR-P-E-K-0000000342.dcoi.xml
# Added text from WR-P-E-K-0000000342.dcoi.xml to the combined file.
# Processing file 343/778: WR-P-E-K-0000000343.dcoi.xml
# Added text from WR-P-E-K-0000000343.dcoi.xml to the combined file.
# Processing file 344/778: WR-P-E-K-0000000344.dcoi.xml
# Added text from WR-P-E-K-0000000344.dcoi.xml to the combined file.
# Processing file 345/778: WR-P-E-K-0000000345.dcoi.xml
# Added text from WR-P-E-K-0000000345.dcoi.xml to the combined file.
# Processing file 346/778: WR-P-E-K-0000000346.dcoi.xml
# Added text from WR-P-E-K-0000000346.dcoi.xml to the combined file.
# Processing file 347/778: WR-P-E-K-0000000347.dcoi.xml
# Added text from WR-P-E-K-0000000347.dcoi.xml to the combined file.
# Processing file 348/778: WR-P-E-K-0000000348.dcoi.xml
# Added text from WR-P-E-K-0000000348.dcoi.xml to the combined file.
# Processing file 349/778: WR-P-E-K-0000000349.dcoi.xml
# Added text from WR-P-E-K-0000000349.dcoi.xml to the combined file.
# Processing file 350/778: WR-P-E-K-0000000350.dcoi.xml
# Added text from WR-P-E-K-0000000350.dcoi.xml to the combined file.
# Processing file 351/778: WR-P-E-K-0000000351.dcoi.xml
# Added text from WR-P-E-K-0000000351.dcoi.xml to the combined file.
# Processing file 352/778: WR-P-E-K-0000000352.dcoi.xml
# Added text from WR-P-E-K-0000000352.dcoi.xml to the combined file.
# Processing file 353/778: WR-P-E-K-0000000353.dcoi.xml
# Added text from WR-P-E-K-0000000353.dcoi.xml to the combined file.
# Processing file 354/778: WR-P-E-K-0000000354.dcoi.xml
# Added text from WR-P-E-K-0000000354.dcoi.xml to the combined file.
# Processing file 355/778: WR-P-E-K-0000000355.dcoi.xml
# Added text from WR-P-E-K-0000000355.dcoi.xml to the combined file.
# Processing file 356/778: WR-P-E-K-0000000356.dcoi.xml
# Added text from WR-P-E-K-0000000356.dcoi.xml to the combined file.
# Processing file 357/778: WR-P-E-K-0000000357.dcoi.xml
# Added text from WR-P-E-K-0000000357.dcoi.xml to the combined file.
# Processing file 358/778: WR-P-E-K-0000000358.dcoi.xml
# Added text from WR-P-E-K-0000000358.dcoi.xml to the combined file.
# Processing file 359/778: WR-P-E-K-0000000359.dcoi.xml
# Added text from WR-P-E-K-0000000359.dcoi.xml to the combined file.
# Processing file 360/778: WR-P-E-K-0000000360.dcoi.xml
# Added text from WR-P-E-K-0000000360.dcoi.xml to the combined file.
# Processing file 361/778: WR-P-E-K-0000000361.dcoi.xml
# Added text from WR-P-E-K-0000000361.dcoi.xml to the combined file.
# Processing file 362/778: WR-P-E-K-0000000362.dcoi.xml
# Added text from WR-P-E-K-0000000362.dcoi.xml to the combined file.
# Processing file 363/778: WR-P-E-K-0000000363.dcoi.xml
# Added text from WR-P-E-K-0000000363.dcoi.xml to the combined file.
# Processing file 364/778: WR-P-E-K-0000000364.dcoi.xml
# Added text from WR-P-E-K-0000000364.dcoi.xml to the combined file.
# Processing file 365/778: WR-P-E-K-0000000365.dcoi.xml
# Added text from WR-P-E-K-0000000365.dcoi.xml to the combined file.
# Processing file 366/778: WR-P-E-K-0000000366.dcoi.xml
# Added text from WR-P-E-K-0000000366.dcoi.xml to the combined file.
# Processing file 367/778: WR-P-E-K-0000000367.dcoi.xml
# Added text from WR-P-E-K-0000000367.dcoi.xml to the combined file.
# Processing file 368/778: WR-P-E-K-0000000368.dcoi.xml
# Added text from WR-P-E-K-0000000368.dcoi.xml to the combined file.
# Processing file 369/778: WR-P-E-K-0000000369.dcoi.xml
# Added text from WR-P-E-K-0000000369.dcoi.xml to the combined file.
# Processing file 370/778: WR-P-E-K-0000000370.dcoi.xml
# Added text from WR-P-E-K-0000000370.dcoi.xml to the combined file.
# Processing file 371/778: WR-P-E-K-0000000371.dcoi.xml
# Added text from WR-P-E-K-0000000371.dcoi.xml to the combined file.
# Processing file 372/778: WR-P-E-K-0000000372.dcoi.xml
# Added text from WR-P-E-K-0000000372.dcoi.xml to the combined file.
# Processing file 373/778: WR-P-E-K-0000000373.dcoi.xml
# Added text from WR-P-E-K-0000000373.dcoi.xml to the combined file.
# Processing file 374/778: WR-P-E-K-0000000374.dcoi.xml
# Added text from WR-P-E-K-0000000374.dcoi.xml to the combined file.
# Processing file 375/778: WR-P-E-K-0000000375.dcoi.xml
# Added text from WR-P-E-K-0000000375.dcoi.xml to the combined file.
# Processing file 376/778: WR-P-E-K-0000000376.dcoi.xml
# Added text from WR-P-E-K-0000000376.dcoi.xml to the combined file.
# Processing file 377/778: WR-P-E-K-0000000377.dcoi.xml
# Added text from WR-P-E-K-0000000377.dcoi.xml to the combined file.
# Processing file 378/778: WR-P-E-K-0000000378.dcoi.xml
# Added text from WR-P-E-K-0000000378.dcoi.xml to the combined file.
# Processing file 379/778: WR-P-E-K-0000000379.dcoi.xml
# Added text from WR-P-E-K-0000000379.dcoi.xml to the combined file.
# Processing file 380/778: WR-P-E-K-0000000380.dcoi.xml
# Added text from WR-P-E-K-0000000380.dcoi.xml to the combined file.
# Processing file 381/778: WR-P-E-K-0000000381.dcoi.xml
# Added text from WR-P-E-K-0000000381.dcoi.xml to the combined file.
# Processing file 382/778: WR-P-E-K-0000000382.dcoi.xml
# Added text from WR-P-E-K-0000000382.dcoi.xml to the combined file.
# Processing file 383/778: WR-P-E-K-0000000383.dcoi.xml
# Added text from WR-P-E-K-0000000383.dcoi.xml to the combined file.
# Processing file 384/778: WR-P-E-K-0000000384.dcoi.xml
# Added text from WR-P-E-K-0000000384.dcoi.xml to the combined file.
# Processing file 385/778: WR-P-E-K-0000000385.dcoi.xml
# Added text from WR-P-E-K-0000000385.dcoi.xml to the combined file.
# Processing file 386/778: WR-P-E-K-0000000386.dcoi.xml
# Added text from WR-P-E-K-0000000386.dcoi.xml to the combined file.
# Processing file 387/778: WR-P-E-K-0000000387.dcoi.xml
# Added text from WR-P-E-K-0000000387.dcoi.xml to the combined file.
# Processing file 388/778: WR-P-E-K-0000000388.dcoi.xml
# Added text from WR-P-E-K-0000000388.dcoi.xml to the combined file.
# Processing file 389/778: WR-P-E-K-0000000389.dcoi.xml
# Added text from WR-P-E-K-0000000389.dcoi.xml to the combined file.
# Processing file 390/778: WR-P-E-K-0000000390.dcoi.xml
# Added text from WR-P-E-K-0000000390.dcoi.xml to the combined file.
# Processing file 391/778: WR-P-E-K-0000000391.dcoi.xml
# Added text from WR-P-E-K-0000000391.dcoi.xml to the combined file.
# Processing file 392/778: WR-P-E-K-0000000392.dcoi.xml
# Added text from WR-P-E-K-0000000392.dcoi.xml to the combined file.
# Processing file 393/778: WR-P-E-K-0000000393.dcoi.xml
# Added text from WR-P-E-K-0000000393.dcoi.xml to the combined file.
# Processing file 394/778: WR-P-E-K-0000000394.dcoi.xml
# Added text from WR-P-E-K-0000000394.dcoi.xml to the combined file.
# Processing file 395/778: WR-P-E-K-0000000395.dcoi.xml
# Added text from WR-P-E-K-0000000395.dcoi.xml to the combined file.
# Processing file 396/778: WR-P-E-K-0000000396.dcoi.xml
# Added text from WR-P-E-K-0000000396.dcoi.xml to the combined file.
# Processing file 397/778: WR-P-E-K-0000000397.dcoi.xml
# Added text from WR-P-E-K-0000000397.dcoi.xml to the combined file.
# ...
# Added text from WR-P-E-K-0000000647.dcoi.xml to the combined file.
# Processing file 648/778: WR-P-E-K-0000000648.dcoi.xml
# Added text from WR-P-E-K-0000000648.dcoi.xml to the combined file.
# Processing file 649/778: WR-P-E-K-0000000649.dcoi.xml
# Added text from WR-P-E-K-0000000649.dcoi.xml to the combined file.
# Processing file 650/778: WR-P-E-K-0000000650.dcoi.xml
# Added text from WR-P-E-K-0000000650.dcoi.xml to the combined file.
# Processing file 651/778: WR-P-E-K-0000000651.dcoi.xml
# Added text from WR-P-E-K-0000000651.dcoi.xml to the combined file.
# Processing file 652/778: WR-P-E-K-0000000652.dcoi.xml
# Added text from WR-P-E-K-0000000652.dcoi.xml to the combined file.
# Processing file 653/778: WR-P-E-K-0000000653.dcoi.xml
# Added text from WR-P-E-K-0000000653.dcoi.xml to the combined file.
# Processing file 654/778: WR-P-E-K-0000000654.dcoi.xml
# Added text from WR-P-E-K-0000000654.dcoi.xml to the combined file.
# Processing file 655/778: WR-P-E-K-0000000655.dcoi.xml
# Added text from WR-P-E-K-0000000655.dcoi.xml to the combined file.
# Processing file 656/778: WR-P-E-K-0000000656.dcoi.xml
# Added text from WR-P-E-K-0000000656.dcoi.xml to the combined file.
# Processing file 657/778: WR-P-E-K-0000000657.dcoi.xml
# Added text from WR-P-E-K-0000000657.dcoi.xml to the combined file.
# Processing file 658/778: WR-P-E-K-0000000658.dcoi.xml
# Added text from WR-P-E-K-0000000658.dcoi.xml to the combined file.
# Processing file 659/778: WR-P-E-K-0000000659.dcoi.xml
# Added text from WR-P-E-K-0000000659.dcoi.xml to the combined file.
# Processing file 660/778: WR-P-E-K-0000000660.dcoi.xml
# Added text from WR-P-E-K-0000000660.dcoi.xml to the combined file.
# Processing file 661/778: WR-P-E-K-0000000661.dcoi.xml
# Added text from WR-P-E-K-0000000661.dcoi.xml to the combined file.
# Processing file 662/778: WR-P-E-K-0000000662.dcoi.xml
# Added text from WR-P-E-K-0000000662.dcoi.xml to the combined file.
# Processing file 663/778: WR-P-E-K-0000000663.dcoi.xml
# Added text from WR-P-E-K-0000000663.dcoi.xml to the combined file.
# Processing file 664/778: WR-P-E-K-0000000664.dcoi.xml
# Added text from WR-P-E-K-0000000664.dcoi.xml to the combined file.
# Processing file 665/778: WR-P-E-K-0000000665.dcoi.xml
# Added text from WR-P-E-K-0000000665.dcoi.xml to the combined file.
# Processing file 666/778: WR-P-E-K-0000000666.dcoi.xml
# Added text from WR-P-E-K-0000000666.dcoi.xml to the combined file.
# Processing file 667/778: WR-P-E-K-0000000667.dcoi.xml
# Added text from WR-P-E-K-0000000667.dcoi.xml to the combined file.
# Processing file 668/778: WR-P-E-K-0000000668.dcoi.xml
# Added text from WR-P-E-K-0000000668.dcoi.xml to the combined file.
# Processing file 669/778: WR-P-E-K-0000000669.dcoi.xml
# Added text from WR-P-E-K-0000000669.dcoi.xml to the combined file.
# Processing file 670/778: WR-P-E-K-0000000670.dcoi.xml
# Added text from WR-P-E-K-0000000670.dcoi.xml to the combined file.
# Processing file 671/778: WR-P-E-K-0000000671.dcoi.xml
# Added text from WR-P-E-K-0000000671.dcoi.xml to the combined file.
# Processing file 672/778: WR-P-E-K-0000000672.dcoi.xml
# Added text from WR-P-E-K-0000000672.dcoi.xml to the combined file.
# Processing file 673/778: WR-P-E-K-0000000673.dcoi.xml
# Added text from WR-P-E-K-0000000673.dcoi.xml to the combined file.
# Processing file 674/778: WR-P-E-K-0000000674.dcoi.xml
# Added text from WR-P-E-K-0000000674.dcoi.xml to the combined file.
# Processing file 675/778: WR-P-E-K-0000000675.dcoi.xml
# Added text from WR-P-E-K-0000000675.dcoi.xml to the combined file.
# Processing file 676/778: WR-P-E-K-0000000676.dcoi.xml
# Added text from WR-P-E-K-0000000676.dcoi.xml to the combined file.
# Processing file 677/778: WR-P-E-K-0000000677.dcoi.xml
# Added text from WR-P-E-K-0000000677.dcoi.xml to the combined file.
# Processing file 678/778: WR-P-E-K-0000000678.dcoi.xml
# Added text from WR-P-E-K-0000000678.dcoi.xml to the combined file.
# Processing file 679/778: WR-P-E-K-0000000679.dcoi.xml
# Added text from WR-P-E-K-0000000679.dcoi.xml to the combined file.
# Processing file 680/778: WR-P-E-K-0000000680.dcoi.xml
# Added text from WR-P-E-K-0000000680.dcoi.xml to the combined file.
# Processing file 681/778: WR-P-E-K-0000000681.dcoi.xml
# Added text from WR-P-E-K-0000000681.dcoi.xml to the combined file.
# Processing file 682/778: WR-P-E-K-0000000682.dcoi.xml
# Added text from WR-P-E-K-0000000682.dcoi.xml to the combined file.
# Processing file 683/778: WR-P-E-K-0000000683.dcoi.xml
# Added text from WR-P-E-K-0000000683.dcoi.xml to the combined file.
# Processing file 684/778: WR-P-E-K-0000000684.dcoi.xml
# Added text from WR-P-E-K-0000000684.dcoi.xml to the combined file.
# Processing file 685/778: WR-P-E-K-0000000685.dcoi.xml
# Added text from WR-P-E-K-0000000685.dcoi.xml to the combined file.
# Processing file 686/778: WR-P-E-K-0000000686.dcoi.xml
# Added text from WR-P-E-K-0000000686.dcoi.xml to the combined file.
# Processing file 687/778: WR-P-E-K-0000000687.dcoi.xml
# Added text from WR-P-E-K-0000000687.dcoi.xml to the combined file.
# Processing file 688/778: WR-P-E-K-0000000688.dcoi.xml
# Added text from WR-P-E-K-0000000688.dcoi.xml to the combined file.
# Processing file 689/778: WR-P-E-K-0000000689.dcoi.xml
# Added text from WR-P-E-K-0000000689.dcoi.xml to the combined file.
# Processing file 690/778: WR-P-E-K-0000000690.dcoi.xml
# Added text from WR-P-E-K-0000000690.dcoi.xml to the combined file.
# Processing file 691/778: WR-P-E-K-0000000691.dcoi.xml
# Added text from WR-P-E-K-0000000691.dcoi.xml to the combined file.
# Processing file 692/778: WR-P-E-K-0000000692.dcoi.xml
# Added text from WR-P-E-K-0000000692.dcoi.xml to the combined file.
# Processing file 693/778: WR-P-E-K-0000000693.dcoi.xml
# Added text from WR-P-E-K-0000000693.dcoi.xml to the combined file.
# Processing file 694/778: WR-P-E-K-0000000694.dcoi.xml
# Added text from WR-P-E-K-0000000694.dcoi.xml to the combined file.
# Processing file 695/778: WR-P-E-K-0000000695.dcoi.xml
# Added text from WR-P-E-K-0000000695.dcoi.xml to the combined file.
# Processing file 696/778: WR-P-E-K-0000000696.dcoi.xml
# Added text from WR-P-E-K-0000000696.dcoi.xml to the combined file.
# Processing file 697/778: WR-P-E-K-0000000697.dcoi.xml
# Added text from WR-P-E-K-0000000697.dcoi.xml to the combined file.
# Processing file 698/778: WR-P-E-K-0000000698.dcoi.xml
# Added text from WR-P-E-K-0000000698.dcoi.xml to the combined file.
# Processing file 699/778: WR-P-E-K-0000000699.dcoi.xml
# Added text from WR-P-E-K-0000000699.dcoi.xml to the combined file.
# Processing file 700/778: WR-P-E-K-0000000700.dcoi.xml
# Added text from WR-P-E-K-0000000700.dcoi.xml to the combined file.
# Processing file 701/778: WR-P-E-K-0000000701.dcoi.xml
# Added text from WR-P-E-K-0000000701.dcoi.xml to the combined file.
# Processing file 702/778: WR-P-E-K-0000000702.dcoi.xml
# Added text from WR-P-E-K-0000000702.dcoi.xml to the combined file.
# Processing file 703/778: WR-P-E-K-0000000703.dcoi.xml
# Added text from WR-P-E-K-0000000703.dcoi.xml to the combined file.
# Processing file 704/778: WR-P-E-K-0000000704.dcoi.xml
# Added text from WR-P-E-K-0000000704.dcoi.xml to the combined file.
# Processing file 705/778: WR-P-E-K-0000000705.dcoi.xml
# Added text from WR-P-E-K-0000000705.dcoi.xml to the combined file.
# Processing file 706/778: WR-P-E-K-0000000706.dcoi.xml
# Added text from WR-P-E-K-0000000706.dcoi.xml to the combined file.
# Processing file 707/778: WR-P-E-K-0000000707.dcoi.xml
# Added text from WR-P-E-K-0000000707.dcoi.xml to the combined file.
# Processing file 708/778: WR-P-E-K-0000000708.dcoi.xml
# Added text from WR-P-E-K-0000000708.dcoi.xml to the combined file.
# Processing file 709/778: WR-P-E-K-0000000709.dcoi.xml
# Added text from WR-P-E-K-0000000709.dcoi.xml to the combined file.
# Processing file 710/778: WR-P-E-K-0000000710.dcoi.xml
# Added text from WR-P-E-K-0000000710.dcoi.xml to the combined file.
# Processing file 711/778: WR-P-E-K-0000000711.dcoi.xml
# Added text from WR-P-E-K-0000000711.dcoi.xml to the combined file.
# Processing file 712/778: WR-P-E-K-0000000712.dcoi.xml
# Added text from WR-P-E-K-0000000712.dcoi.xml to the combined file.
# Processing file 713/778: WR-P-E-K-0000000713.dcoi.xml
# Added text from WR-P-E-K-0000000713.dcoi.xml to the combined file.
# Processing file 714/778: WR-P-E-K-0000000714.dcoi.xml
# Added text from WR-P-E-K-0000000714.dcoi.xml to the combined file.
# Processing file 715/778: WR-P-E-K-0000000715.dcoi.xml
# Added text from WR-P-E-K-0000000715.dcoi.xml to the combined file.
# Processing file 716/778: WR-P-E-K-0000000716.dcoi.xml
# Added text from WR-P-E-K-0000000716.dcoi.xml to the combined file.
# Processing file 717/778: WR-P-E-K-0000000717.dcoi.xml
# Added text from WR-P-E-K-0000000717.dcoi.xml to the combined file.
# Processing file 718/778: WR-P-E-K-0000000718.dcoi.xml
# Added text from WR-P-E-K-0000000718.dcoi.xml to the combined file.
# Processing file 719/778: WR-P-E-K-0000000719.dcoi.xml
# Added text from WR-P-E-K-0000000719.dcoi.xml to the combined file.
# Processing file 720/778: WR-P-E-K-0000000720.dcoi.xml
# Added text from WR-P-E-K-0000000720.dcoi.xml to the combined file.
# Processing file 721/778: WR-P-E-K-0000000721.dcoi.xml
# Added text from WR-P-E-K-0000000721.dcoi.xml to the combined file.
# Processing file 722/778: WR-P-E-K-0000000722.dcoi.xml
# Added text from WR-P-E-K-0000000722.dcoi.xml to the combined file.
# Processing file 723/778: WR-P-E-K-0000000723.dcoi.xml
# Added text from WR-P-E-K-0000000723.dcoi.xml to the combined file.
# Processing file 724/778: WR-P-E-K-0000000724.dcoi.xml
# Added text from WR-P-E-K-0000000724.dcoi.xml to the combined file.
# Processing file 725/778: WR-P-E-K-0000000725.dcoi.xml
# Added text from WR-P-E-K-0000000725.dcoi.xml to the combined file.
# Processing file 726/778: WR-P-E-K-0000000726.dcoi.xml
# Added text from WR-P-E-K-0000000726.dcoi.xml to the combined file.
# Processing file 727/778: WR-P-E-K-0000000727.dcoi.xml
# Added text from WR-P-E-K-0000000727.dcoi.xml to the combined file.
# Processing file 728/778: WR-P-E-K-0000000728.dcoi.xml
# Added text from WR-P-E-K-0000000728.dcoi.xml to the combined file.
# Processing file 729/778: WR-P-E-K-0000000729.dcoi.xml
# Added text from WR-P-E-K-0000000729.dcoi.xml to the combined file.
# Processing file 730/778: WR-P-E-K-0000000730.dcoi.xml
# Added text from WR-P-E-K-0000000730.dcoi.xml to the combined file.
# Processing file 731/778: WR-P-E-K-0000000731.dcoi.xml
# Added text from WR-P-E-K-0000000731.dcoi.xml to the combined file.
# Processing file 732/778: WR-P-E-K-0000000732.dcoi.xml
# Added text from WR-P-E-K-0000000732.dcoi.xml to the combined file.
# Processing file 733/778: WR-P-E-K-0000000733.dcoi.xml
# Added text from WR-P-E-K-0000000733.dcoi.xml to the combined file.
# Processing file 734/778: WR-P-E-K-0000000734.dcoi.xml
# Added text from WR-P-E-K-0000000734.dcoi.xml to the combined file.
# Processing file 735/778: WR-P-E-K-0000000735.dcoi.xml
# Added text from WR-P-E-K-0000000735.dcoi.xml to the combined file.
# Processing file 736/778: WR-P-E-K-0000000736.dcoi.xml
# Added text from WR-P-E-K-0000000736.dcoi.xml to the combined file.
# Processing file 737/778: WR-P-E-K-0000000737.dcoi.xml
# Added text from WR-P-E-K-0000000737.dcoi.xml to the combined file.
# Processing file 738/778: WR-P-E-K-0000000738.dcoi.xml
# Added text from WR-P-E-K-0000000738.dcoi.xml to the combined file.
# Processing file 739/778: WR-P-E-K-0000000739.dcoi.xml
# Added text from WR-P-E-K-0000000739.dcoi.xml to the combined file.
# Processing file 740/778: WR-P-E-K-0000000740.dcoi.xml
# Added text from WR-P-E-K-0000000740.dcoi.xml to the combined file.
# Processing file 741/778: WR-P-E-K-0000000741.dcoi.xml
# Added text from WR-P-E-K-0000000741.dcoi.xml to the combined file.
# Processing file 742/778: WR-P-E-K-0000000742.dcoi.xml
# Added text from WR-P-E-K-0000000742.dcoi.xml to the combined file.
# Processing file 743/778: WR-P-E-K-0000000743.dcoi.xml
# Added text from WR-P-E-K-0000000743.dcoi.xml to the combined file.
# Processing file 744/778: WR-P-E-K-0000000744.dcoi.xml
# Added text from WR-P-E-K-0000000744.dcoi.xml to the combined file.
# Processing file 745/778: WR-P-E-K-0000000745.dcoi.xml
# Added text from WR-P-E-K-0000000745.dcoi.xml to the combined file.
# Processing file 746/778: WR-P-E-K-0000000746.dcoi.xml
# Added text from WR-P-E-K-0000000746.dcoi.xml to the combined file.
# Processing file 747/778: WR-P-E-K-0000000747.dcoi.xml
# Added text from WR-P-E-K-0000000747.dcoi.xml to the combined file.
# Processing file 748/778: WR-P-E-K-0000000748.dcoi.xml
# Added text from WR-P-E-K-0000000748.dcoi.xml to the combined file.
# Processing file 749/778: WR-P-E-K-0000000749.dcoi.xml
# Added text from WR-P-E-K-0000000749.dcoi.xml to the combined file.
# Processing file 750/778: WR-P-E-K-0000000750.dcoi.xml
# Added text from WR-P-E-K-0000000750.dcoi.xml to the combined file.
# Processing file 751/778: WR-P-E-K-0000000751.dcoi.xml
# Added text from WR-P-E-K-0000000751.dcoi.xml to the combined file.
# Processing file 752/778: WR-P-E-K-0000000752.dcoi.xml
# Added text from WR-P-E-K-0000000752.dcoi.xml to the combined file.
# Processing file 753/778: WR-P-E-K-0000000753.dcoi.xml
# Added text from WR-P-E-K-0000000753.dcoi.xml to the combined file.
# Processing file 754/778: WR-P-E-K-0000000754.dcoi.xml
# Added text from WR-P-E-K-0000000754.dcoi.xml to the combined file.
# Processing file 755/778: WR-P-E-K-0000000755.dcoi.xml
# Added text from WR-P-E-K-0000000755.dcoi.xml to the combined file.
# Processing file 756/778: WR-P-E-K-0000000756.dcoi.xml
# Added text from WR-P-E-K-0000000756.dcoi.xml to the combined file.
# Processing file 757/778: WR-P-E-K-0000000757.dcoi.xml
# Added text from WR-P-E-K-0000000757.dcoi.xml to the combined file.
# Processing file 758/778: WR-P-E-K-0000000758.dcoi.xml
# Added text from WR-P-E-K-0000000758.dcoi.xml to the combined file.
# Processing file 759/778: WR-P-E-K-0000000759.dcoi.xml
# Added text from WR-P-E-K-0000000759.dcoi.xml to the combined file.
# Processing file 760/778: WR-P-E-K-0000000760.dcoi.xml
# Added text from WR-P-E-K-0000000760.dcoi.xml to the combined file.
# Processing file 761/778: WR-P-E-K-0000000761.dcoi.xml
# Added text from WR-P-E-K-0000000761.dcoi.xml to the combined file.
# Processing file 762/778: WR-P-E-K-0000000762.dcoi.xml
# Added text from WR-P-E-K-0000000762.dcoi.xml to the combined file.
# Processing file 763/778: WR-P-E-K-0000000763.dcoi.xml
# Added text from WR-P-E-K-0000000763.dcoi.xml to the combined file.
# Processing file 764/778: WR-P-E-K-0000000764.dcoi.xml
# Added text from WR-P-E-K-0000000764.dcoi.xml to the combined file.
# Processing file 765/778: WR-P-E-K-0000000765.dcoi.xml
# Added text from WR-P-E-K-0000000765.dcoi.xml to the combined file.
# Processing file 766/778: WR-P-E-K-0000000766.dcoi.xml
# Added text from WR-P-E-K-0000000766.dcoi.xml to the combined file.
# Processing file 767/778: WR-P-E-K-0000000767.dcoi.xml
# Added text from WR-P-E-K-0000000767.dcoi.xml to the combined file.
# Processing file 768/778: WR-P-E-K-0000000768.dcoi.xml
# Added text from WR-P-E-K-0000000768.dcoi.xml to the combined file.
# Processing file 769/778: WR-P-E-K-0000000769.dcoi.xml
# Added text from WR-P-E-K-0000000769.dcoi.xml to the combined file.
# Processing file 770/778: WR-P-E-K-0000000770.dcoi.xml
# Added text from WR-P-E-K-0000000770.dcoi.xml to the combined file.
# Processing file 771/778: WR-P-E-K-0000000771.dcoi.xml
# Added text from WR-P-E-K-0000000771.dcoi.xml to the combined file.
# Processing file 772/778: WR-P-E-K-0000000772.dcoi.xml
# Added text from WR-P-E-K-0000000772.dcoi.xml to the combined file.
# Processing file 773/778: WR-P-E-K-0000000773.dcoi.xml
# Added text from WR-P-E-K-0000000773.dcoi.xml to the combined file.
# Processing file 774/778: WR-P-E-K-0000000774.dcoi.xml
# Added text from WR-P-E-K-0000000774.dcoi.xml to the combined file.
# Processing file 775/778: WR-P-E-K-0000000775.dcoi.xml
# Added text from WR-P-E-K-0000000775.dcoi.xml to the combined file.
# Processing file 776/778: WR-P-E-K-0000000776.dcoi.xml
# Added text from WR-P-E-K-0000000776.dcoi.xml to the combined file.
# Processing file 777/778: WR-P-E-K-0000000777.dcoi.xml
# Added text from WR-P-E-K-0000000777.dcoi.xml to the combined file.
# Processing file 778/778: WR-P-E-K-0000000778.dcoi.xml
# Added text from WR-P-E-K-0000000778.dcoi.xml to the combined file.
# All texts saved to a single file at ../out/blogs/combined_blogs.txt.

# %% [markdown]
# ### Counting per word

# %%
class BlobWordFrequencyAggregator:
    def __init__(self, connection_string, container_name):
        self.connection_string = connection_string
        self.container_name = container_name
        self.blob_service_client = BlobServiceClient.from_connection_string(connection_string)
        self.container_client = self.blob_service_client.get_container_client(container_name)

    def extract_word_frequencies_from_blob(self, blob_name):
        """Extract word frequencies from a single blob."""
        try:
            # Download blob content
            blob_client = self.container_client.get_blob_client(blob_name)
            blob_data = blob_client.download_blob().readall()
            
            # Parse the XML content
            tree = ET.ElementTree(ET.fromstring(blob_data.decode('iso-8859-15')))
            root = tree.getroot()
            
            # Extract words from <w> elements
            word_elements = root.findall('.//dcoi:w', {'dcoi': 'http://lands.let.ru.nl/projects/d-coi/ns/1.0'})
            words = [w.text for w in word_elements if w.text]
            
            # Return word frequencies as a Counter
            return Counter(words)
        except Exception as e:
            print(f"Error processing blob {blob_name}: {e}")
            return Counter()

    def aggregate_word_frequencies(self):
        """Aggregate word frequencies from all XML blobs in the container."""
        total_frequencies = Counter()
        
        # List all XML blobs in the container
        blobs = list(self.container_client.list_blobs())
        xml_files = [blob.name for blob in blobs if blob.name.endswith('.xml')]

        print(f"Found {len(xml_files)} XML files in container '{self.container_name}'.")

        for i, blob_name in enumerate(xml_files, start=1):
            print(f"Processing file {i}/{len(xml_files)}: {blob_name}")
            
            # Extract word frequencies from the current blob
            word_frequencies = self.extract_word_frequencies_from_blob(blob_name)
            
            # Update the total frequencies with the current blob's frequencies
            total_frequencies.update(word_frequencies)
        
        return total_frequencies

    def save_aggregated_frequencies_to_csv(self, word_frequencies, output_file):
        """Save aggregated word frequencies to a CSV file."""
        # Sort words by frequency in descending order
        sorted_frequencies = sorted(word_frequencies.items(), key=lambda item: item[1], reverse=True)
        
        with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            # Write header
            writer.writerow(['Word', 'Frequency'])
            # Write sorted word and frequency data
            for word, freq in sorted_frequencies:
                writer.writerow([word, freq])
        
        print(f"Word frequencies saved to {output_file}.")

    def get_word_frequency_from_csv(self, word, csv_file):
        """Get the frequency of a single word from the CSV file."""
        try:
            # Load the CSV file into a DataFrame
            word_frequencies = pd.read_csv(csv_file, sep=',', on_bad_lines='skip')

            # Find the frequency for the given word
            word_df = word_frequencies[word_frequencies['Word'] == word]
            
            if not word_df.empty:
                frequency = word_df['Frequency'].iloc[0]
                print(f"The word '{word}' appears {frequency} time(s) in the CSV file.")
                return frequency
            else:
                print(f"The word '{word}' does not appear in the CSV file.")
                return 0
        except Exception as e:
            print(f"Error reading CSV file {csv_file}: {e}")
            return 0

# %%
# Initialize the BlobWordFrequencyAggregator
aggregator = BlobWordFrequencyAggregator(connection_string, container_name)

# Aggregate word frequencies
#total_word_frequencies = aggregator.aggregate_word_frequencies()
#
## Save aggregated frequencies to a CSV file
#aggregator.save_aggregated_frequencies_to_csv(total_word_frequencies, output_csv_wordfrequencies)

# %%
word_to_check = "Directrice"
aggregator.get_word_frequency_from_csv(word_to_check, output_csv_wordfrequencies)
# Out:
# The word 'Directrice' appears 2 time(s) in the CSV file.
# 2

# %%
words_to_check = [
    'logistiek medewerker', 'beveiligingsmedewerker', 'directeur', 'chauffeur',
    'productieleider', 'schilder', 'vrachtwagenchauffeur', 'constructiewerker',
    'metaalbewerker', 'apothekerassistent', 'praktijkassistent', 'verzorger',
    'schoonheidsspecialist', 'kapper', 'verpleger', 'onderwijzer', 'psycholoog',
    'socioloog', 'kassamedewerker', 'maatschappelijk werker', 'boekhouder',
    'schoonmaker', 'fysiotherapeut', 'sociaal werker', 'laborant',
    'administratief medewerker', 'receptionist', 'telefonist', 'docent',
    'verkoopmedewerker', 'reisbegeleider', 'loopbaanbegeleider',
    'loopbaanadviseur', 'hr-medewerker', 'barmedewerker', 'bibliothecaris'
]

unique_words = set(word.lower() for word in words_to_check)

frequencies = {}
for word in unique_words:
    # Check both capitalized and lowercase versions
    lower_word = word.lower()
    capitalized_word = word.capitalize()

    # Get frequencies for both versions
    freq_lower = aggregator.get_word_frequency_from_csv(lower_word, output_csv_wordfrequencies)
    freq_cap = aggregator.get_word_frequency_from_csv(capitalized_word, output_csv_wordfrequencies)

    # Combine them
    total_freq = freq_lower + freq_cap
    frequencies[word] = total_freq

# order the frequencies by the word
frequencies = dict(sorted(frequencies.items(), key=lambda item: item[0]))
print(frequencies)
# Out:
# The word 'constructiewerker' does not appear in the CSV file.
# The word 'Constructiewerker' does not appear in the CSV file.
# The word 'psycholoog' appears 137 time(s) in the CSV file.
# The word 'Psycholoog' appears 1 time(s) in the CSV file.
# The word 'schoonheidsspecialist' appears 1 time(s) in the CSV file.
# The word 'Schoonheidsspecialist' does not appear in the CSV file.
# The word 'chauffeur' appears 633 time(s) in the CSV file.
# The word 'Chauffeur' does not appear in the CSV file.
# The word 'reisbegeleider' does not appear in the CSV file.
# The word 'Reisbegeleider' does not appear in the CSV file.
# The word 'logistiek medewerker' does not appear in the CSV file.
# The word 'Logistiek medewerker' does not appear in the CSV file.
# The word 'loopbaanadviseur' does not appear in the CSV file.
# The word 'Loopbaanadviseur' does not appear in the CSV file.
# The word 'bibliothecaris' appears 16 time(s) in the CSV file.
# The word 'Bibliothecaris' appears 1 time(s) in the CSV file.
# The word 'apothekerassistent' does not appear in the CSV file.
# The word 'Apothekerassistent' does not appear in the CSV file.
# The word 'telefonist' appears 4 time(s) in the CSV file.
# The word 'Telefonist' does not appear in the CSV file.
# The word 'kassamedewerker' appears 1 time(s) in the CSV file.
# The word 'Kassamedewerker' does not appear in the CSV file.
# The word 'barmedewerker' does not appear in the CSV file.
# The word 'Barmedewerker' does not appear in the CSV file.
# The word 'productieleider' does not appear in the CSV file.
# The word 'Productieleider' does not appear in the CSV file.
# The word 'onderwijzer' appears 139 time(s) in the CSV file.
# The word 'Onderwijzer' appears 1 time(s) in the CSV file.
# The word 'verpleger' appears 65 time(s) in the CSV file.
# The word 'Verpleger' does not appear in the CSV file.
# The word 'schoonmaker' appears 14 time(s) in the CSV file.
# The word 'Schoonmaker' does not appear in the CSV file.
# The word 'receptionist' appears 69 time(s) in the CSV file.
# The word 'Receptionist' does not appear in the CSV file.
# The word 'laborant' appears 2 time(s) in the CSV file.
# The word 'Laborant' does not appear in the CSV file.
# The word 'vrachtwagenchauffeur' appears 34 time(s) in the CSV file.
# The word 'Vrachtwagenchauffeur' does not appear in the CSV file.
# The word 'beveiligingsmedewerker' appears 3 time(s) in the CSV file.
# The word 'Beveiligingsmedewerker' does not appear in the CSV file.
# The word 'kapper' appears 195 time(s) in the CSV file.
# The word 'Kapper' appears 1 time(s) in the CSV file.
# The word 'boekhouder' appears 45 time(s) in the CSV file.
# The word 'Boekhouder' appears 1 time(s) in the CSV file.
# The word 'administratief medewerker' does not appear in the CSV file.
# The word 'Administratief medewerker' does not appear in the CSV file.
# The word 'praktijkassistent' does not appear in the CSV file.
# The word 'Praktijkassistent' does not appear in the CSV file.
# The word 'verzorger' appears 39 time(s) in the CSV file.
# The word 'Verzorger' does not appear in the CSV file.
# The word 'hr-medewerker' does not appear in the CSV file.
# The word 'Hr-medewerker' does not appear in the CSV file.
# The word 'metaalbewerker' appears 2 time(s) in the CSV file.
# The word 'Metaalbewerker' does not appear in the CSV file.
# The word 'loopbaanbegeleider' appears 3 time(s) in the CSV file.
# The word 'Loopbaanbegeleider' does not appear in the CSV file.
# The word 'directeur' appears 778 time(s) in the CSV file.
# The word 'Directeur' appears 23 time(s) in the CSV file.
# The word 'fysiotherapeut' appears 13 time(s) in the CSV file.
# The word 'Fysiotherapeut' appears 1 time(s) in the CSV file.
# The word 'schilder' appears 694 time(s) in the CSV file.
# The word 'Schilder' appears 14 time(s) in the CSV file.
# The word 'maatschappelijk werker' does not appear in the CSV file.
# The word 'Maatschappelijk werker' does not appear in the CSV file.
# The word 'verkoopmedewerker' does not appear in the CSV file.
# The word 'Verkoopmedewerker' does not appear in the CSV file.
# The word 'docent' appears 476 time(s) in the CSV file.
# The word 'Docent' appears 4 time(s) in the CSV file.
# The word 'sociaal werker' does not appear in the CSV file.
# The word 'Sociaal werker' does not appear in the CSV file.
# The word 'socioloog' appears 57 time(s) in the CSV file.
# The word 'Socioloog' appears 2 time(s) in the CSV file.
# {'administratief medewerker': 0, 'apothekerassistent': 0, 'barmedewerker': 0, 'beveiligingsmedewerker': 3, 'bibliothecaris': 17, 'boekhouder': 46, 'chauffeur': 633, 'constructiewerker': 0, 'directeur': 801, 'docent': 480, 'fysiotherapeut': 14, 'hr-medewerker': 0, 'kapper': 196, 'kassamedewerker': 1, 'laborant': 2, 'logistiek medewerker': 0, 'loopbaanadviseur': 0, 'loopbaanbegeleider': 3, 'maatschappelijk werker': 0, 'metaalbewerker': 2, 'onderwijzer': 140, 'praktijkassistent': 0, 'productieleider': 0, 'psycholoog': 138, 'receptionist': 69, 'reisbegeleider': 0, 'schilder': 708, 'schoonheidsspecialist': 1, 'schoonmaker': 14, 'sociaal werker': 0, 'socioloog': 59, 'telefonist': 4, 'verkoopmedewerker': 0, 'verpleger': 65, 'verzorger': 39, 'vrachtwagenchauffeur': 34}

# %%
words_to_check = [
    'logistiek medewerkster', 'beveiligingsmedewerkster', 'directrice', 'chauffeuse',
    'productieleidster', 'schilderes', 'vrachtwagenchauffeuse', 'constructiewerkster',
    'metaalbewerkster', 'apothekerassistente', 'praktijkassistente', 'verzorgster',
    'kapster', 'schoonheidsspecialiste', 'verpleegster', 'onderwijzeres', 'sociologe',
    'psychologe', 'kassière', 'maatschappelijk werkster', 'boekhoudster',
    'schoonmaakster', 'fysiotherapeute', 'sociaal werkster', 'laborante',
    'administratief medewerkster', 'receptioniste', 'telefoniste', 'docente',
    'verkoopster', 'reisbegeleidster', 'loopbaanbegeleidster', 'loopbaanadviseuse',
    'hr-medewerkster', 'barmedewerkster', 'bibliothecaresse'
]

unique_words = set(word.lower() for word in words_to_check)

frequencies = {}
for word in unique_words:
    # Check both capitalized and lowercase versions
    lower_word = word.lower()
    capitalized_word = word.capitalize()

    # Get frequencies for both versions
    freq_lower = aggregator.get_word_frequency_from_csv(lower_word, output_csv_wordfrequencies)
    freq_cap = aggregator.get_word_frequency_from_csv(capitalized_word, output_csv_wordfrequencies)

    # Combine them
    total_freq = freq_lower + freq_cap
    frequencies[word] = total_freq

# order the frequencies by the word
frequencies = dict(sorted(frequencies.items(), key=lambda item: item[0]))
print(frequencies)
# Out:
# The word 'schoonmaakster' appears 95 time(s) in the CSV file.
# The word 'Schoonmaakster' appears 2 time(s) in the CSV file.
# The word 'loopbaanbegeleidster' appears 3 time(s) in the CSV file.
# The word 'Loopbaanbegeleidster' does not appear in the CSV file.
# The word 'hr-medewerkster' does not appear in the CSV file.
# The word 'Hr-medewerkster' does not appear in the CSV file.
# The word 'loopbaanadviseuse' does not appear in the CSV file.
# The word 'Loopbaanadviseuse' does not appear in the CSV file.
# The word 'verkoopster' appears 104 time(s) in the CSV file.
# The word 'Verkoopster' appears 1 time(s) in the CSV file.
# The word 'verpleegster' appears 325 time(s) in the CSV file.
# The word 'Verpleegster' appears 3 time(s) in the CSV file.
# The word 'verzorgster' appears 15 time(s) in the CSV file.
# The word 'Verzorgster' appears 1 time(s) in the CSV file.
# The word 'apothekerassistente' does not appear in the CSV file.
# The word 'Apothekerassistente' does not appear in the CSV file.
# The word 'laborante' appears 3 time(s) in the CSV file.
# The word 'Laborante' does not appear in the CSV file.
# The word 'barmedewerkster' does not appear in the CSV file.
# The word 'Barmedewerkster' does not appear in the CSV file.
# The word 'schoonheidsspecialiste' appears 17 time(s) in the CSV file.
# The word 'Schoonheidsspecialiste' does not appear in the CSV file.
# The word 'sociaal werkster' does not appear in the CSV file.
# The word 'Sociaal werkster' does not appear in the CSV file.
# The word 'fysiotherapeute' appears 2 time(s) in the CSV file.
# The word 'Fysiotherapeute' does not appear in the CSV file.
# The word 'vrachtwagenchauffeuse' does not appear in the CSV file.
# The word 'Vrachtwagenchauffeuse' does not appear in the CSV file.
# The word 'logistiek medewerkster' does not appear in the CSV file.
# The word 'Logistiek medewerkster' does not appear in the CSV file.
# The word 'kassière' does not appear in the CSV file.
# The word 'Kassière' does not appear in the CSV file.
# The word 'receptioniste' appears 84 time(s) in the CSV file.
# The word 'Receptioniste' does not appear in the CSV file.
# The word 'boekhoudster' appears 1 time(s) in the CSV file.
# The word 'Boekhoudster' does not appear in the CSV file.
# The word 'chauffeuse' appears 2 time(s) in the CSV file.
# The word 'Chauffeuse' does not appear in the CSV file.
# The word 'psychologe' appears 26 time(s) in the CSV file.
# The word 'Psychologe' appears 3 time(s) in the CSV file.
# The word 'bibliothecaresse' appears 34 time(s) in the CSV file.
# The word 'Bibliothecaresse' does not appear in the CSV file.
# The word 'maatschappelijk werkster' does not appear in the CSV file.
# The word 'Maatschappelijk werkster' does not appear in the CSV file.
# The word 'reisbegeleidster' does not appear in the CSV file.
# The word 'Reisbegeleidster' does not appear in the CSV file.
# The word 'beveiligingsmedewerkster' does not appear in the CSV file.
# The word 'Beveiligingsmedewerkster' does not appear in the CSV file.
# The word 'metaalbewerkster' does not appear in the CSV file.
# The word 'Metaalbewerkster' does not appear in the CSV file.
# The word 'constructiewerkster' does not appear in the CSV file.
# The word 'Constructiewerkster' does not appear in the CSV file.
# The word 'schilderes' appears 46 time(s) in the CSV file.
# The word 'Schilderes' does not appear in the CSV file.
# The word 'kapster' appears 27 time(s) in the CSV file.
# The word 'Kapster' appears 1 time(s) in the CSV file.
# The word 'praktijkassistente' does not appear in the CSV file.
# The word 'Praktijkassistente' does not appear in the CSV file.
# The word 'administratief medewerkster' does not appear in the CSV file.
# The word 'Administratief medewerkster' does not appear in the CSV file.
# The word 'sociologe' appears 4 time(s) in the CSV file.
# The word 'Sociologe' appears 1 time(s) in the CSV file.
# The word 'docente' appears 38 time(s) in the CSV file.
# The word 'Docente' does not appear in the CSV file.
# The word 'directrice' appears 102 time(s) in the CSV file.
# The word 'Directrice' appears 2 time(s) in the CSV file.
# The word 'telefoniste' appears 36 time(s) in the CSV file.
# The word 'Telefoniste' does not appear in the CSV file.
# The word 'onderwijzeres' appears 57 time(s) in the CSV file.
# The word 'Onderwijzeres' appears 1 time(s) in the CSV file.
# The word 'productieleidster' does not appear in the CSV file.
# The word 'Productieleidster' does not appear in the CSV file.
# {'administratief medewerkster': 0, 'apothekerassistente': 0, 'barmedewerkster': 0, 'beveiligingsmedewerkster': 0, 'bibliothecaresse': 34, 'boekhoudster': 1, 'chauffeuse': 2, 'constructiewerkster': 0, 'directrice': 104, 'docente': 38, 'fysiotherapeute': 2, 'hr-medewerkster': 0, 'kapster': 28, 'kassière': 0, 'laborante': 3, 'logistiek medewerkster': 0, 'loopbaanadviseuse': 0, 'loopbaanbegeleidster': 3, 'maatschappelijk werkster': 0, 'metaalbewerkster': 0, 'onderwijzeres': 58, 'praktijkassistente': 0, 'productieleidster': 0, 'psychologe': 29, 'receptioniste': 84, 'reisbegeleidster': 0, 'schilderes': 46, 'schoonheidsspecialiste': 17, 'schoonmaakster': 97, 'sociaal werkster': 0, 'sociologe': 5, 'telefoniste': 36, 'verkoopster': 105, 'verpleegster': 328, 'verzorgster': 16, 'vrachtwagenchauffeuse': 0}

# %%
words_to_check = ['landbouwer', 'bosbouwer', 'ambtenaar', 'arts', 'taalkundige',
 'auteur', 'onderwijskundige', 'procesoperator', 'metaalspuiter',
 'monteur', 'loodgieter', 'elektricien', 'lasser', 'dekofficier', 'officier',
 'bouwarbeider', "ict'er", 'technicus', 'manager', 'ingenieur',
 'transportplanner', 'militair', 'hovenier', 'softwareontwikkelaar', 'tuinder',
 'applicatieontwikkelaar', 'kweker', 'boekhoudkundige', 'verzorgende', 'bedrijfskundige',
 'leerkracht', 'verpleegkundige', 'secretaresse', 'econoom', 'accountant', 'slager', 'controleur',
 'majoor', 'generaal', 'kapitein', 'luitenant', 'sergeant', 'korporaal', 'soldaat', 'inkoper',
 'hulpkracht'
 ]

#words_to_check = ['bouwer', 'pilote', 'ontwikkelster', 'conservatrice', 'journaliste', 'bestuurster',
#                  'biologe', 'architecte', 'inkoopster'
#                  ]
words_to_check = ['bestuurster']
unique_words = set(word.lower() for word in words_to_check)

frequencies = {}
for word in unique_words:
    # Check both capitalized and lowercase versions
    lower_word = word.lower()
    capitalized_word = word.capitalize()

    # Get frequencies for both versions
    freq_lower = aggregator.get_word_frequency_from_csv(lower_word, output_csv_wordfrequencies)
    freq_cap = aggregator.get_word_frequency_from_csv(capitalized_word, output_csv_wordfrequencies)

    # Combine them
    total_freq = freq_lower + freq_cap
    frequencies[word] = total_freq

# order the frequencies by the word
frequencies = dict(sorted(frequencies.items(), key=lambda item: item[0]))
print(frequencies)
# Out:
# The word 'bestuurster' appears 1 time(s) in the CSV file.
# The word 'Bestuurster' does not appear in the CSV file.
# {'bestuurster': 1}

# %%
words_to_check = [
    "voetballer", "voetbalster", "acteur", "actrice", "zanger", "zangeres",
    "schrijver", "schrijfster", "kunstenaar", "kunstenares", "ondernemer", "onderneemster",
]

unique_words = set(word.lower() for word in words_to_check)

frequencies = {}
for word in unique_words:
    # Check both capitalized and lowercase versions
    lower_word = word.lower()
    capitalized_word = word.capitalize()

    # Get frequencies for both versions
    freq_lower = aggregator.get_word_frequency_from_csv(lower_word, output_csv_wordfrequencies)
    freq_cap = aggregator.get_word_frequency_from_csv(capitalized_word, output_csv_wordfrequencies)

    # Combine them
    total_freq = freq_lower + freq_cap
    frequencies[word] = total_freq

# order the frequencies by the word
frequencies = dict(sorted(frequencies.items(), key=lambda item: item[0]))
print(frequencies)
# Out:
# The word 'voetbalster' appears 1 time(s) in the CSV file.
# The word 'Voetbalster' does not appear in the CSV file.
# The word 'onderneemster' appears 3 time(s) in the CSV file.
# The word 'Onderneemster' does not appear in the CSV file.
# The word 'zanger' appears 128 time(s) in the CSV file.
# The word 'Zanger' appears 1 time(s) in the CSV file.
# The word 'acteur' appears 165 time(s) in the CSV file.
# The word 'Acteur' appears 1 time(s) in the CSV file.
# The word 'zangeres' appears 96 time(s) in the CSV file.
# The word 'Zangeres' appears 1 time(s) in the CSV file.
# The word 'ondernemer' appears 89 time(s) in the CSV file.
# The word 'Ondernemer' appears 1 time(s) in the CSV file.
# The word 'kunstenaar' appears 796 time(s) in the CSV file.
# The word 'Kunstenaar' appears 5 time(s) in the CSV file.
# The word 'schrijver' appears 1812 time(s) in the CSV file.
# The word 'Schrijver' appears 69 time(s) in the CSV file.
# The word 'schrijfster' appears 274 time(s) in the CSV file.
# The word 'Schrijfster' appears 3 time(s) in the CSV file.
# The word 'kunstenares' appears 59 time(s) in the CSV file.
# The word 'Kunstenares' does not appear in the CSV file.
# The word 'actrice' appears 161 time(s) in the CSV file.
# The word 'Actrice' does not appear in the CSV file.
# The word 'voetballer' appears 36 time(s) in the CSV file.
# The word 'Voetballer' does not appear in the CSV file.
# {'acteur': 166, 'actrice': 161, 'kunstenaar': 801, 'kunstenares': 59, 'onderneemster': 3, 'ondernemer': 90, 'schrijfster': 277, 'schrijver': 1881, 'voetballer': 36, 'voetbalster': 1, 'zanger': 129, 'zangeres': 97}

# %% [markdown]
# ### File locator word a specific word

# %%
class BlobWordSearcher:
    def __init__(self, connection_string, container_name):
        self.connection_string = connection_string
        self.container_name = container_name
        self.blob_service_client = BlobServiceClient.from_connection_string(connection_string)
        self.container_client = self.blob_service_client.get_container_client(container_name)

    def find_blobs_with_word(self, target_word):
        """Find blobs in the container that contain the target word."""
        matching_blobs = []
        
        # List all XML blobs in the container
        blobs = list(self.container_client.list_blobs())
        xml_files = [blob.name for blob in blobs if blob.name.endswith('.xml')]

        print(f"Searching for the word '{target_word}' in {len(xml_files)} XML files.")

        for i, blob_name in enumerate(xml_files, start=1):
            print(f"Processing file {i}/{len(xml_files)}: {blob_name}")

            try:
                # Download blob content
                blob_client = self.container_client.get_blob_client(blob_name)
                blob_data = blob_client.download_blob().readall()

                # Parse the XML content
                tree = ET.ElementTree(ET.fromstring(blob_data.decode('iso-8859-15')))
                root_element = tree.getroot()

                # Search for the target word in all <w> elements
                word_elements = root_element.findall('.//dcoi:w', {'dcoi': 'http://lands.let.ru.nl/projects/d-coi/ns/1.0'})
                for word_element in word_elements:
                    if word_element.text and target_word in word_element.text:
                        matching_blobs.append(blob_name)
                        print(f"Word '{target_word}' found in {blob_name}")
                        break  # Stop searching this file if the word is found

            except ET.ParseError:
                print(f"Error parsing {blob_name}. Skipping.")

        return matching_blobs

# %%
search_word = "haar"

# Initialize the BlobWordSearcher
searcher = BlobWordSearcher(connection_string, container_name)

# Search for blobs containing the word
blobs_with_word = searcher.find_blobs_with_word(search_word)

# Display the results
if blobs_with_word:
    print(f"The word '{search_word}' was found in the following blobs:")
    for blob in blobs_with_word:
        print(blob)
else:
    print(f"No blobs contain the word '{search_word}'.")
# Out:
# Searching for the word 'haar' in 508 XML files.
# Processing file 1/508: WR-P-P-B-0000000001.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000001.dcoi.xml
# Processing file 2/508: WR-P-P-B-0000000002.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000002.dcoi.xml
# Processing file 3/508: WR-P-P-B-0000000003.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000003.dcoi.xml
# Processing file 4/508: WR-P-P-B-0000000004.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000004.dcoi.xml
# Processing file 5/508: WR-P-P-B-0000000005.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000005.dcoi.xml
# Processing file 6/508: WR-P-P-B-0000000006.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000006.dcoi.xml
# Processing file 7/508: WR-P-P-B-0000000007.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000007.dcoi.xml
# Processing file 8/508: WR-P-P-B-0000000008.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000008.dcoi.xml
# Processing file 9/508: WR-P-P-B-0000000011.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000011.dcoi.xml
# Processing file 10/508: WR-P-P-B-0000000012.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000012.dcoi.xml
# Processing file 11/508: WR-P-P-B-0000000013.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000013.dcoi.xml
# Processing file 12/508: WR-P-P-B-0000000014.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000014.dcoi.xml
# Processing file 13/508: WR-P-P-B-0000000015.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000015.dcoi.xml
# Processing file 14/508: WR-P-P-B-0000000016.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000016.dcoi.xml
# Processing file 15/508: WR-P-P-B-0000000017.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000017.dcoi.xml
# Processing file 16/508: WR-P-P-B-0000000018.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000018.dcoi.xml
# Processing file 17/508: WR-P-P-B-0000000019.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000019.dcoi.xml
# Processing file 18/508: WR-P-P-B-0000000020.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000020.dcoi.xml
# Processing file 19/508: WR-P-P-B-0000000021.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000021.dcoi.xml
# Processing file 20/508: WR-P-P-B-0000000022.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000000022.dcoi.xml
# Processing file 21/508: WR-P-P-B-0000000023.dcoi.xml
# Word 'haar' found in WR-P-P-B-0000
# WR-P-P-B-0000000504.dcoi.xml
# WR-P-P-B-0000000505.dcoi.xml
# WR-P-P-B-0000000506.dcoi.xml
# WR-P-P-B-0000000507.dcoi.xml
# WR-P-P-B-0000000508.dcoi.xml
# WR-P-P-B-0000000509.dcoi.xml
# WR-P-P-B-0000000510.dcoi.xml
# WR-P-P-B-0000000511.dcoi.xml
# WR-P-P-B-0000000512.dcoi.xml
# WR-P-P-B-0000000513.dcoi.xml
# WR-P-P-B-0000000514.dcoi.xml
# WR-P-P-B-0000000515.dcoi.xml
# WR-P-P-B-0000000516.dcoi.xml
# WR-P-P-B-0000000517.dcoi.xml

# %% [markdown]
# ### Generating genedered wordpairs and professions csv files

# %%
class BlobWordAnalyzer:
    def __init__(self, connection_string, container_name):
        self.connection_string = connection_string
        self.container_name = container_name
        self.blob_service_client = BlobServiceClient.from_connection_string(connection_string)
        self.container_client = self.blob_service_client.get_container_client(container_name)

    def load_csv(self, file_path):
        """Load a CSV file into a Pandas DataFrame."""
        return pd.read_csv(file_path, sep=',', on_bad_lines='skip')

    def analyze_gendered_words(self, word_frequencies, gendered_wordpairs_list, output_csv):
        """Analyze gendered words and save the results to a CSV."""
        gendered_wordpairs = word_frequencies[word_frequencies['Word'].isin(gendered_wordpairs_list)].reset_index(drop=True)
        gendered_wordpairs['Word'] = gendered_wordpairs["Word"].str.lower()
        gendered_wordpairs = gendered_wordpairs.groupby(["Word"]).agg({"Frequency": "sum"}).reset_index()

        word_mapping = {
            "baron": ["baron"],
            "barones": ["barones"],
            "broer": ["broer", "broers"],
            "bruid": ["bruid", "bruiden"],
            "bruidegom": ["bruidegom", "bruidegoms"],
            "dame": ["dame", "dames"],
            "dochter": ["dochter", "dochters"],
            "gentleman": ["gentleman"],
            "gozer": ["gozer", "gozers"],
            "grootmoeder": ["grootmoeder", "grootmoeders"],
            "grootvader": ["grootvader", "grootvaders"],
            "heer": ["heer", "heren"],
            "hertog": ["hertog", "hertogen"],
            "hertogin": ["hertogin"],
            "hij": ["hij"],
            "hijzelf": ["hijzelf"],
            "jongen": ["jongen", "jongens"],
            "jongetje": ["jongetje", "jongetjes"],
            "kerel": ["kerel", "kerels"],
            "kleindochter": ["kleindochter", "kleindochters"],
            "kleinzoon": ["kleinzoon", "kleinzonen"],
            "koning": ["koning", "koningen"],
            "koningin": ["koningin", "koninginnen"],
            "lady": ["lady"],
            "lord": ["lord"],
            "mama": ["mama", "mama's", "mamma", "mamma's"],
            "man": ["man", "mannen"],
            "meid": ["meid", "meiden"],
            "meisje": ["meisje", "meisjes"],
            "meneer": ["meneer"],
            "mijnheer": ["mijnheer"],
            "mevrouw": ["mevrouw"],
            "miss": ["miss"],
            "mister": ["mister"],
            "moeder": ["moeder", "moeders"],
            "monnik": ["monnik", "monniken"],
            "mr": ["mr", "mr.", "mrs", "mrs."],
            "ms": ["ms", "ms."],
            "neef": ["neef", "neven"],
            "nicht": ["nicht", "nichten"],
            "non": ["non", "nonnen"],
            "oma": ["oma", "oma's"],
            "oom": ["oom", "ooms"],
            "opa": ["opa", "opa's"],
            "papa": ["papa", "papa's", "pappa", "pappa's"],
            "peetmoeder": ["peetmoeder"],
            "peetvader": ["peetvader"],
            "prins": ["prins", "prinsen"],
            "prinses": ["prinses", "prinsessen"],
            "schoondochter": ["schoondochter", "schoondochters"],
            "schoonmoeder": ["schoonmoeder", "schoonmoeders"],
            "schoonvader": ["schoonvader", "schoonvaders"],
            "schoonzoon": ["schoonzoon", "schoonzonen"],
            "stiefdochter": ["stiefdochter"],
            "stiefmoeder": ["stiefmoeder", "stiefmoeders"],
            "stiefvader": ["stiefvader", "stiefvaders"],
            "stiefzoon": ["stiefzoon", "stiefzonen"],
            "tante": ["tante", "tantes"],
            "vader": ["vader", "vaders"],
            "vrouw": ["vrouw", "vrouwen"],
            "mannelijk": ["mannelijk", "mannelijke"],
            "vrouwelijk": ["vrouwelijk", "vrouwelijke"],
            "wijf": ["wijf", "wijven"],
            "zij": ["zij"],
            "zijzelf": ["zijzelf"],
            "zoon": ["zoon", "zonen"],
            "zus": ["zus", "zussen"],
        }

        reverse_mapping = {plural: singular for singular, plurals in word_mapping.items() for plural in plurals}
        gendered_wordpairs["BaseWord"] = gendered_wordpairs["Word"].map(reverse_mapping)

        gendered_wordpairs.to_csv(output_csv, index=False)

        gendered_wordpairs_base = gendered_wordpairs.groupby(["BaseWord"]).agg({"Frequency": "sum"}).reset_index()
        gendered_wordpairs_base = gendered_wordpairs_base.sort_values(by='Frequency', ascending=False)

        return gendered_wordpairs, gendered_wordpairs_base

    def analyze_professions(self, word_frequencies, professions_list, output_csv):
        """Analyze professions and save the results to a CSV."""
        professions = word_frequencies[word_frequencies['Word'].isin(professions_list)].reset_index(drop=True)
        professions['Word'] = professions["Word"].str.lower()
        professions = professions.groupby(["Word"]).agg({"Frequency": "sum"}).reset_index()
        professions = professions.sort_values(by='Frequency', ascending=False)

        professions.to_csv(output_csv, index=False)
        return professions

# %%
# Initialize the word analyzer
analyzer = BlobWordAnalyzer(connection_string, container_name)

# Analyze gendered words
word_frequencies = analyzer.load_csv(output_csv_wordfrequencies)
gendered_wordpairs_list = [
    'man', 'vrouw',
    'Man', 'Vrouw',
    'mannen', 'vrouwen',
    'Mannen', 'Vrouwen',
    'jongen', 'meisje',
    'Jongen', 'Meisje',
    'jongens', 'meisjes',
    'Jongens', 'Meisjes',
    'jongetje', 'meisje',
    'Jongetje', 'Meisje',
    'jongetjes', 'meisjes',
    'Jongetjes', 'Meisjes',
    'kerel', 'meid',
    'Kerel', 'Meid',
    'kerels', 'meiden',
    'Kerels', 'Meiden',
    'gozer', 'meid',
    'Gozer', 'Meid',
    'gozers', 'meiden',
    'Gozers', 'Meiden',
    'gozer', 'wijf',
    'Gozer', 'Wijf',
    'gozers', 'wijven',
    'Gozers', 'Wijven',
    'gentleman', 'lady',
    'Gentleman', 'Lady',
    'lord', 'lady',
    'Lord', 'Lady',
    'heer', 'dame',
    'Heer', 'Dame',
    'heren', 'dames',
    'Heren', 'Dames',
    'meneer', 'mevrouw',
    'Meneer', 'Mevrouw',
    'mijnheer', 'mevrouw',
    'Mijnheer', 'Mevrouw',
    'mister', 'miss',
    'Mister', 'Miss',
    'Mr.', 'Ms.',
    'Mr', 'Ms',
    'Mr.', 'Mrs.',
    'Mr', 'Mrs',
    'mannelijk', 'vrouwelijk',
    'Mannelijk', 'Vrouwelijk',
    'mannelijke', 'vrouwelijke',
    'Mannelijke', 'Vrouwelijke',
    'koning', 'koningin',
    'Koning', 'Koningin',
    'koningen', 'koninginnen',
    'Koningen', 'Koninginnen',
    'prins', 'prinses',
    'Prins', 'Prinses',
    'prinsen', 'prinsessen',
    'Prinsen', 'Prinsessen',
    'hertog', 'hertogin',
    'Hertog', 'Hertogin',
    'hertogen', 'hertoginnen',
    'monnik', 'non',
    'Monnik', 'Non',
    'monniken', 'nonnen',
    'Monniken', 'Nonnen',
    'baron', 'barones',
    'Baron', 'Barones',
    'hij', 'zij',
    'Hij', 'Zij',
    'hijzelf', 'zijzelf',
    'Hijzelf', 'Zijzelf',
    'vader', 'moeder',
    'Vader', 'Moeder',
    'vaders', 'moeders',
    'Vaders', 'Moeders',
    'papa', 'mama',
    'Papa', 'Mama',
    'papa\'s', 'mama\'s',
    'Papa\'s', 'Mama\'s',
    'pappa', 'mamma',
    'Pappa', 'Mamma',
    'pappa\'s', 'mamma\'s',
    'Pappa\'s', 'Mamma\'s',
    'broer', 'zus',
    'Broer', 'Zus',
    'broers', 'zussen',
    'Broers', 'Zussen',
    'neef', 'nicht',
    'Neef', 'Nicht',
    'neven', 'nichten',
    'oom', 'tante',
    'Oom', 'Tante',
    'ooms', 'tantes',
    'grootvader', 'grootmoeder',
    'Grootvader', 'Grootmoeder',
    'grootvaders', 'grootmoeders',
    'Grootvaders', 'Grootmoeders',
    'opa', 'oma',
    'Opa', 'Oma',
    'opa\'s', 'oma\'s',
    'Opa\'s', 'Oma\'s',
    'zoon', 'dochter',
    'Zoon', 'Dochter',
    'zonen', 'dochters',
    'Zonen', 'Dochters',
    'kleinzoon', 'kleindochter',
    'Kleinzoon', 'Kleindochter',
    'kleinzonen', 'kleindochters',
    'schoonzoon', 'schoondochter',
    'Schoonzoon', 'Schoondochter',
    'schoonzonen', 'schoondochters',
    'stiefvader', 'stiefmoeder',
    'Stiefvader', 'Stiefmoeder',
    'stiefvaders', 'stiefmoeders',
    'Stiefvaders', 'Stiefmoeders',
    'stiefzoon', 'stiefdochter',
    'Stiefzoon', 'Stiefdochter',
    'stiefzonen', 'stiefdochters',
    'schoonvader', 'schoonmoeder',
    'schoonvaders', 'schoonmoeders',
    'bruidegom', 'bruid',
    'Bruidegom', 'Bruid',
    'bruidegoms', 'bruiden',
    'peetvader', 'peetmoeder',
    'Peetvader', 'Peetmoeder',
]
gendered_wordpairs, gendered_wordpairs_base = analyzer.analyze_gendered_words(word_frequencies, gendered_wordpairs_list, gendered_output_csv)

# Analyze professions
professions_list = [
    #"Pedagoog", "Pedagogen", "pedagoog", "pedagogen",
    #"Docent", "Docenten", "docent", "docenten",
    #"leraar", "leraren", "Leraar", "Leraren", 
    #"leerkracht", "leerkrachten", "Leerkracht", "Leerkrachten",
    #"onderwijzer", "onderwijzers", "Onderwijzer", "Onderwijzers",
    #"auteur", "auteurs", "Auteur", "Auteurs",
    #"Kunstenaar", "Kunstenaars", "kunstenaar", "kunstenaars",
    #"journalist", "journalisten", "Journalist", "Journalisten",
    #"fotograaf", "fotografen", "Fotograaf", "Fotografen",
    #"adviseur", "adviseurs", "Adviseur", "Adviseurs",
    #"vertegenwoordiger", "vertegenwoordigers", "Vertegenwoordiger", "Vertegenwoordigers",
    #"verkoper", "Verkoper",
    #"winkelier", "Winkelier",
    #"teamleider", "Teamleider",
    #"hoogleraar", "hoogleraren", "Hoogleraar", "Hoogleraren",
    #"apotheker", "apothekers", "Apotheker", "Apothekers",
    #"assistent", "assistenten", "Assistent", "Assistenten",
    #"conciërge", "conciërges", "Conciërge", "Conciërges",
    
    "technicus", #"Technicus",
    "accountant", "Accountant",
    "supervisor", #"Supervisor",
    "ingenieur", "Ingenieur",
    "arbeider", "Arbeider",
    #"klerk", "Klerk",
    "adviseur", "Adviseur",
    "inspecteur", "Inspecteur",
    "monteur", #"Monteur",
    'manager', 'Manager',
    "administrateur", "Administrateur", 
    "portier", "Portier",
    "psycholoog", "Psycholoog", 
    "arts", "Arts",
    "timmerman", "Timmerman",
    "verpleegkundige", "Verpleegkundige",
    "onderzoeker", "Onderzoeker",
    "barkeeper", #"Barkeeper",
    "specialist", "Specialist",
    "Deskundige", "deskundige",
    "expert", "Expert",
    "elektricien", #"Elektricien",
    "ambtenaar", #"Ambtenaar",
    "officier", "Officier",
    "beambte", #"Beambte",
    "patholoog", #"Patholoog",
    "jurist", "Jurist",
    "rechtsgeleerde", #"Rechtsgeleerde",
    "roostermaker", #"Roostermaker",
    "huisarts", "Huisarts",
    "loodgieter", #"Loodgieter",
    "dierenarts", "Dierenarts",
    "fysiotherapeut", "Fysiotherapeut",
    "scheikundige", "Scheikundige", 
    "machinist", "Machinist",
    "architect", "Architect",
    "bakker", "Bakker",
    "programmeur", #"Programmeur",
    "wetenschapper", #"Wetenschapper",
    "coördinator", "Coördinator",
    "kassier", #"Kassier",
    "schilder", "Schilder",
    "makelaar", "Makelaar",
    "chef", "Chef",
    "dokter", "Dokter",
    ]
professions = analyzer.analyze_professions(word_frequencies, professions_list, professions_output_csv)

# %% [markdown]
# ### Summarizing the entire corpus

# %%
class CorpusSummaryAnalyzer:
    @staticmethod
    def analyze_corpus_summary(word_frequencies_file, gendered_wordpairs_file, professions_file, wordcount_and_10gram_file):
        """Generate a summary of the corpus analysis."""
        # Load CSV files
        word_frequencies = pd.read_csv(word_frequencies_file, sep=',', on_bad_lines='skip')
        gendered_wordpairs_base = pd.read_csv(gendered_wordpairs_file, sep=',', on_bad_lines='skip')
        professions = pd.read_csv(professions_file, sep=',', on_bad_lines='skip')
        wordcount_and_10gram = pd.read_csv(wordcount_and_10gram_file, sep=',', on_bad_lines='skip')

        total_words = word_frequencies['Frequency'].sum()
        total_ten_grams = wordcount_and_10gram['ten_grams'].sum()
        num_files = len(wordcount_and_10gram)

        total_frequency_gendered = gendered_wordpairs_base['Frequency'].sum()
        total_frequency_professions = professions['Frequency'].sum()

        summary = {
            "Total Words in Corpus": total_words,
            "Unique Words in Corpus": len(word_frequencies),
            "Gendered Words": len(gendered_wordpairs_base),
            "Frequency of Gendered Words": total_frequency_gendered,
            "Professions": len(professions),
            "Frequency of Professions": total_frequency_professions,
            "Number of Book Files": num_files,
            "Total 10-Grams": total_ten_grams,
        }

        return summary

# %%
# Summarize the corpus
summary = CorpusSummaryAnalyzer.analyze_corpus_summary(
    output_csv_wordfrequencies,
    gendered_output_csv,
    professions_output_csv,
    output_file_wordcount_and_10gram_perfile
)

for key, value in summary.items():
    print(f"{key}: {value}")
# Out:
# Total Words in Corpus: 8626248
# Unique Words in Corpus: 264525
# Gendered Words: 113
# Frequency of Gendered Words: 45172
# Professions: 41
# Frequency of Professions: 2426
# Number of Book Files: 18699
# Total 10-Grams: 8457957

# %% [markdown]
# ### Running everything at once

# %%
container_name = "subtitles"
output_file_wordcount_and_10gram_perfile = f"../out/{container_name}/wordcount_and_10gram_perfile_{container_name}.csv"
output_file_fulltext = f"../out/{container_name}/combined_{container_name}.txt"
output_csv_wordfrequencies = f"../out/{container_name}/word_frequencies_{container_name}.csv"
gendered_output_csv = f"../out/{container_name}/gendered_wordpairs_{container_name}.csv"
professions_output_csv = f"../out/{container_name}/professions_{container_name}.csv"

# %%
# ============== STEP 1 =================
# Initialize BlobProcessor
processor = BlobProcessor(connection_string, container_name, output_file_wordcount_and_10gram_perfile)

# Process XML files
processor.process_xml_files()

# Print summary
processor.summary()

# Save DataFrame to a CSV file
processor.save_dataframe()

# ============== STEP 2 =================
# Initialize the BlobTextExtractor
extractor = BlobTextExtractor(connection_string, container_name)

# Extract texts and save to a single output file
extractor.save_texts_to_single_file(output_file_fulltext)

# ============== STEP 3 =================
# Initialize the BlobWordFrequencyAggregator
aggregator = BlobWordFrequencyAggregator(connection_string, container_name)

# Aggregate word frequencies
total_word_frequencies = aggregator.aggregate_word_frequencies()

# Save aggregated frequencies to a CSV file
aggregator.save_aggregated_frequencies_to_csv(total_word_frequencies, output_csv_wordfrequencies)

# ============== STEP 4 =================
# Initialize the word analyzer
analyzer = BlobWordAnalyzer(connection_string, container_name)

# Analyze gendered words
word_frequencies = analyzer.load_csv(output_csv_wordfrequencies)
gendered_wordpairs_list = [
    'man', 'vrouw',
    'Man', 'Vrouw',
    'mannen', 'vrouwen',
    'Mannen', 'Vrouwen',
    'jongen', 'meisje',
    'Jongen', 'Meisje',
    'jongens', 'meisjes',
    'Jongens', 'Meisjes',
    'jongetje', 'meisje',
    'Jongetje', 'Meisje',
    'jongetjes', 'meisjes',
    'Jongetjes', 'Meisjes',
    'kerel', 'meid',
    'Kerel', 'Meid',
    'kerels', 'meiden',
    'Kerels', 'Meiden',
    'gozer', 'meid',
    'Gozer', 'Meid',
    'gozers', 'meiden',
    'Gozers', 'Meiden',
    'gozer', 'wijf',
    'Gozer', 'Wijf',
    'gozers', 'wijven',
    'Gozers', 'Wijven',
    'gentleman', 'lady',
    'Gentleman', 'Lady',
    'lord', 'lady',
    'Lord', 'Lady',
    'heer', 'dame',
    'Heer', 'Dame',
    'heren', 'dames',
    'Heren', 'Dames',
    'meneer', 'mevrouw',
    'Meneer', 'Mevrouw',
    'mijnheer', 'mevrouw',
    'Mijnheer', 'Mevrouw',
    'mister', 'miss',
    'Mister', 'Miss',
    'Mr.', 'Ms.',
    'Mr', 'Ms',
    'Mr.', 'Mrs.',
    'Mr', 'Mrs',
    'mannelijk', 'vrouwelijk',
    'Mannelijk', 'Vrouwelijk',
    'mannelijke', 'vrouwelijke',
    'Mannelijke', 'Vrouwelijke',
    'koning', 'koningin',
    'Koning', 'Koningin',
    'koningen', 'koninginnen',
    'Koningen', 'Koninginnen',
    'prins', 'prinses',
    'Prins', 'Prinses',
    'prinsen', 'prinsessen',
    'Prinsen', 'Prinsessen',
    'hertog', 'hertogin',
    'Hertog', 'Hertogin',
    'hertogen', 'hertoginnen',
    'monnik', 'non',
    'Monnik', 'Non',
    'monniken', 'nonnen',
    'Monniken', 'Nonnen',
    'baron', 'barones',
    'Baron', 'Barones',
    'hij', 'zij',
    'Hij', 'Zij',
    'hijzelf', 'zijzelf',
    'Hijzelf', 'Zijzelf',
    'vader', 'moeder',
    'Vader', 'Moeder',
    'vaders', 'moeders',
    'Vaders', 'Moeders',
    'papa', 'mama',
    'Papa', 'Mama',
    'papa\'s', 'mama\'s',
    'Papa\'s', 'Mama\'s',
    'pappa', 'mamma',
    'Pappa', 'Mamma',
    'pappa\'s', 'mamma\'s',
    'Pappa\'s', 'Mamma\'s',
    'broer', 'zus',
    'Broer', 'Zus',
    'broers', 'zussen',
    'Broers', 'Zussen',
    'neef', 'nicht',
    'Neef', 'Nicht',
    'neven', 'nichten',
    'oom', 'tante',
    'Oom', 'Tante',
    'ooms', 'tantes',
    'grootvader', 'grootmoeder',
    'Grootvader', 'Grootmoeder',
    'grootvaders', 'grootmoeders',
    'Grootvaders', 'Grootmoeders',
    'opa', 'oma',
    'Opa', 'Oma',
    'opa\'s', 'oma\'s',
    'Opa\'s', 'Oma\'s',
    'zoon', 'dochter',
    'Zoon', 'Dochter',
    'zonen', 'dochters',
    'Zonen', 'Dochters',
    'kleinzoon', 'kleindochter',
    'Kleinzoon', 'Kleindochter',
    'kleinzonen', 'kleindochters',
    'schoonzoon', 'schoondochter',
    'Schoonzoon', 'Schoondochter',
    'schoonzonen', 'schoondochters',
    'stiefvader', 'stiefmoeder',
    'Stiefvader', 'Stiefmoeder',
    'stiefvaders', 'stiefmoeders',
    'Stiefvaders', 'Stiefmoeders',
    'stiefzoon', 'stiefdochter',
    'Stiefzoon', 'Stiefdochter',
    'stiefzonen', 'stiefdochters',
    'schoonvader', 'schoonmoeder',
    'schoonvaders', 'schoonmoeders',
    'bruidegom', 'bruid',
    'Bruidegom', 'Bruid',
    'bruidegoms', 'bruiden',
    'peetvader', 'peetmoeder',
    'Peetvader', 'Peetmoeder',
]
gendered_wordpairs, gendered_wordpairs_base = analyzer.analyze_gendered_words(word_frequencies, gendered_wordpairs_list, gendered_output_csv)

# Analyze professions
professions_list = [
    "Pedagoog", "Pedagogen", "pedagoog", "pedagogen",
    "Docent", "Docenten", "docent", "docenten",
    "leraar", "leraren", "Leraar", "Leraren", 
    "leerkracht", "leerkrachten", "Leerkracht", "Leerkrachten",
    "onderwijzer", "onderwijzers", "Onderwijzer", "Onderwijzers",
    "auteur", "auteurs", "Auteur", "Auteurs",
    "Kunstenaar", "Kunstenaars", "kunstenaar", "kunstenaars",
    "journalist", "journalisten", "Journalist", "Journalisten",
    "fotograaf", "fotografen", "Fotograaf", "Fotografen",
    "adviseur", "adviseurs", "Adviseur", "Adviseurs",
    "vertegenwoordiger", "vertegenwoordigers", "Vertegenwoordiger", "Vertegenwoordigers",
    "verkoper", "Verkoper",
    "winkelier", "Winkelier",
    "teamleider", "Teamleider",
    "hoogleraar", "hoogleraren", "Hoogleraar", "Hoogleraren",
    "apotheker", "apothekers", "Apotheker", "Apothekers",
    "assistent", "assistenten", "Assistent", "Assistenten",
    "conciërge", "conciërges", "Conciërge", "Conciërges",
    
    "technicus", "Technicus",
    "accountant", "Accountant",
    "supervisor", "Supervisor",
    "ingenieur", "Ingenieur",
    "arbeider", "Arbeider",
    "klerk", "Klerk",
    "adviseur", "Adviseur",
    "inspecteur", "Inspecteur",
    "monteur", "Monteur",
    'manager', 'Manager',
    "administrateur", "Administrateur", 
    "portier", "Portier",
    "psycholoog", "Psycholoog", 
    "arts", "Arts",
    "timmerman", "Timmerman",
    "verpleegkundige", "Verpleegkundige",
    "onderzoeker", "Onderzoeker",
    "barkeeper", "Barkeeper",
    "specialist", "Specialist",
    "Deskundige", "deskundige",
    "expert", "Expert",
    "elektricien", "Elektricien",
    "ambtenaar", "Ambtenaar",
    "officier", "Officier",
    "beambte", "Beambte",
    "patholoog", "Patholoog",
    "jurist", "Jurist",
    "rechtsgeleerde", "Rechtsgeleerde",
    "roostermaker", "Roostermaker",
    "huisarts", "Huisarts",
    "loodgieter", "Loodgieter",
    "dierenarts", "Dierenarts",
    "fysiotherapeut", "Fysiotherapeut",
    "scheikundige", "Scheikundige", 
    "machinist", "Machinist",
    "architect", "Architect",
    "bakker", "Bakker",
    "programmeur", "Programmeur",
    "wetenschapper", "Wetenschapper",
    "coördinator", "Coördinator",
    "kassier", "Kassier",
    "schilder", "Schilder",
    "makelaar", "Makelaar",
    "chef", "Chef",
    "dokter", "Dokter",
    ]
professions = analyzer.analyze_professions(word_frequencies, professions_list, professions_output_csv)

# ============== STEP 5 =================
# Summarize the corpus
summary = CorpusSummaryAnalyzer.analyze_corpus_summary(
    output_csv_wordfrequencies,
    gendered_output_csv,
    professions_output_csv,
    output_file_wordcount_and_10gram_perfile
)

for key, value in summary.items():
    print(f"{key}: {value}")
# Out:
252)
# Blob data: b'<?xml version=\'1.0\' encoding=\'iso-8859-15\'?>\n <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI" '
# File WR-P-P-B-0000000453.dcoi.xml processed: 192/252
# Processing file WR-P-P-B-0000000455.dcoi.xml (193/252)
# Blob data: b'<?xml version=\'1.0\' encoding=\'iso-8859-15\'?>\n <DCOI xmlns:imdi="http://www.mpi.nl/IMDI/Schema/IMDI" '
# File WR-P-P-B-0000000455.dcoi.xml processed: 193/252
# ...
# Processing file 236/252: WR-P-P-B-0000000501.dcoi.xml
# Added text from WR-P-P-B-0000000501.dcoi.xml to the combined file.
# Processing file 237/252: WR-P-P-B-0000000502.dcoi.xml
# Added text from WR-P-P-B-0000000502.dcoi.xml to the combined file.
# Processing file 238/252: WR-P-P-B-0000000503.dcoi.xml
# Added text from WR-P-P-B-0000000503.dcoi.xml to the combined file.
# Processing file 239/252: WR-P-P-B-0000000504.dcoi.xml
# Added text from WR-P-P-B-0000000504.dcoi.xml to the combined file.
# Processing file 240/252: WR-P-P-B-0000000505.dcoi.xml
# Added text from WR-P-P-B-0000000505.dcoi.xml to the combined file.
# Processing file 241/252: WR-P-P-B-0000000506.dcoi.xml
# Added text from WR-P-P-B-0000000506.dcoi.xml to the combined file.
# Processing file 242/252: WR-P-P-B-0000000507.dcoi.xml
# Added text from WR-P-P-B-0000000507.dcoi.xml to the combined file.
# Processing file 243/252: WR-P-P-B-0000000508.dcoi.xml
# Added text from WR-P-P-B-0000000508.dcoi.xml to the combined file.
# Processing file 244/252: WR-P-P-B-0000000509.dcoi.xml
# Added text from WR-P-P-B-0000000509.dcoi.xml to the combined file.
# Processing file 245/252: WR-P-P-B-0000000510.dcoi.xml
# Added text from WR-P-P-B-0000000510.dcoi.xml to the combined file.
# Processing file 246/252: WR-P-P-B-0000000511.dcoi.xml
# Added text from WR-P-P-B-0000000511.dcoi.xml to the combined file.
# Processing file 247/252: WR-P-P-B-0000000512.dcoi.xml
# Added text from WR-P-P-B-0000000512.dcoi.xml to the combined file.
# Processing file 248/252: WR-P-P-B-0000000513.dcoi.xml
# Added text from WR-P-P-B-0000000513.dcoi.xml to the combined file.
# Processing file 249/252: WR-P-P-B-0000000514.dcoi.xml
# Added text from WR-P-P-B-0000000514.dcoi.xml to the combined file.
# Processing file 250/252: WR-P-P-B-0000000515.dcoi.xml
# Added text from WR-P-P-B-0000000515.dcoi.xml to the combined file.
# Processing file 251/252: WR-P-P-B-0000000516.dcoi.xml
# Added text from WR-P-P-B-0000000516.dcoi.xml to the combined file.
# Processing file 252/252: WR-P-P-B-0000000517.dcoi.xml
# Added text from WR-P-P-B-0000000517.dcoi.xml to the combined file.
# All texts saved to a single file at ../out/booksbiblical/combined_booksbiblical.txt.
# Found 252 XML files in container 'booksbiblical'.
# Processing file 1/252: WR-P-P-B-0000000071.dcoi.xml
# Processing file 2/252: WR-P-P-B-0000000072.dcoi.xml
# Processing file 3/252: WR-P-P-B-0000000073.dcoi.xml
# Processing file 4/252: WR-P-P-B-0000000074.dcoi.xml
# Processing file 5/252: WR-P-P-B-0000000075.dcoi.xml
# Processing file 6/252: WR-P-P-B-0000000076.dcoi.xml
# Processing file 7/252: WR-P-P-B-0000000077.dcoi.xml
# Processing file 8/252: WR-P-P-B-0000000078.dcoi.xml
# Processing file 9/252: WR-P-P-B-0000000079.dcoi.xml
# Processing file 250/252: WR-P-P-B-0000000515.dcoi.xml
# Processing file 251/252: WR-P-P-B-0000000516.dcoi.xml
# Processing file 252/252: WR-P-P-B-0000000517.dcoi.xml
# Word frequencies saved to ../out/booksbiblical/word_frequencies_booksbiblical.csv.
# Total Words in Corpus: 3330348
# Unique Words in Corpus: 43911
# Gendered Words: 68
# Frequency of Gendered Words: 105111
# Professions: 28
# Frequency of Professions: 293
# Number of Book Files: 252
# Total 10-Grams: 3328080

# %% [markdown]
# ### Topic analysis using GPT-4

# %%
class DataFrameMaker:
    def __init__(self, file_path):
        self.file_path = file_path
        self.valid_sections = {}
        self.df = None

    def read_file(self):
        print("Reading file...")
        with open(self.file_path, "r", encoding="utf-8") as file:
            content = file.read()
        return content

    def split_sections(self, content):
        print("Splitting content into sections...")
        sections = re.split(r"\n\s*\n+", content)  # Split on blank lines

        for sec in sections:
            lines = sec.strip().split("\n")

            # Identify the title line (ending in .dcoi)
            title_line = next((line for line in lines if re.match(r"^\S+\.dcoi$", line)), None)

            # Remove the title from the lines and clean the rest
            cleaned_lines = [line for line in lines if line != title_line]

            # Store in dictionary if a valid title exists
            if title_line and cleaned_lines:
                self.valid_sections[title_line] = " ".join(cleaned_lines)

        print(f"Extracted {len(self.valid_sections)} valid sections.")

    def make_dataframe(self):
        print("Making dataframe...")
        self.df = pd.DataFrame(self.valid_sections.items(), columns=["Title", "Text"])
        print("Processing complete!")

    def run(self):
        content = self.read_file()
        self.split_sections(content)
        self.make_dataframe()

# %%
dfmaker = DataFrameMaker(output_file_fulltext)
dfmaker.run()

df = dfmaker.df
df.head()
# Out:
# Reading file...
# Splitting content into sections...
# Extracted 8368 valid sections.
# Making dataframe...
# Processing complete!
#                         Title  \
# 0  0/WR-P-E-G-0000000001.dcoi
# 1  0/WR-P-E-G-0000000002.dcoi
# 2  0/WR-P-E-G-0000000006.dcoi
# 3  0/WR-P-E-G-0000000008.dcoi
# 4  0/WR-P-E-G-0000000009.dcoi
#
#                                                                                                                                                                                                                                                         Text
# 0  Subtitles for afritnegen 9.8.99 In deze uitzending : Luk Demarey , schakel tussen boer en slager Alfons Morret , weekend-ridder Verlekkerd op ' Vragen staat vrij ' Alain Rinckhout van de improvisatie-liga Frans Van Hool en zijn kalebassen Dat is ...
# 1  Subtitles for Boerenkrijg , afl. 1 Au ! Aaah ! Stommerik ! Het is de verkeerde ! Deze zal nooit meer pijn doen . - Ik kom hier nooit meer . Hela , vergeet je niks ? Geld hoeft niet . In natura is ook goed . Het overschot mag je houden . Kom , ik ...
# 2                                                                                                                                                            Subtitles for program1 ghndghjdjdghj ghjgjgj sdfghfhfh khkhkyyiy ykykykykyk hkhkhkhjkjhk kkllkl
# 3                                                                                                                                                                  Subtitles for testuitzending Dit zijn enkele testtitels . En nog een paar . Dat was het .
# 4                                                                                                                                       Subtitles for testuitzending Dit zijn enkele testtitels . En nog een paar . Dat was het . Hier is een nieuwe titel .

# %%
class EmbeddingProcessor:
    def __init__(self, file_path, openai_client, max_tokens=8100, num_workers=4):
        self.file_path = file_path
        self.openai_client = openai_client
        self.max_tokens = max_tokens
        self.num_workers = num_workers  # Number of parallel workers
        self.tokenizer = tiktoken.get_encoding("cl100k_base")
        self.valid_sections = []
        self.df = None
        self.matrix = None

    def read_file(self):
        print("Reading file...")
        with open(self.file_path, "r", encoding="utf-8") as file:
            content = file.read()
        return content

    def split_sections(self, content):
        print("Splitting content into sections...")
        sections = re.split(r"\n\s*\n+", content)
        
        for sec in sections:
            lines = sec.strip().split("\n")
            cleaned_lines = [line for line in lines if not re.match(r"^\S+\.dcoi$", line)]
            if cleaned_lines:
                self.valid_sections.append(" ".join(cleaned_lines))
        
        print(f"Extracted {len(self.valid_sections)} valid sections.")

    def split_into_chunks(self, text):
        tokens = self.tokenizer.encode(text)
        chunks = [self.tokenizer.decode(tokens[i:i+self.max_tokens]) for i in range(0, len(tokens), self.max_tokens)]
        print(f"Split text into {len(chunks)} chunks.")
        return chunks

    def get_embedding(self, text):
        """Fetches embedding for a given text."""
        try:
            response = self.openai_client.embeddings.create(
                model="text-embedding-3-small",
                input=text
            )
            return np.array(response.data[0].embedding)
        except Exception as e:
            print(f"Error generating embedding: {e}")
            return np.zeros(1536)

    def process_section(self, text, index, total):
        """Processes a single section, splitting it into chunks and averaging embeddings."""
        print(f"Processing section {index+1}/{total} in parallel...")
        chunks = self.split_into_chunks(text)
        embeddings = np.array([self.get_embedding(chunk) for chunk in chunks])
        averaged_embedding = np.mean(embeddings, axis=0)
        print(f"Completed section {index+1}/{total}.")
        return averaged_embedding

    def generate_embeddings(self, save_path="embedding_matrix.npy", embedding_dim=1536):
        """Generate embeddings in parallel and ensure consistency."""
        print("Generating averaged embeddings for all sections in parallel...")
        self.df = pd.DataFrame({"text": self.valid_sections})
        
        total_sections = len(self.df)

        with concurrent.futures.ThreadPoolExecutor(max_workers=self.num_workers) as executor:
            results = list(executor.map(
                lambda args: self.process_section(*args),
                [(text, idx, total_sections) for idx, text in enumerate(self.df["text"])]
            ))

        self.df["embedding"] = results

        # Convert to NumPy arrays and ensure all embeddings have the correct shape
        fixed_embeddings = []
        for idx, emb in enumerate(self.df["embedding"]):
            try:
                emb_array = np.array(emb)

                # Validate shape (should match embedding_dim)
                if emb_array.shape != (embedding_dim,):
                    print(f"Warning: Embedding at index {idx} has shape {emb_array.shape}, replacing with zeros.")
                    emb_array = np.zeros(embedding_dim)

            except Exception as e:
                print(f"Error processing embedding at index {idx}: {e}, replacing with zeros.")
                emb_array = np.zeros(embedding_dim)

            fixed_embeddings.append(emb_array)

        self.df["embedding"] = fixed_embeddings
        self.matrix = np.vstack(self.df["embedding"].values)
        
        print(f"Embedding matrix shape: {self.matrix.shape}")
        print("Processing complete!")

    def run(self):
        """Runs the entire pipeline."""
        content = self.read_file()
        self.split_sections(content)
        self.generate_embeddings()

# %%
processor = EmbeddingProcessor(output_file_fulltext, openai_client, num_workers=8)
processor.run()
# Out:
# Reading file...
# Splitting content into sections...
# Extracted 8369 valid sections.
# Generating averaged embeddings for all sections in parallel...
# Processing section 1/8369 in parallel...Processing section 2/8369 in parallel...
#
# Processing section 3/8369 in parallel...
# Processing section 4/8369 in parallel...
# Processing section 5/8369 in parallel...
# Processing section 6/8369 in parallel...
# Processing section 7/8369 in parallel...
# Processing section 8/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 3/8369.
# Processing section 9/8369 in parallel...
# Split text into 1 chunks.
# Completed section 1/8369.
# Processing section 10/8369 in parallel...
# Split text into 1 chunks.
# Completed section 5/8369.
# Processing section 11/8369 in parallel...
# Split text into 1 chunks.
# Completed section 7/8369.
# Processing section 12/8369 in parallel...
# Split text into 1 chunks.
# Completed section 4/8369.
# Processing section 13/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8/8369.
# Processing section 14/8369 in parallel...
# Split text into 1 chunks.
# Completed section 2/8369.
# Processing section 15/8369 in parallel...
# Split text into 1 chunks.
# Completed section 6/8369.
# Processing section 16/8369 in parallel...
# Split text into 1 chunks.
# Completed section 14/8369.
# Processing section 17/8369 in parallel...
# Split text into 1 chunks.
# Completed section 13/8369.
# Processing section 18/8369 in parallel...
# Split text into 1 chunks.
# Completed section 9/8369.
# Processing section 19/8369 in parallel...
# Split text into 1 chunks.
# Completed section 11/8369.
# Processing section 20/8369 in parallel...
# Split text into 1 chunks.
# Completed section 15/8369.
# Processing section 21/8369 in parallel...
# Split text into 1 chunks.
# Completed section 12/8369.
# Processing section 22/8369 in parallel...
# Split text into 1 chunks.
# Completed section 17/8369.
# Processing section 23/8369 in parallel...
# Completed section 10/8369.
# Processing section 24/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 16/8369.
# Processing section 25/8369 in parallel...
# Split text into 1 chunks.
# Completed section 20/8369.
# Processing section 26/8369 in parallel...
# Split text into 1 chunks.
# Completed section 19/8369.
# Processing section 27/8369 in parallel...
# Split text into 1 chunks.
# Completed section 22/8369.
# Processing section 28/8369 in parallel...
# Split text into 1 chunks.
# Completed section 18/8369.
# Processing section 29/8369 in parallel...
# Split text into 1 chunks.
# Completed section 25/8369.
# Processing section 30/8369 in parallel...
# Split text into 1 chunks.
# Completed section 23/8369.
# Processing section 31/8369 in parallel...
# Split text into 1 chunks.
# Completed section 24/8369.
# Processing section 32/8369 in parallel...
# Split text into 1 chunks.
# Completed section 21/8369.
# Processing section 33/8369 in parallel...
# Split text into 1 chunks.
# Completed section 26/8369.
# Processing section 34/8369 in parallel...
# Split text into 1 chunks.
# Completed section 27/8369.
# Processing section 35/8369 in parallel...
# Split text into 1 chunks.
# Completed section 28/8369.
# Processing section 36/8369 in parallel...
# Split text into 1 chunks.
# Completed section 30/8369.
# Processing section 37/8369 in parallel...
# Split text into 1 chunks.
# Completed section 29/8369.
# Processing section 38/8369 in parallel...
# Split text into 1 chunks.
# Completed section 31/8369.
# Processing section 39/8369 in parallel...
# Split text into 1 chunks.
# Completed section 36/8369.
# Processing section 40/8369 in parallel...
# Split text into 1 chunks.
# Completed section 32/8369.
# Processing section 41/8369 in parallel...
# Split text into 1 chunks.
# Completed section 33/8369.
# Processing section 42/8369 in parallel...
# Split text into 1 chunks.
# Completed section 35/8369.
# Processing section 43/8369 in parallel...
# Split text into 1 chunks.
# Completed section 34/8369.
# Processing section 44/8369 in parallel...
# Split text into 1 chunks.
# Completed section 38/8369.
# Processing section 45/8369 in parallel...
# Split text into 1 chunks.
# Completed section 39/8369.
# Processing section 46/8369 in parallel...
# Split text into 1 chunks.
# Completed section 40/8369.
# Processing section 47/8369 in parallel...
# Split text into 1 chunks.
# Completed section 41/8369.
# Processing section 48/8369 in parallel...
# Split text into 1 chunks.
# Completed section 37/8369.
# Processing section 49/8369 in parallel...
# Split text into 1 chunks.
# Completed section 42/8369.
# Processing section 50/8369 in parallel...
# Split text into 1 chunks.
# Completed section 43/8369.
# Processing section 51/8369 in parallel...
# Split text into 1 chunks.
# Completed section 44/8369.
# Processing section 52/8369 in parallel...
# Split text into 1 chunks.
# Completed section 45/8369.
# Processing section 53/8369 in parallel...
# Split text into 1 chunks.
# Completed section 46/8369.
# Processing section 54/8369 in parallel...
# Split text into 1 chunks.
# Completed section 51/8369.
# Processing section 55/8369 in parallel...
# Split text into 1 chunks.
# Completed section 49/8369.
# Processing section 56/8369 in parallel...
# Split text into 1 chunks.
# Completed section 48/8369.
# Processing section 57/8369 in parallel...
# Split text into 1 chunks.
# Completed section 47/8369.
# Processing section 58/8369 in parallel...
# Split text into 1 chunks.
# Completed section 54/8369.
# Processing section 59/8369 in parallel...
# Split text into 1 chunks.
# Completed section 50/8369.
# Processing section 60/8369 in parallel...
# Split text into 1 chunks.
# Completed section 53/8369.
# Processing section 61/8369 in parallel...
# Split text into 1 chunks.
# Completed section 55/8369.
# Processing section 62/8369 in parallel...
# Split text into 1 chunks.
# Completed section 52/8369.
# Processing section 63/8369 in parallel...
# Split text into 1 chunks.
# Completed section 56/8369.
# Processing section 64/8369 in parallel...
# Split text into 1 chunks.
# Completed section 57/8369.
# Processing section 65/8369 in parallel...
# Split text into 1 chunks.
# Completed section 59/8369.
# Processing section 66/8369 in parallel...
# Split text into 1 chunks.
# Completed section 58/8369.
# Processing section 67/8369 in parallel...
# Split text into 1 chunks.
# Completed section 60/8369.
# Processing section 68/8369 in parallel...
# Split text into 1 chunks.
# Completed section 64/8369.
# Processing section 69/8369 in parallel...
# Split text into 1 chunks.
# Completed section 62/8369.
# Processing section 70/8369 in parallel...
# Split text into 1 chunks.
# Completed section 63/8369.
# Processing section 71/8369 in parallel...
# Split text into 1 chunks.
# Completed section 61/8369.
# Processing section 72/8369 in parallel...
# Split text into 1 chunks.
# Completed section 65/8369.
# Processing section 73/8369 in parallel...
# Split text into 1 chunks.
# Completed section 66/8369.
# Processing section 74/8369 in parallel...
# Split text into 1 chunks.
# Completed section 67/8369.
# Processing section 75/8369 in parallel...
# Split text into 1 chunks.
# Completed section 72/8369.
# Processing section 76/8369 in parallel...
# Split text into 1 chunks.
# Completed section 68/8369.
# Processing section 77/8369 in parallel...
# Split text into 1 chunks.
# Completed section 73/8369.
# Processing section 78/8369 in parallel...
# Split text into 1 chunks.
# Completed section 69/8369.
# Processing section 79/8369 in parallel...
# Split text into 1 chunks.
# Completed section 74/8369.
# Processing section 80/8369 in parallel...
# Split text into 1 chunks.
# Completed section 71/8369.
# Processing section 81/8369 in parallel...
# Split text into 1 chunks.
# Completed section 77/8369.
# Processing section 82/8369 in parallel...
# Split text into 1 chunks.
# Completed section 75/8369.
# Processing section 83/8369 in parallel...
# Split text into 1 chunks.
# Completed section 76/8369.
# Processing section 84/8369 in parallel...
# Split text into 1 chunks.
# Completed section 78/8369.
# Processing section 85/8369 in parallel...
# Split text into 1 chunks.
# Completed section 79/8369.
# Processing section 86/8369 in parallel...
# Split text into 1 chunks.
# Completed section 81/8369.
# Processing section 87/8369 in parallel...
# Split text into 1 chunks.
# Completed section 80/8369.
# Processing section 88/8369 in parallel...
# Split text into 1 chunks.
# Completed section 70/8369.
# Processing section 89/8369 in parallel...
# Split text into 1 chunks.
# Completed section 83/8369.
# Processing section 90/8369 in parallel...
# Split text into 1 chunks.
# Completed section 84/8369.
# Processing section 91/8369 in parallel...
# Split text into 1 chunks.
# Completed section 85/8369.
# Processing section 92/8369 in parallel...
# Split text into 1 chunks.
# Completed section 87/8369.
# Processing section 93/8369 in parallel...
# Split text into 1 chunks.
# Completed section 82/8369.
# Processing section 94/8369 in parallel...
# Split text into 1 chunks.
# Completed section 88/8369.
# Processing section 95/8369 in parallel...
# Completed section 89/8369.
# Processing section 96/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 86/8369.
# Processing section 97/8369 in parallel...
# Split text into 1 chunks.
# Completed section 91/8369.
# Processing section 98/8369 in parallel...
# Split text into 1 chunks.
# Completed section 90/8369.
# Processing section 99/8369 in parallel...
# Split text into 1 chunks.
# Completed section 94/8369.
# Processing section 100/8369 in parallel...
# Split text into 1 chunks.
# Completed section 92/8369.
# Processing section 101/8369 in parallel...
# Split text into 1 chunks.
# Completed section 95/8369.
# Processing section 102/8369 in parallel...
# Split text into 1 chunks.
# Completed section 93/8369.
# Processing section 103/8369 in parallel...
# Split text into 1 chunks.
# Completed section 96/8369.
# Processing section 104/8369 in parallel...
# Split text into 1 chunks.
# Completed section 97/8369.
# Processing section 105/8369 in parallel...
# Split text into 1 chunks.
# Completed section 101/8369.
# Processing section 106/8369 in parallel...
# Split text into 1 chunks.
# Completed section 100/8369.
# Processing section 107/8369 in parallel...
# Split text into 1 chunks.
# Completed section 98/8369.
# Processing section 108/8369 in parallel...
# Completed section 103/8369.
# Processing section 109/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 105/8369.
# Processing section 110/8369 in parallel...
# Split text into 1 chunks.
# Completed section 99/8369.
# Processing section 111/8369 in parallel...
# Split text into 1 chunks.
# Completed section 102/8369.
# Processing section 112/8369 in parallel...
# Completed section 104/8369.
# Processing section 113/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 110/8369.
# Processing section 114/8369 in parallel...
# Completed section 109/8369.
# Processing section 115/8369 in parallel...
# Completed section 111/8369.
# Processing section 116/8369 in parallel...
# Completed section 107/8369.
# Processing section 117/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 106/8369.
# Processing section 118/8369 in parallel...
# Completed section 113/8369.
# Processing section 119/8369 in parallel...
# Split text into 1 chunks.
# Completed section 108/8369.
# Processing section 120/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 112/8369.
# Processing section 121/8369 in parallel...
# Split text into 1 chunks.
# Completed section 116/8369.
# Processing section 122/8369 in parallel...
# Completed section 114/8369.
# Processing section 123/8369 in parallel...
# Completed section 120/8369.
# Processing section 124/8369 in parallel...
# Split text into 1 chunks.
# Completed section 119/8369.
# Processing section 125/8369 in parallel...
# Completed section 115/8369.
# Processing section 126/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 117/8369.
# Processing section 127/8369 in parallel...
# Split text into 1 chunks.
# Completed section 118/8369.
# Processing section 128/8369 in parallel...
# Split text into 1 chunks.
# Completed section 121/8369.
# Processing section 129/8369 in parallel...
# Split text into 1 chunks.
# Completed section 126/8369.
# Processing section 130/8369 in parallel...
# Split text into 1 chunks.
# Completed section 123/8369.
# Processing section 131/8369 in parallel...
# Split text into 1 chunks.
# Completed section 124/8369.
# Processing section 132/8369 in parallel...
# Split text into 1 chunks.
# Completed section 125/8369.
# Processing section 133/8369 in parallel...
# Completed section 127/8369.
# Processing section 134/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 129/8369.
# Processing section 135/8369 in parallel...
# Split text into 1 chunks.
# Completed section 134/8369.Completed section 132/8369.
# Processing section 136/8369 in parallel...
#
# Processing section 137/8369 in parallel...
# Completed section 135/8369.
# Processing section 138/8369 in parallel...
# Completed section 130/8369.
# Processing section 139/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 133/8369.
# Processing section 140/8369 in parallel...
# Split text into 1 chunks.
# Completed section 131/8369.
# Processing section 141/8369 in parallel...
# Split text into 1 chunks.
# Completed section 137/8369.
# Processing section 142/8369 in parallel...
# Split text into 1 chunks.
# Completed section 136/8369.
# Processing section 143/8369 in parallel...
# Split text into 1 chunks.
# Completed section 140/8369.
# Processing section 144/8369 in parallel...
# Split text into 1 chunks.
# Completed section 138/8369.
# Processing section 145/8369 in parallel...
# Split text into 1 chunks.
# Completed section 128/8369.
# Processing section 146/8369 in parallel...
# Split text into 1 chunks.
# Completed section 139/8369.
# Processing section 147/8369 in parallel...
# Split text into 1 chunks.
# Completed section 141/8369.
# Processing section 148/8369 in parallel...
# Split text into 1 chunks.
# Completed section 146/8369.
# Processing section 149/8369 in parallel...
# Split text into 1 chunks.
# Completed section 143/8369.
# Processing section 150/8369 in parallel...
# Split text into 1 chunks.
# Completed section 147/8369.
# Processing section 151/8369 in parallel...
# Split text into 1 chunks.
# Completed section 148/8369.
# Processing section 152/8369 in parallel...
# Split text into 1 chunks.
# Completed section 144/8369.
# Processing section 153/8369 in parallel...
# Split text into 1 chunks.
# Completed section 149/8369.
# Processing section 154/8369 in parallel...
# Split text into 2 chunks.
# Completed section 150/8369.
# Processing section 155/8369 in parallel...
# Split text into 1 chunks.
# Completed section 153/8369.
# Processing section 156/8369 in parallel...
# Split text into 1 chunks.
# Completed section 152/8369.
# Processing section 157/8369 in parallel...
# Split text into 1 chunks.
# Completed section 155/8369.
# Processing section 158/8369 in parallel...
# Completed section 151/8369.
# Processing section 159/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 157/8369.
# Processing section 160/8369 in parallel...
# Split text into 1 chunks.
# Completed section 156/8369.
# Processing section 161/8369 in parallel...
# Split text into 1 chunks.
# Completed section 142/8369.
# Processing section 162/8369 in parallel...
# Split text into 1 chunks.
# Completed section 154/8369.
# Processing section 163/8369 in parallel...
# Split text into 1 chunks.
# Completed section 158/8369.
# Processing section 164/8369 in parallel...
# Split text into 1 chunks.
# Completed section 160/8369.
# Processing section 165/8369 in parallel...
# Split text into 1 chunks.
# Completed section 162/8369.
# Processing section 166/8369 in parallel...
# Split text into 1 chunks.
# Completed section 161/8369.
# Processing section 167/8369 in parallel...
# Split text into 1 chunks.
# Completed section 159/8369.
# Processing section 168/8369 in parallel...
# Split text into 1 chunks.
# Completed section 164/8369.
# Processing section 169/8369 in parallel...
# Split text into 1 chunks.
# Completed section 163/8369.
# Processing section 170/8369 in parallel...
# Split text into 1 chunks.
# Completed section 166/8369.
# Processing section 171/8369 in parallel...
# Split text into 1 chunks.
# Completed section 165/8369.
# Processing section 172/8369 in parallel...
# Split text into 1 chunks.
# Completed section 122/8369.
# Processing section 173/8369 in parallel...
# Split text into 1 chunks.
# Completed section 168/8369.
# Processing section 174/8369 in parallel...
# Split text into 2 chunks.
# Completed section 169/8369.
# Processing section 175/8369 in parallel...
# Split text into 1 chunks.
# Completed section 167/8369.
# Processing section 176/8369 in parallel...
# Split text into 1 chunks.
# Completed section 173/8369.
# Processing section 177/8369 in parallel...
# Split text into 1 chunks.
# Completed section 170/8369.
# Processing section 178/8369 in parallel...
# Split text into 1 chunks.
# Completed section 171/8369.
# Processing section 179/8369 in parallel...
# Split text into 1 chunks.
# Completed section 172/8369.
# Processing section 180/8369 in parallel...
# Split text into 1 chunks.
# Completed section 175/8369.
# Processing section 181/8369 in parallel...
# Split text into 2 chunks.
# Completed section 177/8369.
# Processing section 182/8369 in parallel...
# Split text into 1 chunks.
# Completed section 176/8369.
# Processing section 183/8369 in parallel...
# Split text into 1 chunks.
# Completed section 178/8369.
# Processing section 184/8369 in parallel...
# Split text into 1 chunks.
# Completed section 179/8369.
# Processing section 185/8369 in parallel...
# Split text into 1 chunks.
# Completed section 180/8369.
# Processing section 186/8369 in parallel...
# Split text into 1 chunks.
# Completed section 182/8369.
# Processing section 187/8369 in parallel...
# Split text into 1 chunks.
# Completed section 183/8369.
# Processing section 188/8369 in parallel...
# Split text into 1 chunks.
# Completed section 185/8369.
# Processing section 189/8369 in parallel...
# Split text into 1 chunks.
# Completed section 174/8369.
# Processing section 190/8369 in parallel...
# Split text into 1 chunks.
# Completed section 186/8369.
# Processing section 191/8369 in parallel...
# Split text into 1 chunks.
# Completed section 145/8369.
# Processing section 192/8369 in parallel...
# Completed section 188/8369.
# Processing section 193/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 184/8369.
# Processing section 194/8369 in parallel...
# Split text into 1 chunks.
# Completed section 187/8369.
# Processing section 195/8369 in parallel...
# Split text into 1 chunks.
# Completed section 189/8369.
# Processing section 196/8369 in parallel...
# Split text into 1 chunks.
# Completed section 190/8369.
# Processing section 197/8369 in parallel...
# Split text into 1 chunks.
# Completed section 191/8369.
# Processing section 198/8369 in parallel...
# Split text into 1 chunks.
# Completed section 195/8369.
# Processing section 199/8369 in parallel...
# Split text into 1 chunks.
# Completed section 193/8369.
# Processing section 200/8369 in parallel...
# Split text into 1 chunks.
# Completed section 181/8369.
# Processing section 201/8369 in parallel...
# Split text into 1 chunks.
# Completed section 192/8369.
# Processing section 202/8369 in parallel...
# Split text into 1 chunks.
# Completed section 194/8369.
# Processing section 203/8369 in parallel...
# Split text into 1 chunks.
# Completed section 196/8369.
# Processing section 204/8369 in parallel...
# Split text into 2 chunks.
# Completed section 200/8369.
# Processing section 205/8369 in parallel...
# Split text into 1 chunks.
# Completed section 201/8369.
# Processing section 206/8369 in parallel...
# Split text into 1 chunks.
# Completed section 198/8369.
# Processing section 207/8369 in parallel...
# Split text into 1 chunks.
# Completed section 199/8369.
# Processing section 208/8369 in parallel...
# Split text into 1 chunks.
# Completed section 197/8369.
# Processing section 209/8369 in parallel...
# Split text into 1 chunks.
# Completed section 203/8369.
# Processing section 210/8369 in parallel...
# Split text into 1 chunks.
# Completed section 202/8369.
# Processing section 211/8369 in parallel...
# Split text into 1 chunks.
# Completed section 205/8369.
# Processing section 212/8369 in parallel...
# Split text into 1 chunks.
# Completed section 206/8369.
# Processing section 213/8369 in parallel...
# Split text into 1 chunks.
# Completed section 207/8369.
# Processing section 214/8369 in parallel...
# Split text into 1 chunks.
# Completed section 211/8369.
# Processing section 215/8369 in parallel...
# Split text into 1 chunks.
# Completed section 210/8369.
# Processing section 216/8369 in parallel...
# Split text into 1 chunks.
# Completed section 209/8369.
# Processing section 217/8369 in parallel...
# Split text into 1 chunks.
# Completed section 208/8369.
# Processing section 218/8369 in parallel...
# Split text into 1 chunks.
# Completed section 213/8369.
# Processing section 219/8369 in parallel...
# Split text into 1 chunks.
# Completed section 215/8369.
# Processing section 220/8369 in parallel...
# Split text into 1 chunks.
# Completed section 217/8369.
# Processing section 221/8369 in parallel...
# Split text into 1 chunks.
# Completed section 214/8369.
# Processing section 222/8369 in parallel...
# Completed section 218/8369.
# Processing section 223/8369 in parallel...
# Split text into 1 chunks.
# Completed section 204/8369.
# Processing section 224/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 216/8369.
# Processing section 225/8369 in parallel...
# Split text into 1 chunks.
# Completed section 212/8369.
# Processing section 226/8369 in parallel...
# Split text into 1 chunks.
# Completed section 222/8369.
# Processing section 227/8369 in parallel...
# Split text into 1 chunks.
# Completed section 219/8369.
# Processing section 228/8369 in parallel...
# Split text into 1 chunks.
# Completed section 225/8369.
# Processing section 229/8369 in parallel...
# Split text into 1 chunks.
# Completed section 220/8369.
# Processing section 230/8369 in parallel...
# Split text into 1 chunks.
# Completed section 223/8369.
# Processing section 231/8369 in parallel...
# Split text into 1 chunks.
# Completed section 221/8369.
# Processing section 232/8369 in parallel...
# Split text into 1 chunks.
# Completed section 224/8369.
# Processing section 233/8369 in parallel...
# Split text into 1 chunks.
# Completed section 226/8369.
# Processing section 234/8369 in parallel...
# Split text into 1 chunks.
# Completed section 230/8369.
# Processing section 235/8369 in parallel...
# Split text into 1 chunks.
# Completed section 227/8369.
# Processing section 236/8369 in parallel...
# Split text into 1 chunks.
# Completed section 231/8369.
# Processing section 237/8369 in parallel...
# Split text into 1 chunks.
# Completed section 233/8369.
# Processing section 238/8369 in parallel...
# Split text into 1 chunks.
# Completed section 228/8369.
# Processing section 239/8369 in parallel...
# Split text into 1 chunks.
# Completed section 229/8369.
# Processing section 240/8369 in parallel...
# Split text into 1 chunks.
# Completed section 232/8369.
# Processing section 241/8369 in parallel...
# Split text into 1 chunks.
# Completed section 237/8369.
# Processing section 242/8369 in parallel...
# Split text into 1 chunks.
# Completed section 236/8369.
# Processing section 243/8369 in parallel...
# Split text into 1 chunks.
# Completed section 240/8369.
# Processing section 244/8369 in parallel...
# Split text into 1 chunks.
# Completed section 235/8369.
# Processing section 245/8369 in parallel...
# Split text into 1 chunks.
# Completed section 239/8369.
# Processing section 246/8369 in parallel...
# Split text into 1 chunks.
# Completed section 234/8369.
# Processing section 247/8369 in parallel...
# Split text into 1 chunks.
# Completed section 238/8369.
# Processing section 248/8369 in parallel...
# Split text into 1 chunks.
# Completed section 245/8369.
# Processing section 249/8369 in parallel...
# Split text into 1 chunks.
# Completed section 242/8369.
# Processing section 250/8369 in parallel...
# Split text into 1 chunks.
# Completed section 241/8369.
# Processing section 251/8369 in parallel...
# Split text into 1 chunks.
# Completed section 244/8369.
# Processing section 252/8369 in parallel...
# Split text into 1 chunks.
# Completed section 247/8369.
# Processing section 253/8369 in parallel...
# Split text into 1 chunks.
# Completed section 246/8369.
# Processing section 254/8369 in parallel...
# Split text into 1 chunks.
# Completed section 251/8369.
# Processing section 255/8369 in parallel...
# Split text into 1 chunks.
# Completed section 248/8369.
# Processing section 256/8369 in parallel...
# Split text into 1 chunks.
# Completed section 249/8369.
# Processing section 257/8369 in parallel...
# Split text into 1 chunks.
# Completed section 252/8369.
# Processing section 258/8369 in parallel...
# Split text into 1 chunks.
# Completed section 253/8369.
# Processing section 259/8369 in parallel...
# Split text into 1 chunks.
# Completed section 250/8369.
# Processing section 260/8369 in parallel...
# Completed section 254/8369.
# Processing section 261/8369 in parallel...
# Split text into 1 chunks.
# Split text into 2 chunks.
# Completed section 256/8369.
# Processing section 262/8369 in parallel...
# Split text into 1 chunks.
# Completed section 257/8369.
# Processing section 263/8369 in parallel...
# Split text into 1 chunks.
# Completed section 258/8369.
# Processing section 264/8369 in parallel...
# Split text into 1 chunks.
# Completed section 255/8369.
# Processing section 265/8369 in parallel...
# Split text into 1 chunks.
# Completed section 262/8369.
# Processing section 266/8369 in parallel...
# Split text into 1 chunks.
# Completed section 259/8369.
# Processing section 267/8369 in parallel...
# Split text into 1 chunks.
# Completed section 260/8369.
# Processing section 268/8369 in parallel...
# Split text into 1 chunks.
# Completed section 263/8369.
# Processing section 269/8369 in parallel...
# Split text into 1 chunks.
# Completed section 266/8369.
# Processing section 270/8369 in parallel...
# Split text into 1 chunks.
# Completed section 261/8369.
# Processing section 271/8369 in parallel...
# Completed section 267/8369.
# Processing section 272/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 264/8369.
# Processing section 273/8369 in parallel...
# Split text into 1 chunks.
# Completed section 268/8369.
# Processing section 274/8369 in parallel...
# Split text into 1 chunks.
# Completed section 269/8369.
# Processing section 275/8369 in parallel...
# Split text into 1 chunks.
# Completed section 265/8369.
# Processing section 276/8369 in parallel...
# Split text into 1 chunks.
# Completed section 272/8369.
# Processing section 277/8369 in parallel...
# Split text into 1 chunks.
# Completed section 273/8369.
# Processing section 278/8369 in parallel...
# Split text into 1 chunks.
# Completed section 274/8369.
# Processing section 279/8369 in parallel...
# Completed section 270/8369.
# Processing section 280/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 271/8369.
# Processing section 281/8369 in parallel...
# Split text into 1 chunks.
# Completed section 275/8369.
# Processing section 282/8369 in parallel...
# Split text into 1 chunks.
# Completed section 276/8369.
# Processing section 283/8369 in parallel...
# Split text into 1 chunks.
# Completed section 277/8369.
# Processing section 284/8369 in parallel...
# Split text into 1 chunks.
# Completed section 279/8369.
# Processing section 285/8369 in parallel...
# Split text into 1 chunks.
# Completed section 278/8369.
# Processing section 286/8369 in parallel...
# Split text into 1 chunks.
# Completed section 280/8369.
# Processing section 287/8369 in parallel...
# Split text into 1 chunks.
# Completed section 282/8369.
# Processing section 288/8369 in parallel...
# Split text into 1 chunks.
# Completed section 281/8369.
# Processing section 289/8369 in parallel...
# Split text into 1 chunks.
# Completed section 284/8369.
# Processing section 290/8369 in parallel...
# Completed section 283/8369.
# Processing section 291/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 286/8369.
# Processing section 292/8369 in parallel...
# Split text into 1 chunks.
# Completed section 285/8369.
# Processing section 293/8369 in parallel...
# Completed section 287/8369.
# Processing section 294/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 243/8369.
# Processing section 295/8369 in parallel...
# Split text into 1 chunks.
# Completed section 291/8369.
# Processing section 296/8369 in parallel...
# Split text into 1 chunks.
# Completed section 289/8369.
# Processing section 297/8369 in parallel...
# Split text into 1 chunks.
# Completed section 288/8369.
# Processing section 298/8369 in parallel...
# Split text into 1 chunks.
# Completed section 290/8369.
# Processing section 299/8369 in parallel...
# Split text into 1 chunks.
# Completed section 295/8369.
# Processing section 300/8369 in parallel...
# Split text into 1 chunks.
# Completed section 294/8369.
# Processing section 301/8369 in parallel...
# Split text into 1 chunks.
# Completed section 298/8369.
# Processing section 302/8369 in parallel...
# Split text into 1 chunks.
# Completed section 297/8369.
# Processing section 303/8369 in parallel...
# Split text into 1 chunks.
# Completed section 296/8369.
# Processing section 304/8369 in parallel...
# Split text into 1 chunks.
# Completed section 293/8369.
# Processing section 305/8369 in parallel...
# Split text into 1 chunks.
# Completed section 292/8369.
# Processing section 306/8369 in parallel...
# Split text into 1 chunks.
# Completed section 304/8369.
# Processing section 307/8369 in parallel...
# Split text into 1 chunks.
# Completed section 303/8369.
# Processing section 308/8369 in parallel...
# Split text into 1 chunks.
# Completed section 300/8369.
# Processing section 309/8369 in parallel...
# Completed section 301/8369.
# Processing section 310/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 302/8369.
# Processing section 311/8369 in parallel...
# Split text into 1 chunks.
# Completed section 299/8369.
# Processing section 312/8369 in parallel...
# Split text into 1 chunks.
# Completed section 305/8369.
# Processing section 313/8369 in parallel...
# Split text into 1 chunks.
# Completed section 307/8369.
# Processing section 314/8369 in parallel...
# Split text into 1 chunks.
# Completed section 310/8369.
# Processing section 315/8369 in parallel...
# Split text into 1 chunks.
# Completed section 311/8369.
# Processing section 316/8369 in parallel...
# Completed section 308/8369.
# Processing section 317/8369 in parallel...
# Completed section 306/8369.
# Processing section 318/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 312/8369.
# Processing section 319/8369 in parallel...
# Split text into 1 chunks.
# Completed section 315/8369.
# Processing section 320/8369 in parallel...
# Split text into 1 chunks.
# Completed section 314/8369.
# Processing section 321/8369 in parallel...
# Split text into 1 chunks.
# Completed section 318/8369.
# Processing section 322/8369 in parallel...
# Completed section 316/8369.
# Processing section 323/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 317/8369.
# Processing section 324/8369 in parallel...
# Split text into 1 chunks.
# Completed section 313/8369.
# Processing section 325/8369 in parallel...
# Split text into 1 chunks.
# Completed section 319/8369.
# Processing section 326/8369 in parallel...
# Split text into 1 chunks.
# Completed section 325/8369.
# Processing section 327/8369 in parallel...
# Split text into 1 chunks.
# Completed section 320/8369.
# Processing section 328/8369 in parallel...
# Completed section 321/8369.
# Processing section 329/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 322/8369.
# Processing section 330/8369 in parallel...
# Split text into 1 chunks.
# Completed section 309/8369.
# Processing section 331/8369 in parallel...
# Split text into 1 chunks.
# Completed section 323/8369.
# Processing section 332/8369 in parallel...
# Split text into 1 chunks.
# Completed section 324/8369.
# Processing section 333/8369 in parallel...
# Split text into 1 chunks.
# Completed section 326/8369.
# Processing section 334/8369 in parallel...
# Split text into 1 chunks.
# Completed section 328/8369.
# Processing section 335/8369 in parallel...
# Split text into 1 chunks.
# Completed section 330/8369.
# Processing section 336/8369 in parallel...
# Split text into 1 chunks.
# Completed section 329/8369.
# Processing section 337/8369 in parallel...
# Split text into 1 chunks.
# Completed section 331/8369.
# Processing section 338/8369 in parallel...
# Split text into 1 chunks.
# Completed section 327/8369.
# Processing section 339/8369 in parallel...
# Split text into 1 chunks.
# Completed section 332/8369.
# Processing section 340/8369 in parallel...
# Split text into 1 chunks.
# Completed section 334/8369.
# Processing section 341/8369 in parallel...
# Completed section 335/8369.
# Processing section 342/8369 in parallel...
# Completed section 333/8369.
# Processing section 343/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 337/8369.
# Processing section 344/8369 in parallel...
# Split text into 1 chunks.
# Completed section 336/8369.
# Processing section 345/8369 in parallel...
# Completed section 339/8369.
# Processing section 346/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 338/8369.
# Processing section 347/8369 in parallel...
# Completed section 340/8369.
# Processing section 348/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 341/8369.
# Processing section 349/8369 in parallel...
# Completed section 344/8369.
# Processing section 350/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 342/8369.
# Processing section 351/8369 in parallel...
# Split text into 1 chunks.
# Completed section 343/8369.
# Processing section 352/8369 in parallel...
# Split text into 1 chunks.
# Completed section 345/8369.
# Processing section 353/8369 in parallel...
# Completed section 346/8369.
# Processing section 354/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 348/8369.
# Processing section 355/8369 in parallel...
# Split text into 1 chunks.
# Completed section 347/8369.
# Processing section 356/8369 in parallel...
# Split text into 1 chunks.
# Completed section 350/8369.
# Processing section 357/8369 in parallel...
# Split text into 1 chunks.
# Completed section 351/8369.
# Processing section 358/8369 in parallel...
# Completed section 353/8369.
# Processing section 359/8369 in parallel...
# Completed section 354/8369.
# Processing section 360/8369 in parallel...
# Split text into 1 chunks.
# Completed section 352/8369.
# Processing section 361/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 349/8369.
# Processing section 362/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 357/8369.
# Processing section 363/8369 in parallel...
# Completed section 356/8369.
# Processing section 364/8369 in parallel...
# Completed section 355/8369.
# Processing section 365/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 359/8369.
# Processing section 366/8369 in parallel...
# Completed section 360/8369.
# Processing section 367/8369 in parallel...
# Completed section 358/8369.
# Processing section 368/8369 in parallel...
# Completed section 362/8369.
# Processing section 369/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 361/8369.
# Processing section 370/8369 in parallel...
# Split text into 1 chunks.
# Completed section 364/8369.
# Processing section 371/8369 in parallel...
# Completed section 365/8369.
# Processing section 372/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 363/8369.
# Processing section 373/8369 in parallel...
# Completed section 367/8369.
# Processing section 374/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 366/8369.
# Processing section 375/8369 in parallel...
# Completed section 371/8369.
# Processing section 376/8369 in parallel...
# Completed section 369/8369.
# Processing section 377/8369 in parallel...
# Completed section 368/8369.
# Processing section 378/8369 in parallel...
# Split text into 1 chunks.
# Completed section 372/8369.
# Processing section 379/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 2 chunks.
# Completed section 370/8369.
# Processing section 380/8369 in parallel...
# Split text into 1 chunks.
# Completed section 374/8369.
# Processing section 381/8369 in parallel...
# Split text into 1 chunks.
# Completed section 376/8369.
# Processing section 382/8369 in parallel...
# Completed section 378/8369.
# Processing section 383/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 380/8369.
# Processing section 384/8369 in parallel...
# Split text into 1 chunks.
# Completed section 375/8369.
# Processing section 385/8369 in parallel...
# Split text into 1 chunks.
# Completed section 381/8369.
# Processing section 386/8369 in parallel...
# Completed section 373/8369.
# Processing section 387/8369 in parallel...
# Completed section 377/8369.
# Processing section 388/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 382/8369.
# Processing section 389/8369 in parallel...
# Split text into 1 chunks.
# Completed section 379/8369.
# Processing section 390/8369 in parallel...
# Split text into 1 chunks.
# Completed section 383/8369.
# Processing section 391/8369 in parallel...
# Split text into 1 chunks.
# Completed section 384/8369.
# Processing section 392/8369 in parallel...
# Split text into 1 chunks.
# Completed section 390/8369.
# Processing section 393/8369 in parallel...
# Split text into 1 chunks.
# Completed section 386/8369.
# Processing section 394/8369 in parallel...
# Split text into 1 chunks.
# Completed section 387/8369.
# Processing section 395/8369 in parallel...
# Completed section 388/8369.
# Processing section 396/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 392/8369.
# Processing section 397/8369 in parallel...
# Split text into 1 chunks.
# Completed section 391/8369.
# Processing section 398/8369 in parallel...
# Split text into 1 chunks.
# Completed section 394/8369.
# Processing section 399/8369 in parallel...
# Split text into 1 chunks.
# Completed section 395/8369.
# Processing section 400/8369 in parallel...
# Split text into 1 chunks.
# Completed section 396/8369.
# Processing section 401/8369 in parallel...
# Split text into 1 chunks.
# Completed section 393/8369.
# Processing section 402/8369 in parallel...
# Split text into 1 chunks.
# Completed section 385/8369.
# Processing section 403/8369 in parallel...
# Split text into 1 chunks.
# Completed section 397/8369.
# Processing section 404/8369 in parallel...
# Split text into 1 chunks.
# Completed section 400/8369.
# Processing section 405/8369 in parallel...
# Split text into 1 chunks.
# Completed section 401/8369.
# Processing section 406/8369 in parallel...
# Split text into 1 chunks.
# Completed section 398/8369.
# Processing section 407/8369 in parallel...
# Completed section 399/8369.
# Processing section 408/8369 in parallel...
# Split text into 1 chunks.
# Split text into 2 chunks.
# Completed section 403/8369.
# Processing section 409/8369 in parallel...
# Split text into 1 chunks.
# Completed section 404/8369.
# Processing section 410/8369 in parallel...
# Split text into 1 chunks.
# Completed section 389/8369.
# Processing section 411/8369 in parallel...
# Split text into 1 chunks.
# Completed section 406/8369.
# Processing section 412/8369 in parallel...
# Split text into 1 chunks.
# Completed section 408/8369.
# Processing section 413/8369 in parallel...
# Split text into 1 chunks.
# Completed section 409/8369.
# Processing section 414/8369 in parallel...
# Split text into 1 chunks.
# Completed section 405/8369.
# Processing section 415/8369 in parallel...
# Split text into 1 chunks.
# Completed section 411/8369.
# Processing section 416/8369 in parallel...
# Split text into 1 chunks.
# Completed section 410/8369.
# Processing section 417/8369 in parallel...
# Split text into 1 chunks.
# Completed section 414/8369.
# Processing section 418/8369 in parallel...
# Split text into 1 chunks.
# Completed section 413/8369.
# Processing section 419/8369 in parallel...
# Split text into 1 chunks.
# Completed section 412/8369.
# Processing section 420/8369 in parallel...
# Split text into 1 chunks.
# Completed section 416/8369.
# Processing section 421/8369 in parallel...
# Split text into 1 chunks.
# Completed section 415/8369.
# Processing section 422/8369 in parallel...
# Split text into 1 chunks.
# Completed section 407/8369.
# Processing section 423/8369 in parallel...
# Split text into 1 chunks.
# Completed section 418/8369.
# Processing section 424/8369 in parallel...
# Split text into 1 chunks.
# Completed section 420/8369.
# Processing section 425/8369 in parallel...
# Split text into 1 chunks.
# Completed section 421/8369.
# Processing section 426/8369 in parallel...
# Split text into 1 chunks.
# Completed section 419/8369.
# Processing section 427/8369 in parallel...
# Split text into 2 chunks.
# Completed section 424/8369.
# Processing section 428/8369 in parallel...
# Split text into 1 chunks.
# Completed section 422/8369.
# Processing section 429/8369 in parallel...
# Split text into 1 chunks.
# Completed section 425/8369.
# Processing section 430/8369 in parallel...
# Split text into 1 chunks.
# Completed section 423/8369.
# Processing section 431/8369 in parallel...
# Split text into 1 chunks.
# Completed section 426/8369.
# Processing section 432/8369 in parallel...
# Split text into 1 chunks.
# Completed section 417/8369.
# Processing section 433/8369 in parallel...
# Split text into 1 chunks.
# Completed section 429/8369.
# Processing section 434/8369 in parallel...
# Completed section 428/8369.
# Processing section 435/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 402/8369.
# Processing section 436/8369 in parallel...
# Split text into 1 chunks.
# Completed section 430/8369.
# Processing section 437/8369 in parallel...
# Split text into 1 chunks.
# Completed section 432/8369.
# Processing section 438/8369 in parallel...
# Split text into 1 chunks.
# Completed section 431/8369.
# Processing section 439/8369 in parallel...
# Split text into 1 chunks.
# Completed section 433/8369.
# Processing section 440/8369 in parallel...
# Split text into 1 chunks.
# Completed section 427/8369.
# Processing section 441/8369 in parallel...
# Split text into 1 chunks.
# Completed section 434/8369.
# Processing section 442/8369 in parallel...
# Split text into 1 chunks.
# Completed section 436/8369.
# Processing section 443/8369 in parallel...
# Split text into 1 chunks.
# Completed section 438/8369.
# Processing section 444/8369 in parallel...
# Split text into 1 chunks.
# Completed section 435/8369.
# Processing section 445/8369 in parallel...
# Split text into 1 chunks.
# Completed section 439/8369.
# Processing section 446/8369 in parallel...
# Split text into 1 chunks.
# Completed section 437/8369.
# Processing section 447/8369 in parallel...
# Split text into 1 chunks.
# Completed section 440/8369.
# Processing section 448/8369 in parallel...
# Split text into 1 chunks.
# Completed section 441/8369.
# Processing section 449/8369 in parallel...
# Split text into 1 chunks.
# Completed section 443/8369.
# Processing section 450/8369 in parallel...
# Split text into 1 chunks.
# Completed section 442/8369.
# Processing section 451/8369 in parallel...
# Split text into 1 chunks.
# Completed section 447/8369.
# Processing section 452/8369 in parallel...
# Split text into 1 chunks.
# Completed section 445/8369.
# Processing section 453/8369 in parallel...
# Split text into 1 chunks.
# Completed section 446/8369.
# Processing section 454/8369 in parallel...
# Split text into 1 chunks.
# Completed section 448/8369.
# Processing section 455/8369 in parallel...
# Split text into 1 chunks.
# Completed section 444/8369.
# Processing section 456/8369 in parallel...
# Split text into 1 chunks.
# Completed section 450/8369.
# Processing section 457/8369 in parallel...
# Split text into 1 chunks.
# Completed section 451/8369.
# Processing section 458/8369 in parallel...
# Split text into 1 chunks.
# Completed section 454/8369.
# Processing section 459/8369 in parallel...
# Completed section 452/8369.
# Processing section 460/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 449/8369.
# Processing section 461/8369 in parallel...
# Split text into 1 chunks.
# Completed section 453/8369.
# Processing section 462/8369 in parallel...
# Split text into 1 chunks.
# Completed section 456/8369.
# Processing section 463/8369 in parallel...
# Completed section 455/8369.
# Processing section 464/8369 in parallel...
# Completed section 457/8369.
# Processing section 465/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 458/8369.
# Processing section 466/8369 in parallel...
# Split text into 1 chunks.
# Completed section 461/8369.
# Processing section 467/8369 in parallel...
# Split text into 1 chunks.
# Completed section 459/8369.
# Processing section 468/8369 in parallel...
# Split text into 1 chunks.
# Completed section 460/8369.
# Processing section 469/8369 in parallel...
# Split text into 1 chunks.
# Completed section 462/8369.
# Processing section 470/8369 in parallel...
# Split text into 1 chunks.
# Completed section 463/8369.
# Processing section 471/8369 in parallel...
# Split text into 1 chunks.
# Completed section 467/8369.
# Processing section 472/8369 in parallel...
# Split text into 1 chunks.
# Completed section 464/8369.
# Processing section 473/8369 in parallel...
# Split text into 1 chunks.
# Completed section 466/8369.
# Processing section 474/8369 in parallel...
# Split text into 1 chunks.
# Completed section 465/8369.
# Processing section 475/8369 in parallel...
# Split text into 1 chunks.
# Completed section 470/8369.
# Processing section 476/8369 in parallel...
# Split text into 1 chunks.
# Completed section 471/8369.
# Processing section 477/8369 in parallel...
# Split text into 1 chunks.
# Completed section 469/8369.
# Processing section 478/8369 in parallel...
# Split text into 2 chunks.
# Completed section 474/8369.
# Processing section 479/8369 in parallel...
# Split text into 1 chunks.
# Completed section 468/8369.
# Processing section 480/8369 in parallel...
# Split text into 1 chunks.
# Completed section 475/8369.
# Processing section 481/8369 in parallel...
# Split text into 1 chunks.
# Completed section 472/8369.
# Processing section 482/8369 in parallel...
# Split text into 2 chunks.
# Completed section 476/8369.
# Processing section 483/8369 in parallel...
# Split text into 1 chunks.
# Completed section 473/8369.
# Processing section 484/8369 in parallel...
# Split text into 1 chunks.
# Completed section 479/8369.
# Processing section 485/8369 in parallel...
# Split text into 1 chunks.
# Completed section 477/8369.
# Processing section 486/8369 in parallel...
# Split text into 1 chunks.
# Completed section 480/8369.
# Processing section 487/8369 in parallel...
# Split text into 1 chunks.
# Completed section 481/8369.
# Processing section 488/8369 in parallel...
# Split text into 1 chunks.
# Completed section 483/8369.
# Processing section 489/8369 in parallel...
# Split text into 1 chunks.
# Completed section 484/8369.
# Processing section 490/8369 in parallel...
# Split text into 1 chunks.
# Completed section 485/8369.
# Processing section 491/8369 in parallel...
# Split text into 1 chunks.
# Completed section 487/8369.
# Processing section 492/8369 in parallel...
# Split text into 1 chunks.
# Completed section 486/8369.
# Processing section 493/8369 in parallel...
# Split text into 1 chunks.
# Completed section 489/8369.
# Processing section 494/8369 in parallel...
# Split text into 1 chunks.
# Completed section 478/8369.
# Processing section 495/8369 in parallel...
# Split text into 1 chunks.
# Completed section 482/8369.
# Processing section 496/8369 in parallel...
# Split text into 1 chunks.
# Completed section 492/8369.
# Processing section 497/8369 in parallel...
# Split text into 1 chunks.
# Completed section 493/8369.
# Processing section 498/8369 in parallel...
# ...
# Processing section 8216/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8210/8369.
# Processing section 8217/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8211/8369.
# Processing section 8218/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8209/8369.
# Processing section 8219/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8213/8369.
# Processing section 8220/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8216/8369.
# Processing section 8221/8369 in parallel...
# Completed section 8212/8369.
# Processing section 8222/8369 in parallel...
# Split text into 1 chunks.
# Split text into 3 chunks.
# Completed section 8218/8369.
# Processing section 8223/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8214/8369.
# Processing section 8224/8369 in parallel...
# Completed section 8215/8369.
# Processing section 8225/8369 in parallel...
# Split text into 2 chunks.
# Split text into 3 chunks.
# Completed section 8222/8369.
# Processing section 8226/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8217/8369.
# Processing section 8227/8369 in parallel...
# Completed section 8219/8369.
# Processing section 8228/8369 in parallel...
# Split text into 2 chunks.
# Split text into 2 chunks.
# Completed section 8220/8369.
# Processing section 8229/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8226/8369.
# Processing section 8230/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8223/8369.
# Processing section 8231/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8224/8369.
# Processing section 8232/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8232/8369.
# Processing section 8233/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8221/8369.
# Processing section 8234/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8231/8369.
# Processing section 8235/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8225/8369.
# Processing section 8236/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8230/8369.
# Processing section 8237/8369 in parallel...
# Completed section 8229/8369.
# Processing section 8238/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 8234/8369.
# Processing section 8239/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8228/8369.
# Processing section 8240/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8233/8369.
# Processing section 8241/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8235/8369.
# Processing section 8242/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8237/8369.
# Processing section 8243/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8238/8369.
# Processing section 8244/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8239/8369.
# Processing section 8245/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8241/8369.
# Processing section 8246/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8236/8369.
# Processing section 8247/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8240/8369.
# Processing section 8248/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8242/8369.
# Processing section 8249/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8244/8369.
# Processing section 8250/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8243/8369.
# Processing section 8251/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8245/8369.
# Processing section 8252/8369 in parallel...
# Completed section 8249/8369.
# Processing section 8253/8369 in parallel...
# Completed section 8247/8369.
# Processing section 8254/8369 in parallel...
# Completed section 8248/8369.
# Processing section 8255/8369 in parallel...
# Completed section 8246/8369.
# Processing section 8256/8369 in parallel...
# Split text into 2 chunks.
# Split text into 2 chunks.
# Split text into 1 chunks.
# Split text into 2 chunks.
# Split text into 2 chunks.
# Completed section 8250/8369.
# Processing section 8257/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8227/8369.
# Processing section 8258/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8251/8369.
# Processing section 8259/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8254/8369.
# Processing section 8260/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8257/8369.
# Processing section 8261/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8256/8369.
# Processing section 8262/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8259/8369.
# Processing section 8263/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8255/8369.Completed section 8252/8369.
# Processing section 8264/8369 in parallel...
#
# Processing section 8265/8369 in parallel...
# Split text into 2 chunks.
# Split text into 2 chunks.
# Completed section 8253/8369.
# Processing section 8266/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8260/8369.
# Processing section 8267/8369 in parallel...
# Completed section 8258/8369.
# Processing section 8268/8369 in parallel...
# Split text into 2 chunks.
# Split text into 1 chunks.
# Completed section 8261/8369.
# Processing section 8269/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8268/8369.
# Processing section 8270/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8263/8369.
# Processing section 8271/8369 in parallel...
# Completed section 8266/8369.
# Processing section 8272/8369 in parallel...
# Split text into 2 chunks.
# Split text into 1 chunks.
# Completed section 8264/8369.
# Processing section 8273/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8265/8369.
# Processing section 8274/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8262/8369.
# Processing section 8275/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8272/8369.
# Processing section 8276/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8267/8369.
# Processing section 8277/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8269/8369.
# Processing section 8278/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8273/8369.
# Processing section 8279/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8274/8369.
# Processing section 8280/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8270/8369.
# Processing section 8281/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8275/8369.
# Processing section 8282/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8271/8369.
# Processing section 8283/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8276/8369.
# Processing section 8284/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8277/8369.
# Processing section 8285/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8278/8369.
# Processing section 8286/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8279/8369.
# Processing section 8287/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8283/8369.
# Processing section 8288/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8280/8369.
# Processing section 8289/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8281/8369.
# Processing section 8290/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8282/8369.
# Processing section 8291/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8290/8369.
# Processing section 8292/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8286/8369.
# Processing section 8293/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8291/8369.
# Processing section 8294/8369 in parallel...
# Split text into 3 chunks.
# Completed section 8285/8369.
# Processing section 8295/8369 in parallel...
# Completed section 8284/8369.
# Processing section 8296/8369 in parallel...
# Split text into 1 chunks.
# Split text into 2 chunks.
# Completed section 8288/8369.
# Processing section 8297/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8287/8369.
# Processing section 8298/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8289/8369.
# Processing section 8299/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8295/8369.
# Processing section 8300/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8292/8369.
# Processing section 8301/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8293/8369.
# Processing section 8302/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8296/8369.
# Processing section 8303/8369 in parallel...
# Completed section 8298/8369.
# Processing section 8304/8369 in parallel...
# Split text into 1 chunks.
# Split text into 2 chunks.
# Completed section 8299/8369.
# Processing section 8305/8369 in parallel...
# Split text into 3 chunks.
# Completed section 8300/8369.
# Processing section 8306/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8303/8369.
# Processing section 8307/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8301/8369.
# Processing section 8308/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8302/8369.
# Processing section 8309/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8309/8369.
# Processing section 8310/8369 in parallel...
# Completed section 8307/8369.
# Processing section 8311/8369 in parallel...
# Completed section 8305/8369.
# Processing section 8312/8369 in parallel...
# Split text into 1 chunks.
# Split text into 2 chunks.
# Split text into 2 chunks.
# Completed section 8308/8369.
# Processing section 8313/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8297/8369.
# Processing section 8314/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8306/8369.
# Processing section 8315/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8312/8369.
# Processing section 8316/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8315/8369.
# Processing section 8317/8369 in parallel...
# Completed section 8314/8369.
# Processing section 8318/8369 in parallel...
# Split text into 2 chunks.
# Split text into 1 chunks.
# Completed section 8304/8369.
# Processing section 8319/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8311/8369.
# Processing section 8320/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8310/8369.
# Processing section 8321/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8313/8369.
# Processing section 8322/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8318/8369.
# Processing section 8323/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8316/8369.
# Processing section 8324/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8322/8369.
# Processing section 8325/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8319/8369.
# Processing section 8326/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8317/8369.
# Processing section 8327/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8320/8369.
# Processing section 8328/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8321/8369.
# Processing section 8329/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8324/8369.
# Processing section 8330/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8294/8369.
# Processing section 8331/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8329/8369.
# Processing section 8332/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8330/8369.
# Processing section 8333/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8323/8369.
# Processing section 8334/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8325/8369.
# Processing section 8335/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8328/8369.
# Processing section 8336/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8327/8369.
# Processing section 8337/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8326/8369.
# Processing section 8338/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8336/8369.
# Processing section 8339/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8331/8369.
# Processing section 8340/8369 in parallel...
# Completed section 8335/8369.
# Processing section 8341/8369 in parallel...
# Split text into 1 chunks.
# Split text into 2 chunks.
# Completed section 8332/8369.
# Processing section 8342/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8333/8369.
# Processing section 8343/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8338/8369.
# Processing section 8344/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8334/8369.
# Processing section 8345/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8337/8369.
# Processing section 8346/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8340/8369.
# Processing section 8347/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8343/8369.
# Processing section 8348/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8342/8369.
# Processing section 8349/8369 in parallel...
# Completed section 8341/8369.
# Processing section 8350/8369 in parallel...
# Split text into 1 chunks.
# Split text into 1 chunks.
# Completed section 8348/8369.
# Processing section 8351/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8345/8369.
# Processing section 8352/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8346/8369.
# Processing section 8353/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8339/8369.
# Processing section 8354/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8349/8369.
# Processing section 8355/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8344/8369.
# Processing section 8356/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8350/8369.
# Processing section 8357/8369 in parallel...
# Completed section 8347/8369.
# Processing section 8358/8369 in parallel...
# Split text into 2 chunks.
# Split text into 1 chunks.
# Completed section 8351/8369.
# Processing section 8359/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8356/8369.
# Processing section 8360/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8358/8369.
# Processing section 8361/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8352/8369.
# Processing section 8362/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8354/8369.
# Processing section 8363/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8355/8369.
# Processing section 8364/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8353/8369.
# Processing section 8365/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8357/8369.
# Processing section 8366/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8359/8369.
# Processing section 8367/8369 in parallel...
# Split text into 2 chunks.
# Completed section 8363/8369.
# Processing section 8368/8369 in parallel...
# Split text into 1 chunks.
# Completed section 8366/8369.
# Processing section 8369/8369 in parallel...
# Split text into 0 chunks.
# Completed section 8365/8369.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Completed section 8369/8369.
# Completed section 8360/8369.
# Completed section 8361/8369.
# Completed section 8362/8369.
# Completed section 8364/8369.
# Completed section 8368/8369.
# Completed section 8367/8369.
# Warning: Embedding at index 8368 has shape (), replacing with zeros.
# Embedding matrix shape: (8369, 1536)
# Processing complete!

# %%
np.save("embedding_matrix_subtitles.npy", processor.matrix)

# %%
# Print the number of embeddings in ../out/books/embedding_matrix_books.npy
matrix = np.load("../out/subtitles/embedding_matrix_subtitles.npy")
print(f"Embedding matrix shape: {matrix.shape}")
# Out:
# Embedding matrix shape: (8369, 1536)

# %%
print(f"Shape of matrix: {matrix.shape}")
print(f"Length of df: {len(df)}")
# Out:
# Shape of matrix: (8369, 1536)
# Length of df: 8368

# %%
from sklearn.cluster import KMeans

matrix = np.load("../out/subtitles/embedding_matrix_subtitles.npy")
# Remove the last row of the matrix
matrix = matrix[:-1]

df = processor.df.copy()

n_clusters = 4

kmeans = KMeans(n_clusters=n_clusters, init="k-means++", random_state=42)
kmeans.fit(matrix)
labels = kmeans.labels_
df["Cluster"] = labels

for cluster in range(n_clusters):
    print(f"Cluster {cluster} Sample Texts:\n")
    print(df[df["Cluster"] == cluster]["Text"].sample(5, random_state=42).values)
    print("\n" + "-"*80 + "\n")
# Out:
# Cluster 0 Sample Texts:
#
# ['Subtitles for Ooggetuige II ( 16 ) Wie kent de inbrekers die in Waregem een brandkast roofden ? Een bewakingscamera heeft ze gefilmd . Wie heeft in Gent een vrouw van 40 achtervolgd ? En zomaar op straat verkracht ? In Antwerpen gingen twee gangsters aan de haal met dure edelstelen . Wie zijn die mannen die zich voordeden als klanten ? Goedenavond . In drie onopgeloste politiezaken kan u het verschil maken . Want misschien bent u de cruciale getuige die het onderzoek op het goede spoor brengt . Als u iets weet over een van de drie dossiers , aarzel dan niet en bel . Er staan drie gratis 0800-nummers klaar . Maar voor we de nieuwe zaken bekijken blikken we terug op vorige Ooggetuiges . Bij ons zit commissaris Danny Jamers . Welkom , commissaris . Heeft u resultaten ? Ja , Tijdens en na vorige uitzending kregen we een 20-tal tips . Er is gebeld voor alledrie de zaken . Die tips worden nu door de speurders verder onderzocht . Ook voor de overval op de eigenaar van de tobacco-shop kregen we tips . Maar men vraagt ons de robotfoto nog eens te tonen . We zoeken de man die de eigenaar van een tobacco-shop in Adinkerke overviel . Op de robottekening valt vooral z\'n zeer kort haar op . En z\'n neus staat scheef alsof hij ooit gebroken is geweest . Als u de man kent , kan u nog deze week bellen . Daarvoor dit extra 0800-nummer : Gisteren meldde het journaal dat een bende homejackers is veroordeeld En dat is gebeurd na een oproep in Ooggetuige . Die bende heeft in maart en april vorig jaar in Aalst twee gewelddadige homejackings gepleegd . We brachten een reconstructie na de laatste overval . Een kijker herkende de robotfoto . Die dader is enkele dagen later opgepakt . Nadien is de bende opgerold . Gisteren zijn 4 daders veroordeeld tot 10 , 8 , 6 en 1 jaar cel . Nu is die zaak dus ook voor de rechtbank gesloten . Tijd dan voor ons eerste nieuwe opsporingsdossier . Daarvoor trekken we naar het West-Vlaamse Waregem . We hebben bewakingsbeelden van maart Op het eerste gezicht lijken de mannen verhuizers . Maar later blijkt dat in het bedrijf naast de deur de brandkast is geroofd . Dan is duidelijk dat het inbrekers zijn . Een van hen had een opvallend motief op de rug van z\'n jas . De dieven zijn blank , ca. 30 jaar oud en tussen 1,75 en 1,80m groot . Ze hebben allebei kort zwart haar . Weet u wie deze twee zijn , dan belt u het eerste 0800-nummer voor vanavond . U komt dan terecht bij de mensen van de politiezone Mira . Dat is de politiezone van Waregem en omstreken . Volgens de speurders hebben deze twee dit al meer gedaan . Ze kunnen op andere plaatsen aan de slag geweest zijn . Als u hen herkent , bel dan 0800 , twee keer 20 en op het eind 1 . Met ons tweede dossier zitten we in Gent .. .. nabij het Jan Palfijnziekenhuis . \'s Avonds is het daar meestal vrij rustig . Maar op 6 september is daar een v
end zijn er rondleidingen langs logementshuizen . Bezoekers kunnen op een vragenlijst hun mening kwijt . Volgende bestemming . De Pauw in Torhout . Ook één van de oude logementshuizen . Hier hebben we een totaal ander verhaal binnen ons erfgoedgegeven . Dde Peerdenposterij is een plaats die nog .. .. gerestaureerd moet worden en waar we een bestemming voor moeten vinden Dit huis is al gerenoveerd . We willen de bezoekers ook vragen erover stellen . Wij willen de mensen confronteren met wat ermee moet gebeuren . En zijn de al gedane restauraties goed of niet ? De rondleidingen volgend weekend zijn te voet en duren 1,5 uur . De Tinnenburg ligt ook op de route . Geen logementshuis , wel een restant van een middeleeuwse heerlijkheid . Het huis dat er nu staat , was ooit de woning .. .. van de eerste burgemeester van Torhout . Tegenwoordig kun je kiezen uit twee , hooguit drie soorten appels of peren . Vroeger was de keuze veel groter . Vlaanderen stond bekend om zijn pomologen , experten in de vruchtenkunde . Vooral hier in Mechelen waren ze heel goed in het veredelen van peren Hun pronkstuk heette de Josephine de Malines . Het zal wel lekker geweest zijn . Ze had bijzondere kenmerken . Zo was het vruchtvlees smeltend . Naarmate ze rijper werd , werd ze rozig van kleur . Die eigenschap werd bij de veredeling verder gebruikt . En ze geurde naar hyacint . Waarom bestaat ze niet meer ? Die oude variëteiten zijn verdwenen wegens minder commercieel . Bestaat ze nog ? Ja , ze groeit in mijn tuin . Ze is heel lekker en kan bewaard worden tot in maart . Kwam ze enkel in België voor ? Die planten werden ook uitgevoerd naar het buitenland . Zo zijn er naar Versailles ganse partijen jonge bomen verzonden van hieruit . Over reizend erfgoed gesproken ! En dan is er nog een ander soort erfgoed : kennis . De pomologen van de 19e eeuw veredelden en snoeiden .. .. die van de 21e eeuw doen het ook en tonen het op 27 april . Een boom gaat heel sterk groeien in zijn jeugdjaren . Dat zie je aan die lange takken . Als je die niet snoeit , gaan ze ombuigen . Nu is er vruchthout vanachter aan de takken . Bedoeling is vruchthout onderaan de boom te krijgen . Anders gaat de boom uitbuigen . We snoeien dus om stevige takken te krijgen en om vruchttakken te krijgen links en rechts . Wat moet er nu weg ? Dit is al een vruchttak met zijtakken . Nu gaan we terug insnoeien . Ongeveer de helft . Dan krijgen we de beste verdikking op een buitenoog . Dat is een buitenoog . Het tweede oog halen we weg . Want de groei gaat naar boven en dan is de tak te steil . We gaan dus een mooie tak naar buiten krijgen . Wat zijn die takjes ? Dat is de schuilplaats voor oorworme ...
#
# --------------------------------------------------------------------------------

# %%
print(df.columns)
# Out:
# Index(['Title', 'Text', 'Cluster'], dtype='object')

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Run t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, perplexity=15, random_state=42, init="random", learning_rate=200)
vis_dims2 = tsne.fit_transform(matrix)

# Extract x and y coordinates
x = [x for x, y in vis_dims2]
y = [y for x, y in vis_dims2]

# Dynamically generate a colormap
n_clusters = df["Cluster"].nunique()
colors = cm.get_cmap("tab10", n_clusters)

plt.figure(figsize=(10, 6))

for category in range(n_clusters):
    xs = np.array(x)[df.Cluster == category]
    ys = np.array(y)[df.Cluster == category]
    
    plt.scatter(xs, ys, color=colors(category), alpha=0.3, label=f"Cluster {category}")
    
    # Compute and plot cluster centroid
    avg_x = xs.mean()
    avg_y = ys.mean()
    plt.scatter(avg_x, avg_y, marker="x", color=colors(category), s=100, edgecolor="black")

plt.title("Clusters visualized in 2D using t-SNE")
# Out:
# /var/folders/yx/bp07d_fj08bd4h_x3m2q3bcr0000gp/T/ipykernel_88664/3993969128.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab10", n_clusters)  # Choose a colormap with distinct colors
# /var/folders/yx/bp07d_fj08bd4h_x3m2q3bcr0000gp/T/ipykernel_88664/3993969128.py:28: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(avg_x, avg_y, marker="x", color=colors(category), s=100, edgecolor="black")
# Text(0.5, 1.0, 'Clusters visualized in 2D using t-SNE')

# %%
rev_per_cluster = 10

for i in range(n_clusters):
    print(f"Cluster {i} Theme:", end=" ")

    sampled_reviews = df[df.Cluster == i].Text.sample(rev_per_cluster, random_state=42).values
    # Make sure the reviews are not too long
    sampled_reviews = [review[:100000] for review in sampled_reviews]
    
    # Summarize each review individually
    summaries = []
    for review in sampled_reviews:
        summary_prompt = [
            {"role": "user", "content": f"Summarize the following text:\n\n\"\"\"\n{review}\n\"\"\""}
        ]
        
        summary_response = openai_client.chat.completions.create(
            model="gpt-4o",
            messages=summary_prompt,
            temperature=0,
            max_tokens=64,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0
        )
        
        summary = summary_response.choices[0].message.content.strip()
        summaries.append(summary)

    # Combine the summaries into a single text
    combined_summaries = "\n".join(summaries)

    # Ask what these summaries have in common
    theme_prompt = [
        {
            "role": "user",
            "content": f"What do the following summaries have in common?\n\nSummaries:\n\"\"\"\n{combined_summaries}\n\"\"\"\n\nTheme:"
        }
    ]

    theme_response = openai_client.chat.completions.create(
        model="gpt-4o",
        messages=theme_prompt,
        temperature=0,
        max_tokens=64,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    print(theme_response.choices[0].message.content.replace("\n", ""))

    # Print the first few characters of each sampled review
    sample_cluster_rows = df[df.Cluster == i].sample(rev_per_cluster, random_state=42)
    for j in range(rev_per_cluster):
        print(sample_cluster_rows.Text.str[:70].values[j])

    print("-" * 100)
# Out:
# Cluster 0 Theme: The common theme among these summaries is that they all describe various documentary or factual programs and narratives that explore different aspects of human society, history, and the natural world. Each summary provides an overview of a specific topic, ranging from crime investigations, historical events, and political figures, to wildlife, human-animal relationships, and
# Subtitles for Ooggetuige II ( 16 ) Wie kent de inbrekers die in Warege
# Subtitles for Het Derde Oog - Het gesticht Aan de rand van Gent , midd
# Subtitles for Histories - Apocalyps toen ( 3 ) Goedenavond . Vanavond
# Subtitles for Kijk Uit ! - Veilighedisgordel zo Elk jaar voert het Ins
# Subtitles for Panorama - De familie Saddam Saddam zit in een cel op zi
# Subtitles for Rare Streken - Wild Indonesia ( 2 Dit is het verhaal van
# Subtitles for Rare Streken - Triomf Van Het Le In de strijd om te over
# Subtitles for Panorama - De keizer van Italiº Hij is tot eind dit jaar
# Subtitles for Rare Streken - United Snakes of De mens en de slang . Ma
# Subtitles for weer Goedenavond . Zuivere zeelucht vandaag , maar toch
# Subtitles for Vlaanderen Vakantieland 26/00 Goedenavond . In Dilbeek z
# Subtitles for weer Dag beste kijker . Na een ijskoude ochtend waren er
# ----------------------------------------------------------------------------------------------------

# %%
class BiblicalChecker(str, Enum):
    is_biblical = "yes"
    is_not_biblical = "no"

class Biblical(BaseModel):
    type: BiblicalChecker

class AsyncBiblicalChecker:
    def __init__(self, df: pd.DataFrame, text_column: str, async_openai_client, max_concurrent_requests=20):
        self.df = df
        self.text_column = text_column
        self.client = async_openai_client
        self.semaphore = asyncio.Semaphore(max_concurrent_requests)

    async def check_biblical(self, text: str) -> str:
        """Asynchronously checks if a given text is biblical."""
        try:
            truncated_text = " ".join(text.split()[:1000])

            async with self.semaphore:  # Ensure limit of concurrent requests
                response = await async_openai_client.beta.chat.completions.parse(
                model="gpt-4o-2024-08-06",
                messages=[
                    {"role": "system", "content": "Determine if the provided text is biblical. Respond with 'Yes' or 'No'."},
                    {"role": "user", "content": f"Is the following text biblical? {truncated_text}"},
                ],
                response_format=Biblical,
            )
            return response.choices[0].message.content.strip()
        except Exception as e:
            return f"Error: {str(e)}"

    async def process_dataframe(self):
        """Processes the DataFrame asynchronously."""
        tasks = [self.check_biblical(row[self.text_column]) for _, row in self.df.iterrows()]
        results = await asyncio.gather(*tasks)
        self.df["is_biblical"] = results
        return results

# %%
checker = AsyncBiblicalChecker(df, text_column="Text", async_openai_client=async_openai_client)

async def run_checker():
    results = await checker.process_dataframe()
    return results

results = await run_checker()

# %%
pd.set_option('display.max_colwidth', None)

# Get the percentage of biblical texts (i.e. if is_biblical contains "yes") in the DataFrame, which would be {"type": "yes"}
biblical_percentage = (checker.df["is_biblical"] == '{"type":"yes"}').mean()
print(f"Biblical text percentage: {biblical_percentage:.2%}")

# Print only the biblical texts
biblical_texts = checker.df[checker.df["is_biblical"] == '{"type":"no"}']
print(biblical_texts["Text"].sample(5).values)

# Save the DataFrame to a CSV file
checker.df.to_csv("biblical_check.csv", index=False)
# Out:
# Biblical text percentage: 49.61%
# ["Manuel Vázquez Montalban Autobiografie van generaal Franco Vertaald door Saskia Otter Maar we hebben zojuist gezien dat de ruis ook vertaald wordt in een bepaalde vorm , in een bepaald spectrum , waarin enkele componenten vaker voorkomen dan anderen . Hij is verbonden met de graad van relatieve ongeordendheid van het universum ( entropie ) , in verhouding tot de graad van de door het signaal opgelegde orde ( negatieve entropie ) , zoals de werken van Szilard en van Brioullin hebben bewezen . Einstein heeft aangetoond dat de globale energie voortgebracht door de ruis groter was als het kanaal hem meer mogelijkheden gaf om zich te manifesteren ; naarmate de bandbreedte , dat wil zeggen het geheel van aleatorische vormen die konden worden doorgegeven , groter was . Bovendien heeft hij bewezen dat als deze ruis buiten de toevallige of opzettelijke signalen viel , dat wil zeggen de toevallige superpositie was van twee boodschappen bestemd voor twee onderling verschillende correspondenten , indien deze ruis bijvoorbeeld verbonden was met de spontane beweging van atomen en electronen die de materiële drager van het communicatiekanaal vormen , het normaal was dat de ruis toenam met de temperatuur ; hoe h
#  "' Syntaxis en semantiek van de van die-constructie ' 0 Inleiding Uit de literatuur is bekend dat zinnen met van die-constructies ambigu zijn ( zie o.a. Droste 1960 , Van der Lubbe 1982 , Haegeman 1987 ) . Zin ( 1 ) kan betekenen dat Jan ' kleffe koekjes , weetje wel ' at , ofwel dat Jan at van een bepaalde verzameling kleffe koekjes . ( 1 ) Jan at van die kleffe koekjes . Van der Lubbe spreekt in het eerste geval van een ' schijnbare ' of ' verbleekte ' partitieve woordgroep . Wij verwijzen in het vervolg naar de eerste lezing met NP-lezing en naar de tweede lezing met PP-lezing . Een van die-constructie met een NP-lezing noemen wij een van die-NP . Dat de van die-NP inderdaad een NP is en geen PP wordt in paragraaf 1.1 aan de hand van een aantal syntactische tests beargumenteerd . Een daaraan gepaard gaande conclusie zal zijn dat de woordgroep in zijn PP-lezing ook inderdaad een PP is . In paragraaf 1.2 zal beargumenteerd worden dat de in ( 1 ) gesignaleerde ambiguïteit blijft bestaan wanneer de van die-constructie een telwoord bevat , zoals in ( 2 ) . ( 2 ) Jan at drie van die kleffe koekjes . In paragraaf 2 worden structuren gegeven voor beide lezingen van ( 1 ) en ( 2 ) . De analyse van de van die-constructie in de PP-lezing verleent steun aan een voorstel van Bennis ( 1979 ) , volgens welk er in ( 2 ) sprake is van een lege N met een PP als complement . In de analyse van de NP-lezing van ( 1 ) en ( 2 ) is echter koekjes het hoofd . Problematisch is dan de status en functie van het determinator-gedeelte van de van die-NP . In paragraaf 3 betogen we dat van die gezien moet worden als een ' syntactisch atoom ' , één woord dus , en dat dit de determinator is van de van die-NP . De analyse wordt ingepast in het kader van Abney ( 1987 ) . Er zal blijken dat van die zowel qua semantiek als qua distributie grote overeenkomsten vertoont met de nul-determinator . Een belangrijk verschil tussen de twee vinden we in generieke zinnen . Paragraaf 4.1 beschrijft de betreffende feiten . In paragraaf 4.2 wordt een semantische verklaring voorgesteld , die en passant het partitiefachtige uiterlijk van de van die-NP verantwoordt . 1 NP-lezing en PP-lezing 1.1 Van die disambigueringen Het verschil tussen de twee lezingen van de ambigue zin ( 1 ) kan duidelijk gemaakt worden aan de hand van de volgende syntactische tests . 1.1.1 PP-over-V Als we de regel PP-over-V toepassen blijft alleen de PP-lezing over : ( 3 ) Jan heeft gegeten van die kleffe koekjes . 1.1.2 R-pronominalisatie Als we het complement van van vervangen door een R-pronomen blijft eveneens alleen de PP-lezing over : ( 4 ) Jan heeft ervan gegeten . 1.1.3 subcategorisatie Sommige werkwoorden werken eveneens disambiguerend , in die zin dat ze een PP-lezing uitsluiten : ( 5 ) Craig draagt altijd van die malle petten . We voorspellen dat deze werkwoorden geen PP-over-V en geen R-pronominalisatie toestaan . Dit blijkt het geval te zijn : ( 6a ) * ... dat Craig altijd draagt van die malle petten . ( 6b ) * ( Over malle petten gesproken , ) Craig draagt er altijd van . 1.1.4 subject De NP-lezing is ook de enige die overleeft als de van die-constituent een subject is , hetzij in bona fide zin , hetzij in een Small Clause ( SC ) : ( 7a ) Er liepen van die eenvoudige marktkooplui op straat . ( 7b ) met van die malle petten op zijn hoofd ( 7c ) Ik eet van die lekkere taartjes altijd helemaal op . ( 7d ) Craig vindt van die mal
ze kregen gelijk ) , en zelfs zijn liefdesleven was in de straten van Rome een terugkerende komedie geworden . Maar hoog boven het gelach op het Forum , in zijn paleis dat zich uitstrekte op de Palatinus , was het Claudius Caesar die in zijn vuistje lachte . Hij wist dat onder zijn grijzende haardos een helder verstand school . Zelfs zijn vijanden moesten toegeven dat hij na de gekke Caligula het Rijk had gestabiliseerd en ook op grootse wijze de grenzen ervan had verlegd . Iedere keer dat hij merkte dat hij al te zeer luisterde naar kritiek of roddel , liep Claudius naar de kolossale kaart van het Rijk die een hele wand in zijn kantoor besloeg en glimlachte hij naar het grote eiland in de noordwestelijke hoek dat nu ingekleurd was met de kleuren van Rome : Brittannia ! Hij , Claudius de clown , de manke machthebber , de wiebelhoofdige wereldveroveraar , had Brittannia veroverd ! En vanwege deze verovering moest Titus Flavius Sabinus op een morgen begin mei op audiëntie bij de keizer komen . Sabinus , een keurig geklede luitenant-bevelhebber die juist terugkwam van het Romeinse leger in Brittannië , werd het paleis binnengelaten en liep nu door de gemarmerde gangen naar de wachtkamer van Claudius \' kantoor . Een man met een Grieks uiterlijk en een slanke gestalte stond op van zijn bureau en stak een geparfumeerde hand uit . \' Ah ... welkom , Flavius Sabinus ! \' zei de op een na machtigste man van het Romeinse Rijk . \' Hartelijk gegroet , waarde Narcissus ! \' antwoordde Sabinus terwijl hij dacht : zeg maar gerust waardevol , zo\'n 400 miljoen sestertiën als staatssecretaris ... niet slecht voor een gewezen slaaf . Maar Sabinus durfde alleen de voor de hand liggende vraag te stellen : \' Verwacht de keizer mij ? \' \' Natuurlijk . Wilt ...

# %%
# Print the different values in the is_biblical column
print(checker.df["is_biblical"].value_counts())
# Out:
# is_biblical
# {"type":"no"}     256
# {"type":"yes"}    252
# Name: count, dtype: int64

# %%
# read in the CSV file
pd.options.display.max_colwidth = 250
biblical_check = pd.read_csv("../out/biblical_check.csv")

biblical_check.sample(5)
# Out:
#                         Title  \
# 109  WR-P-P-B-0000000116.dcoi
# 363  WR-P-P-B-0000000372.dcoi
# 8    WR-P-P-B-0000000011.dcoi
# 365  WR-P-P-B-0000000374.dcoi
# 333  WR-P-P-B-0000000341.dcoi
#
#                                                                                                                                                                                                                                                           Text  \
# 109  Het komt wel goed , juf ! Voor Nille Inhoud Proloog Het vmbo / mbo in vogelvlucht Een leven voor de klas 1 Ontslag 2 Voor de leeuwen 3 Het klappen van de zweep 4 Een vaste aanstelling 5 Afsluiting van het eerste semester 6 Het tweede semester 7 R...
# 363  De invloed van de fysieke omgeving op lichamelijke activiteit : Beleid voor beweegvriendelijke wijken Inhoudsopgave ( removed ) INLEIDING Vrijwel iedereen hecht veel waarde aan een lang en gezond leven . Echter , door onder andere overgewicht ond...
# 8    Aarde . Onze Levende Bibliotheek : Aarde Lessen van de Pleiadiërs BARBARA MARCINIAK in samenwerking met KAREN MARCINIAK TERA THOMAS Uitgeverij Petiet / Laren Oorspronkelijke titel : EARTH [ Pleiadian Keys to the Living Library ] by Barbara Marcin...
# 365  Obadja Obadja 1 1 Hier volgt wat God , de Heer , in een visioen aan Obadja bekendmaakte over het lot van Edom . 1 De Heer zal Edom straffen 1 Een bode is gestuurd naar de volken , 1 hij komt van de Heer ; 1 wij hebben zijn boodschap gehoord : 1 '...
# 333  Inleiding op de eerste brief aan Timoteüs Inleiding op de eerste brief aan Timoteüs DE TWEE BRIEVEN aan Timoteüs ( 1 en 2 Tim ) en de brief aan Titus ( Tit ) worden al vanouds als een aparte groep beschouwd . Sinds de achttiende eeuw worden ze de...
#
#         is_biblical
# 109   {"type":"no"}
# 363   {"type":"no"}
# 8     {"type":"no"}
# 365  {"type":"yes"}
# 333   {"type":"no"}

# %%
# Azure storage account credentials
source_container_name = "books"
destination_container_name = "booksbiblical"

# Load dataframe
df = pd.read_csv("biblical_check.csv")

# Extract non-biblical filenames
non_biblical_files = df[df['is_biblical'].str.contains('yes', case=False)]['Title'].tolist()

# Put '.xml' extension back to the filenames
non_biblical_files = [f"{filename}.xml" for filename in non_biblical_files]
print(f"Number of non-biblical files: {len(non_biblical_files)}")
print(non_biblical_files)

# Initialize Blob Service Client
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
source_container_client = blob_service_client.get_container_client(source_container_name)
destination_container_client = blob_service_client.get_container_client(destination_container_name)

# Iterate over blobs in source container and copy non-biblical files
for blob in source_container_client.list_blobs():
    filename = blob.name
    
    if filename in non_biblical_files:
        source_blob_client = source_container_client.get_blob_client(blob.name)
        destination_blob_client = destination_container_client.get_blob_client(blob.name)
        
        # Copy blob
        destination_blob_client.start_copy_from_url(source_blob_client.url)
        print(f"Copied {blob.name} to {destination_container_name}")

print("Copy process completed.")
# Out:
# Number of non-biblical files: 252
# ['WR-P-P-B-0000000071.dcoi.xml', 'WR-P-P-B-0000000072.dcoi.xml', 'WR-P-P-B-0000000073.dcoi.xml', 'WR-P-P-B-0000000074.dcoi.xml', 'WR-P-P-B-0000000075.dcoi.xml', 'WR-P-P-B-0000000076.dcoi.xml', 'WR-P-P-B-0000000077.dcoi.xml', 'WR-P-P-B-0000000078.dcoi.xml', 'WR-P-P-B-0000000079.dcoi.xml', 'WR-P-P-B-0000000080.dcoi.xml', 'WR-P-P-B-0000000081.dcoi.xml', 'WR-P-P-B-0000000082.dcoi.xml', 'WR-P-P-B-0000000083.dcoi.xml', 'WR-P-P-B-0000000084.dcoi.xml', 'WR-P-P-B-0000000085.dcoi.xml', 'WR-P-P-B-0000000086.dcoi.xml', 'WR-P-P-B-0000000087.dcoi.xml', 'WR-P-P-B-0000000088.dcoi.xml', 'WR-P-P-B-0000000089.dcoi.xml', 'WR-P-P-B-0000000090.dcoi.xml', 'WR-P-P-B-0000000091.dcoi.xml', 'WR-P-P-B-0000000092.dcoi.xml', 'WR-P-P-B-0000000093.dcoi.xml', 'WR-P-P-B-0000000094.dcoi.xml', 'WR-P-P-B-0000000095.dcoi.xml', 'WR-P-P-B-0000000096.dcoi.xml', 'WR-P-P-B-0000000097.dcoi.xml', 'WR-P-P-B-0000000098.dcoi.xml', 'WR-P-P-B-0000000099.dcoi.xml', 'WR-P-P-
dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000455.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000457.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000458.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000460.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000461.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000462.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000463.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000464.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000465.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000466.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000467.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000468.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000469.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000470.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000471.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000472.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000473.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000474.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000475.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000476.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000477.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000478.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000479.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000480.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000481.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000482.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000483.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000484.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000485.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000486.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000488.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000489.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000490.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000491.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000492.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000493.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000494.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000495.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000496.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000497.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000498.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000499.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000500.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000501.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000502.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000503.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000504.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000505.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000506.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000507.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000508.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000509.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000510.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000511.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000512.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000513.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000514.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000515.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000516.dcoi.xml to booksbiblical
# Copied WR-P-P-B-0000000517.dcoi.xml to booksbiblical
# Copy process completed.

# %%
class PlotMaker:
    def __init__(self, corpus_part=None):
        self.corpus_part = corpus_part
        self.df = None
    
    def load_data(self, file_path):
        """Loads the word frequency data from a CSV file."""
        if self.corpus_part is None:
            raise ValueError("No corpus_part provided.")
        
        self.df = pd.read_csv(file_path)
    
    def word_frequency_distribution(self, top_n=20, remove_stopwords=True):
        """Plots a word frequency distribution."""
        # Load the DataFrame
        file_path = f"../out/{self.corpus_part}/word_frequencies_{self.corpus_part}.csv"
        self.load_data(file_path)

        if remove_stopwords:
            # Load Dutch stopwords
            stopwords = set(nltk.corpus.stopwords.words("dutch"))
            
            print(f"Removing {len(stopwords)} stopwords...")
            print(f"Example stopwords: {list(stopwords)[:5]}")
            print(f"Original DataFrame shape: {self.df.shape}")

            # Remove stopwords, punctuation, and non-alphabetic words
            self.df = self.df[
                ~self.df["Word"].str.lower().isin(stopwords) &   # Stopwords removal
                self.df["Word"].str.isalpha() &                  # Remove non-alphabetic words
                ~self.df["Word"].isin(set(string.punctuation))   # Remove punctuation
            ]

            print(f"New DataFrame shape: {self.df.shape}")
        top_words = self.df.nlargest(top_n, 'Frequency')
        
        plt.figure(figsize=(12, 6))
        sns.barplot(data=top_words, x='Word', y='Frequency')
        plt.xticks(rotation=45, ha='right')
        plt.xlabel("Word")
        plt.ylabel("Frequency")
        plt.title(f"Top {top_n} Words by Frequency")
        plt.show()

    def word_count_distribution(self, bins=20):
        """Plots a word count distribution."""
        # Load the DataFrame
        file_path = f"../out/{self.corpus_part}/wordcount_and_10gram_perfile_{self.corpus_part}.csv"
        self.load_data(file_path)
        
        plt.figure(figsize=(12, 6))
        sns.histplot(self.df["word_count"], bins=bins, kde=True, edgecolor="black", alpha=0.7)
        plt.xlabel("Word Count")
        plt.ylabel("Frequency")
        plt.title("Distribution of Word Count per File")
        plt.show()

    def filename_vs_wordcount(self, top_n=10, ascending=False):
        """Plots the top N filenames by word count."""
        # Load the DataFrame
        file_path = f"../out/{self.corpus_part}/wordcount_and_10gram_perfile_{self.corpus_part}.csv"
        self.load_data(file_path)

        df_sorted = self.df.sort_values(by="word_count", ascending=ascending).head(20)
        plt.figure(figsize=(10, 5))
        
        bars = plt.barh(df_sorted["filename"], df_sorted["word_count"], color="skyblue")
        plt.xlabel("Word Count")
        plt.ylabel("Filename")
        if ascending:
            plt.title("Bottom 20 Files by Word Count")
        else:
            plt.title("Top 20 Files by Word Count")
        plt.gca().invert_yaxis()

        # Add word count labels to the bars
        for bar, word_count in zip(bars, df_sorted["word_count"]):
            plt.text(word_count, bar.get_y() + bar.get_height()/2, f"{word_count:,}", va='center', ha='left', fontsize=10)

        plt.show()

# %%
plot_maker = PlotMaker("books")

plot_maker.word_frequency_distribution(top_n=20, remove_stopwords=True)
plot_maker.word_count_distribution(bins=20)
plot_maker.filename_vs_wordcount(top_n=10)
plot_maker.filename_vs_wordcount(top_n=10, ascending=True)
# Out:
# Removing 101 stopwords...
# Example stopwords: ['wat', 'altijd', 'ge', 'en', 'nu']
# Original DataFrame shape: (342999, 2)
# New DataFrame shape: (296779, 2)

# %%
gendered_wordpairs_list = [
    'man', 'vrouw',
    'Man', 'Vrouw',
    'mannen', 'vrouwen',
    'Mannen', 'Vrouwen',
    'jongen', 'meisje',
    'Jongen', 'Meisje',
    'jongens', 'meisjes',
    'Jongens', 'Meisjes',
    'jongetje', 'meisje',
    'Jongetje', 'Meisje',
    'jongetjes', 'meisjes',
    'Jongetjes', 'Meisjes',
    'kerel', 'meid',
    'Kerel', 'Meid',
    'kerels', 'meiden',
    'Kerels', 'Meiden',
    'gozer', 'meid',
    'Gozer', 'Meid',
    'gozers', 'meiden',
    'Gozers', 'Meiden',
    'gozer', 'wijf',
    'Gozer', 'Wijf',
    'gozers', 'wijven',
    'Gozers', 'Wijven',
    'gentleman', 'lady',
    'Gentleman', 'Lady',
    'lord', 'lady',
    'Lord', 'Lady',
    'heer', 'dame',
    'Heer', 'Dame',
    'heren', 'dames',
    'Heren', 'Dames',
    'meneer', 'mevrouw',
    'Meneer', 'Mevrouw',
    'mijnheer', 'mevrouw',
    'Mijnheer', 'Mevrouw',
    'mister', 'miss',
    'Mister', 'Miss',
    'Mr.', 'Ms.',
    'Mr', 'Ms',
    'Mr.', 'Mrs.',
    'Mr', 'Mrs',
    'mannelijk', 'vrouwelijk',
    'Mannelijk', 'Vrouwelijk',
    'mannelijke', 'vrouwelijke',
    'Mannelijke', 'Vrouwelijke',
    'koning', 'koningin',
    'Koning', 'Koningin',
    'koningen', 'koninginnen',
    'Koningen', 'Koninginnen',
    'prins', 'prinses',
    'Prins', 'Prinses',
    'prinsen', 'prinsessen',
    'Prinsen', 'Prinsessen',
    'hertog', 'hertogin',
    'Hertog', 'Hertogin',
    'hertogen', 'hertoginnen',
    'monnik', 'non',
    'Monnik', 'Non',
    'monniken', 'nonnen',
    'Monniken', 'Nonnen',
    'baron', 'barones',
    'Baron', 'Barones',
    'hij', 'zij',
    'Hij', 'Zij',
    'hijzelf', 'zijzelf',
    'Hijzelf', 'Zijzelf',
    'vader', 'moeder',
    'Vader', 'Moeder',
    'vaders', 'moeders',
    'Vaders', 'Moeders',
    'papa', 'mama',
    'Papa', 'Mama',
    'papa\'s', 'mama\'s',
    'Papa\'s', 'Mama\'s',
    'pappa', 'mamma',
    'Pappa', 'Mamma',
    'pappa\'s', 'mamma\'s',
    'Pappa\'s', 'Mamma\'s',
    'broer', 'zus',
    'Broer', 'Zus',
    'broers', 'zussen',
    'Broers', 'Zussen',
    'neef', 'nicht',
    'Neef', 'Nicht',
    'neven', 'nichten',
    'oom', 'tante',
    'Oom', 'Tante',
    'ooms', 'tantes',
    'grootvader', 'grootmoeder',
    'Grootvader', 'Grootmoeder',
    'grootvaders', 'grootmoeders',
    'Grootvaders', 'Grootmoeders',
    'opa', 'oma',
    'Opa', 'Oma',
    'opa\'s', 'oma\'s',
    'Opa\'s', 'Oma\'s',
    'zoon', 'dochter',
    'Zoon', 'Dochter',
    'zonen', 'dochters',
    'Zonen', 'Dochters',
    'kleinzoon', 'kleindochter',
    'Kleinzoon', 'Kleindochter',
    'kleinzonen', 'kleindochters',
    'schoonzoon', 'schoondochter',
    'Schoonzoon', 'Schoondochter',
    'schoonzonen', 'schoondochters',
    'stiefvader', 'stiefmoeder',
    'Stiefvader', 'Stiefmoeder',
    'stiefvaders', 'stiefmoeders',
    'Stiefvaders', 'Stiefmoeders',
    'stiefzoon', 'stiefdochter',
    'Stiefzoon', 'Stiefdochter',
    'stiefzonen', 'stiefdochters',
    'schoonvader', 'schoonmoeder',
    'schoonvaders', 'schoonmoeders',
    'bruidegom', 'bruid',
    'Bruidegom', 'Bruid',
    'bruidegoms', 'bruiden',
    'peetvader', 'peetmoeder',
    'Peetvader', 'Peetmoeder',
]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

class GenderedWordsPlotter:
    def __init__(self, corpus_part=None, gendered_wordpairs_list=None):
        """
        Initializes the plotter.
        
        Parameters:
            corpus_part (str): A subsection of the corpus (e.g., "books").
            gendered_wordpairs_list (list): A list of words where every two consecutive items
                                            form a male/female pair.
        """
        if corpus_part is None:
            raise ValueError("You must provide a corpus_part (e.g., 'books').")
        if gendered_wordpairs_list is None:
            raise ValueError("You must provide a gendered_wordpairs_list.")
            
        self.corpus_part = corpus_part
        self.df = None
        
        self.gendered_wordpairs_list = gendered_wordpairs_list
        # Create pairs
        self.pairs = list(zip(gendered_wordpairs_list[0::2], gendered_wordpairs_list[1::2]))
        # Create lists for later use
        self.male_words = set(gendered_wordpairs_list[0::2])
        self.female_words = set(gendered_wordpairs_list[1::2])
    
    def load_data(self, file_path=None):
        """
        Loads the word frequency data from a CSV file.
        If no file_path is provided, builds one using the corpus_part.
        """
        if self.corpus_part is None:
            raise ValueError("No corpus_part provided.")
        
        if file_path is None:
            file_path = f"../out/{self.corpus_part}/gendered_wordpairs_{self.corpus_part}.csv"
        
        self.df = pd.read_csv(file_path)
        print(f"Data loaded from {file_path} with shape {self.df.shape}")
    
    def plot_gendered_word_pairs(self, n_largest=3):
        """
        Creates a grouped horizontal bar chart that shows the frequencies of each gendered word pair.
        The male and female frequencies for each pair (if present) are plotted side-by-side.
        Also identifies and highlights the top 3 pairs with the biggest frequency differences.
        """
        # Load data if not already loaded.
        if self.df is None:
            self.load_data()

        pair_freq = []
        for male, female in self.pairs:
            # Sum frequencies for exact word matches.
            male_freq = self.df.loc[self.df['Word'] == male, 'Frequency'].sum()
            female_freq = self.df.loc[self.df['Word'] == female, 'Frequency'].sum()

            # Only include pairs with any frequency.
            if male_freq + female_freq > 0:
                pair_freq.append({
                    'pair': f"{male}/{female}",
                    'Male': male_freq,
                    'Female': female_freq,
                    'Difference': abs(male_freq - female_freq)  # Compute the absolute difference.
                })

        pair_df = pd.DataFrame(pair_freq)
        if pair_df.empty:
            print("No matching gendered word pairs found in the DataFrame.")
            return

        # Identify the top 3 pairs with the largest differences.
        top_pairs = pair_df.nlargest(n_largest, 'Difference')
        print("Top 3 pairs with the biggest difference:")
        print(top_pairs[['pair', 'Difference']])

        ind = np.arange(len(pair_df))
        height = 0.35  # Width of the bars.

        fig, ax = plt.subplots(figsize=(10, 15))
        bars_male = ax.barh(ind - height/2, pair_df['Male'], height, label='Male', color='lightskyblue')
        bars_female = ax.barh(ind + height/2, pair_df['Female'], height, label='Female', color='lightpink')

        # Highlight the top 3 pairs by drawing an outline around their bars.
        for i, row in pair_df.iterrows():
            if row['pair'] in top_pairs['pair'].values:
                # Add a black edge to the male bar.
                ax.barh(i - height/2, row['Male'], height,
                        edgecolor='black', linewidth=1, fill=False)
                # Add a black edge to the female bar.
                ax.barh(i + height/2, row['Female'], height,
                        edgecolor='black', linewidth=1, fill=False)

        ax.set_xlabel('Frequency')
        ax.set_xscale('log')
        fig.suptitle('Frequency of Gendered Words by Pair', x=0.6)
        ax.set_title(f"The black outlined bars represent the top {n_largest} pairs with the biggest frequency differences.", fontsize=10)
        ax.set_yticks(ind)
        ax.set_yticklabels(pair_df['pair'])
        ax.legend()

        plt.gca().invert_yaxis()
        plt.tight_layout()
        plt.show()

        # Create a separate plot for the top 3 differences.
        fig2, ax2 = plt.subplots(figsize=(8, 4))

        # Set the color for each bar: lightskyblue if Male frequency is higher (or equal), lightpink if Female is higher.
        colors = ['lightskyblue' if row['Male'] >= row['Female'] else 'lightpink' 
                for _, row in top_pairs.iterrows()]

        ax2.barh(top_pairs['pair'], top_pairs['Difference'], color=colors)
        ax2.set_xlabel('Absolute Frequency Difference')
        ax2.set_title('Top 3 Word Pairs with the Biggest Frequency Difference')
        ax2.invert_yaxis()  # Highest difference at the top.
        plt.tight_layout()
        plt.show()

    def plot_gender_distribution(self, n_largest=3):
        """
        Plots two pie charts as subplots:
        - Left: the overall frequency distribution of gendered words.
        - Right: the frequency distribution after excluding the top n difference pairs.
        
        Parameters:
            n_largest (int): Number of top-difference pairs to exclude in the second pie chart.
        """
        # Ensure data is loaded.
        if self.df is None:
            self.load_data()

        male_total_all = self.df[self.df['Word'].isin(self.male_words)]['Frequency'].sum()
        female_total_all = self.df[self.df['Word'].isin(self.female_words)]['Frequency'].sum()

        pair_freq = []
        for male, female in self.pairs:
            # Sum frequencies for the exact word matches.
            male_freq = self.df.loc[self.df['Word'] == male, 'Frequency'].sum()
            female_freq = self.df.loc[self.df['Word'] == female, 'Frequency'].sum()
            if male_freq + female_freq > 0:
                pair_freq.append({
                    'pair': f"{male}/{female}",
                    'Male': male_freq,
                    'Female': female_freq,
                    'Difference': abs(male_freq - female_freq)
                })
        
        pair_df = pd.DataFrame(pair_freq)
        if pair_df.empty:
            print("No matching gendered word pairs found in the DataFrame.")
            return

        # Identify the top n pairs with the largest absolute frequency differences.
        top_pairs = pair_df.nlargest(n_largest, 'Difference')

        # Collect the words (both male and female) from these top pairs.
        top_words = set()
        for pair in top_pairs['pair']:
            m, f = pair.split('/')
            top_words.update([m, f])

        # For male, remove any word that is in top_words.
        male_total_excl = self.df[self.df['Word'].isin(self.male_words - top_words)]['Frequency'].sum()
        # Likewise for female.
        female_total_excl = self.df[self.df['Word'].isin(self.female_words - top_words)]['Frequency'].sum()

        fig, axs = plt.subplots(1, 2, figsize=(16, 8))

        # Pie chart for the overall distribution.
        totals_all = [male_total_all, female_total_all]
        axs[0].pie(totals_all,
                labels=['Male', 'Female'],
                autopct='%1.1f%%',
                colors=['lightskyblue', 'lightpink'],
                startangle=90)
        axs[0].set_title("Total Frequency of Gendered Words (All Pairs)")
        axs[0].axis('equal')  # Ensures the pie is drawn as a circle.

        # Pie chart for the distribution excluding top difference pairs.
        totals_excl = [male_total_excl, female_total_excl]
        axs[1].pie(totals_excl,
                labels=['Male', 'Female'],
                autopct='%1.1f%%',
                colors=['lightskyblue', 'lightpink'],
                startangle=90)
        axs[1].set_title(f"Frequency Excluding Top {n_largest} Difference Pairs")
        axs[1].axis('equal')

        plt.tight_layout()
        plt.show()

# %%
plotter = GenderedWordsPlotter(corpus_part="books", gendered_wordpairs_list=gendered_wordpairs_list)

plotter.plot_gendered_word_pairs(n_largest=4)
plotter.plot_gender_distribution(n_largest=4)
# Out:
# Data loaded from ../out/books/gendered_wordpairs_books.csv with shape (122, 3)
# Top 3 pairs with the biggest difference:
#                pair  Difference
# 30          hij/zij      223201
# 14        heer/dame       12327
# 21  koning/koningin       11972
# 48     zoon/dochter        6902

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

class ProfessionsPlotter:
    def __init__(self, corpus_part=None):
        """
        Initializes the plotter.
        
        Parameters:
            corpus_part (str): A subsection of the corpus (e.g., "books").
        """
        if corpus_part is None:
            raise ValueError("You must provide a corpus_part (e.g., 'books').")
        
        self.corpus_part = corpus_part
        self.df = None
    
    def load_data(self, file_path=None):
        """
        Loads the profession frequency data from a CSV file.
        If no file_path is provided, builds one using the corpus_part.
        """
        if self.corpus_part is None:
            raise ValueError("No corpus_part provided.")
        
        if file_path is None:
            file_path = f"../out/{self.corpus_part}/professions_{self.corpus_part}.csv"
        
        self.df = pd.read_csv(file_path)
        self.df = self.df.sort_values(by='Frequency', ascending=False)
        print(f"Data loaded from {file_path} with shape {self.df.shape}")
    
    def plot_top_n_professions(self, n=10):
        """Plots a bar chart of the top N professions by frequency."""
        if self.df is None:
            self.load_data()
        
        top_n_df = self.df.head(n)
        
        plt.figure(figsize=(10, 6))
        plt.barh(top_n_df['Word'], top_n_df['Frequency'], color='royalblue')
        plt.xlabel("Frequency")
        plt.ylabel("Profession")
        plt.title(f"Top {n} Most Frequent Professions")
        plt.gca().invert_yaxis()  # Highest frequency at the top
        plt.show()

# %%
profession_plotter = ProfessionsPlotter(corpus_part="subtitles")
profession_plotter.plot_top_n_professions(n=20)
# Out:
# Data loaded from ../out/subtitles/professions_subtitles.csv with shape (74, 2)
